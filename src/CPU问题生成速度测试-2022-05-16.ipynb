# %%
# !pip install transformers
# !pip install question_generation
# !pip install torch
# Out:
# Collecting transformers
#   Downloading transformers-4.19.1-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 24.3 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 50.5 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 47.5 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.6.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.9 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.6.0 pyyaml-6.0 tokenizers-0.12.1 transformers-4.19.1
# Collecting question_generation
#   Downloading question_generation-1.0.5-py3-none-any.whl (34 kB)
# Collecting datasets>=1.15.1
#   Downloading datasets-2.2.1-py3-none-any.whl (342 kB)
#      |████████████████████████████████| 342 kB 24.4 MB/s
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.7/dist-packages (from question_generation) (1.11.0+cu113)
# Requirement already satisfied: transformers>=4.12.5 in /usr/local/lib/python3.7/dist-packages (from question_generation) (4.19.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (2.23.0)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 75.5 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 55.2 MB/s
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (4.64.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (1.21.6)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (0.70.12.2)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 57.3 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (4.11.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (0.6.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (6.0.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (0.3.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.15.1->question_generation) (4.2.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.15.1->question_generation) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.15.1->question_generation) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets>=1.15.1->question_generation) (3.0.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.15.1->question_generation) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.15.1->question_generation) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.15.1->question_generation) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.15.1->question_generation) (2021.10.8)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 58.5 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.12.5->question_generation) (2019.12.20)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.12.5->question_generation) (0.12.1)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.15.1->question_generation) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 60.0 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.15.1->question_generation) (21.4.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.0 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 55.3 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets>=1.15.1->question_generation) (3.8.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets>=1.15.1->question_generation) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets>=1.15.1->question_generation) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets>=1.15.1->question_generation) (1.15.0)
# Installing collected packages: multidict, frozenlist, yarl, urllib3, asynctest, async-timeout, aiosignal, fsspec, aiohttp, xxhash, responses, datasets, question-generation
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 datasets-2.2.1 frozenlist-1.3.0 fsspec-2022.3.0 multidict-6.0.2 question-generation-1.0.5 responses-0.18.0 urllib3-1.25.11 xxhash-3.0.0 yarl-1.7.2
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (4.2.0)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("algolet/mt5-base-chinese-qg")

model = AutoModelForSeq2SeqLM.from_pretrained("algolet/mt5-base-chinese-qg")

from question_generation import pipeline

# gpu版本
qg = pipeline("question-generation", device="cpu") 
qa = pipeline("question-answering", device="cpu")
# Out:
# Downloading:   0%|          | 0.00/428 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.11M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/7.93M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.17G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/669 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/263k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.21G [00:00<?, ?B/s]

# %%
import pandas as pd
import glob
import json
import csv
import re
import os
import time

path = r'./drive/MyDrive/Database/test_data/20220516-cpu' # use your path


all_files = glob.glob(path + "/*.csv")

start_time = time.time()
print('start_time: ', start_time)

for filename in all_files:
    test_list = []
    # 提取需要生成问题的文件名
    fname = filename.split('/')[-1:][0]
    fname = os.path.splitext(fname)[0]
    # 遍历词条信息进行问题生成
    with open(filename, 'r', encoding='utf-8-sig') as csvfile:
        csvReader = csv.DictReader(csvfile)
        i = 0
        for row in csvReader:
            y = {
                '_id':'',
                'text':'',
                'qa_pair':[]}
            i = i + 1
            text1 = row['实体']
            text2 = row['属性']
            text3 = row['值']
            full_text = text1 + ', '+ text2 +  ', '+  text3
            # 正则表达式，去除[]、()中的附加文本内容，减少对模型生成问题的无关影响
            full_text = re.sub("[\(\[].*?[\)\]]", "", full_text)
            # 对row进行转换，把原本的OrderedDict转换成string，此处因为保存原格式模型的表现更好，故此处进行保留
            # row = str(dict(row))
            print('FullText: ', full_text)
            y['_id'] = i
            questions = qg(full_text)
            j = 0
            for q in questions:
                z = {
                     'c_id':'',
                     'q':'',
                     'a':'',
                     'label':''
                }
                y['text'] = full_text
                answer = qa({
                    'question': str(q),
                    'context': full_text,
                })
                print('Q: ', q)
                # print('Row: ', row)
                if bool(answer) is False:
                    print('{ }')
                else:
                    j = j + 1
                    z['c_id'] = j
                    z['q'] = q
                    z['a'] = answer['answer']
                    print('Answer: ', answer['answer'])
                    print('\n')
                    y['qa_pair'].append(z)
            # 在满足q_a pair不空的情况下才进行添加
            if len(y['qa_pair']) == 0:
                pass
            else:
                test_list.append(y)
    # 对单个文件生成完后进行添加操作
    with open('./drive/MyDrive/Database/results/20220516-cpu/'+fname+'.json', 'a', encoding='utf-8-sig') as file:
        json.dump(test_list, file, ensure_ascii=False) 

end_time = time.time()
print('end_time: ', end_time)
use_time = end_time - start_time
print('use time: ', use_time)
# Out:
# start_time:  1652689452.6199744
# FullText:  敦刻尔克大撤退, 地点, 法国敦刻尔克
# Q:  敦刻尔克大撤退地点是哪里?
# Answer:  敦刻尔克
#
#
# Q:  大撤退的地点在哪里?
# { }
# Q:  法国大撤退位于哪里?
# Answer:  敦刻尔克
#
#
# FullText:  敦刻尔克大撤退, 时间, 1940年5月26日 - 1940年6月4日
# Q:  敦刻尔克什么时候撤退的?
# Answer:  1940
#
#
# Q:  哪一个城市在1940年撤退?
# Answer:  敦刻尔克
#
#
# Q:  在1940年5月26日,哪一个城市撤退了?
# Answer:  敦刻尔克
#
#
# FullText:  敦刻尔克大撤退, 参战方, 英国，法国，比利时，德国
# Q:  敦刻尔克的参战方是哪个国家?
# Answer:  英国
#
#
# Q:  哪个国家打败了敦刻尔科?
# Answer:  比利时
#
#
# Q:  哪支球队在敦刻尔顿大撤退?
# Answer:  英国，法国，比利时
#
#
# FullText:  敦刻尔克大撤退, 结果, 英法联军成功撤退至英国本土
# Q:  英法联军从敦刻尔克撤退到哪个国家?
# Answer:  英国
#
#
# Q:  英国的哪个城市撤退了?
# Answer:  敦刻尔克
#
#
# Q:  哪个国家撤退了敦刻尔科?
# Answer:  英国
#
#
# FullText:  敦刻尔克大撤退, 参战方兵力, 英法联军 约400,000人
# 德军 约800,000人
# Q:  敦刻尔克撤退后,英法联军有多少人参战?
# Answer:  400,000人
#
#
# Q:  英法联军队有多少人参加战斗?
# Answer:  400,000人
#
#
# Q:  德军有多少人参加战役?
# Answer:  800,000人
#
#
# FullText:  敦刻尔克大撤退, 伤亡情况, 盟军 2.8万余人阵亡，4万人被俘
# 德军 1万余人阵亡
# Q:  敦刻尔克大撤退后有多少人被俘?
# Answer:  4万
#
#
# Q:  德军有多少人阵亡?
# Answer:  1万余人
#
#
# Q:  盟军有多少伤亡?
# Answer:  2.8万
#
#
# FullText:  敦刻尔克大撤退, 主要指挥官, 罗德·高特，魏刚，伦德施泰特
# Q:  谁是敦刻尔克大撤退的指挥官?
# Answer:  罗德·高特
#
#
# Q:  谁是罗德·高特,魏刚和伦德施泰特?
# Answer:  敦刻尔克大撤退
#
#
# Q:  罗德高特的指挥官是谁?
# Answer:  魏刚
#
#
# FullText:  敦刻尔克大撤退, 作用, 为英、法两国保留了实力
# Q:  敦刻尔克撤退后,英、法两国保留了什么?
# Answer:  实力
#
#
# Q:  哪支军队在战败后保留了实力?
# Answer:  英、法
#
#
# Q:  哪个国家在战后撤退了?
# { }
# Q:  英、法、英、法在战后保留了什么优势?
# Answer:  敦刻尔克大撤退
#
#
# FullText:  硫磺岛战役, 名称, 硫磺岛战役
# Q:  硫磺岛战役的名称是什么?
# Answer:  硫磺岛战役
#
#
# Q:  什么类型的战役是硫磺岛战争的?
# { }
# Q:  硫磺屿战役的简称是什么?
# Answer:  硫磺岛战役
#
#
# FullText:  硫磺岛战役, 地点, 太平洋硫磺岛
# Q:  硫磺岛战役的地点是哪里?
# Answer:  太平洋硫磺岛
#
#
# Q:  什么类型的战役发生在硫磺岛?
# Answer:  硫磺岛战役
#
#
# Q:  硫磺屿战役的名称是什么?
# Answer:  硫磺岛战役
#
#
# FullText:  硫磺岛战役, 时间, 1945年2月19日到3月26日
# Q:  硫磺岛战役是什么时候开始的?
# Answer:  1945
#
#
# Q:  1945年2月19日到3月26日的战役是哪一天?
# Answer:  硫磺岛战役
#
#
# Q:  1945年的硫磺岛战争是什么时候?
# Answer:  1945年2月19日到3月26日
#
#
# FullText:  硫磺岛战役, 参战方, 美国，日本
# Q:  硫磺岛战役的参战方是哪个国家?
# Answer:  美国
#
#
# Q:  美国,日本,哪个国家参加硫磺岛战争?
# Answer:  美国
#
#
# Q:  日本,哪个国家参战?
# Answer:  美国
#
#
# FullText:  硫磺岛战役, 结果, 美国胜利，成功夺占硫磺岛。
# Q:  硫磺岛战役的结果是什么?
# { }
# Q:  美国赢得了什么战役?
# Answer:  硫磺岛战役
#
#
# Q:  谁赢得了硫磺岛大战?
# { }
# FullText:  硫磺岛战役, 参战方兵力, 美军70,000余人，日军23,000余人
# Q:  硫磺岛战役的参战方兵力是多少?
# Answer:  美军70,000余人
#
#
# Q:  在硫磺岛的战役中,有多少人参战?
# Answer:  70,000余人，日军23,000余人
#
#
# Q:  陆地战役的日军有多少?
# Answer:  23,000余人
#
#
# FullText:  硫磺岛战役, 伤亡情况, 美军6,821人阵亡，21,865人受伤
# 日军21,703人阵亡，1083人俘虏
# Q:  硫磺岛战役中有多少伤亡?
# { }
# Q:  有多少人死于硫磺岛?
# Answer:  21,703人阵亡，1083人俘虏
#
#
# Q:  在硫磺岛的战役中,有多少人丧生?
# Answer:  6,821人阵亡，21,865人受伤
# 日军21,703人阵亡，1083人俘虏
#
#
# FullText:  硫磺岛战役, 主要指挥官, 美军：斯普鲁恩斯日军：栗林忠道、西竹一
# Q:  硫磺岛战役的指挥官是谁?
# Answer:  斯普鲁恩斯
#
#
# Q:  谁是斯普鲁恩斯日军的主要指挥官?
# Answer:  栗林忠道
#
#
# Q:  硫磺屿战役的美军是谁?
# Answer:  斯普鲁恩斯
#
#
# FullText:  神圣休战条约, 类别, 古代条约
# Q:  神圣休战条约的另一个名字是什么?
# { }
# Q:  什么条约被认为是神圣的休战的条约?
# Answer:  休战条约
#
#
# Q:  古代条约是什么?
# Answer:  神圣休战条约
#
#
# FullText:  神圣休战条约, 作用, 起到了熄灭战火的保障作用
# Q:  神圣休战条约的作用是什么?
# Answer:  熄灭战火的保障作用
#
#
# Q:  什么条约对休战有帮助?
# Answer:  神圣休战条约
#
#
# Q:  神圣的休战条款是什么?
# Answer:  休战条约
#
#
# FullText:  神圣休战条约, 条约规定时间, 奥林匹克运动会期间
# Q:  神圣休战条约是什么时候签订的?
# { }
# Q:  奥林匹克运动会的休战时间是什么时候?
# Answer:  神圣休战条约, 条约规定时间, 奥林匹克运动会期间
#
#
# Q:  休战的条约规定什么时间?
# Answer:  奥林匹克运动会期间
#
#
# FullText:  乔治五世, 别名, 乔治五世（水手国王）
# Q:  乔治五世的别名是什么?
# Answer:  水手国王
#
#
# Q:  乔治六世别名叫什么?
# Answer:  乔治五世
#
#
# Q:  “水手国王”这个词的由来是什么?
# Answer:  乔治五世
#
#
# FullText:  乔治五世, 国籍, 英国
# Q:  乔治五世的国籍是什么?
# Answer:  英国
#
#
# Q:  乔治六世的国籍是哪里?
# Answer:  英国
#
#
# Q:  英国人是谁?
# Answer:  乔治五世
#
#
# FullText:  乔治五世, 民族, 盎格鲁-撒克逊人
# Q:  乔治五世的民族是什么?
# Answer:  盎格鲁-撒克逊人
#
#
# Q:  乔治六世是哪个国家的人?
# { }
# Q:  谁是乔治四世的民族?
# Answer:  盎格鲁-撒克逊人
#
#
# FullText:  乔治五世, 出生地, 伦敦
# Q:  乔治五世出生地是哪里?
# Answer:  伦敦
#
#
# Q:  乔治六世的出生地是哪个城市?
# Answer:  伦敦
#
#
# Q:  谁是乔治四世的祖先?
# { }
# FullText:  乔治五世, 出生日期, 1865年6月3日
# Q:  乔治五世的出生日期是什么时候?
# Answer:  1865
#
#
# Q:  乔治六世的出生时间是?
# Answer:  1865年6月3日
#
#
# Q:  谁是乔治四世的继承人?
# Answer:  乔治五世
#
#
# FullText:  乔治五世, 逝世日期, 1936年1月20日
# Q:  乔治五世的逝世日期是什么时候?
# Answer:  1936
#
#
# Q:  1936年1月20日乔治六世逝世时间是?
# Answer:  乔治五世, 逝世日期, 1936年1月20日
#
#
# Q:  乔治四世死于哪一天?
# Answer:  1936年1月20日
#
#
# FullText:  乔治五世, 职业, 英国国王
# Q:  乔治五世是哪个国家的国王?
# Answer:  英国
#
#
# Q:  乔治六世的职业是什么?
# Answer:  英国国王
#
#
# Q:  英国国王是谁?
# Answer:  乔治五世
#
#
# FullText:  乔治五世, 信仰, 英国国教
# Q:  乔治五世是哪个国家的国教?
# Answer:  英国
#
#
# Q:  乔治六世的信仰是什么?
# { }
# Q:  英国国教徒叫什么名字?
# Answer:  乔治五世
#
#
# FullText:  乔治五世, 主要成就, 带领英国，参加第一次世界大战
# Q:  乔治五世在第一次世界大战中扮演了什么角色?
# Answer:  英国
#
#
# Q:  乔治六世是在哪一场战争中扮演角色的?
# Answer:  第一次世界大战
#
#
# Q:  英国参加第一次世界大战是哪一年?
# { }
# FullText:  乔治五世, 主要成就, 建立温莎王朝
# Q:  乔治五世创立了哪个王朝?
# Answer:  温莎王朝
#
#
# Q:  乔治六世建立了什么王朝
# Answer:  温莎王朝
#
#
# Q:  谁创立了温莎王朝
# Answer:  乔治五世
#
#
# FullText:  乔治五世, 父亲, 爱德华七世
# Q:  乔治五世的父亲是谁?
# Answer:  爱德华七世
#
#
# Q:  爱德华七世的父亲叫什么名字?
# Answer:  乔治五世
#
#
# Q:  乔治六世的父亲是什么?
# Answer:  爱德华七世
#
#
# FullText:  乔治五世, 外公, 丹麦国王克里斯蒂安九世
# Q:  乔治五世是哪个国家的国王?
# Answer:  丹麦
#
#
# Q:  克里斯蒂安九世是哪国王
# Answer:  丹麦
#
#
# Q:  谁是丹麦国王
# Answer:  乔治五世
#
#
# FullText:  乔治五世, 表兄, 德国皇帝威廉二世
# Q:  乔治五世的表兄是谁?
# Answer:  威廉二世
#
#
# Q:  威廉二世是哪个国家的皇帝?
# Answer:  德国
#
#
# Q:  德国皇帝是谁?
# Answer:  威廉二世
#
#
# FullText:  乔治五世, 表弟, 俄罗斯皇帝尼古拉二世
# Q:  乔治五世的表弟是谁?
# Answer:  尼古拉二世
#
#
# Q:  俄罗斯皇帝尼古拉二世是哪个国家的皇帝?
# Answer:  俄罗斯
#
#
# Q:  乔治六世是哪个国家皇帝的表弟?
# Answer:  俄罗斯
#
#
# FullText:  日本海, 面积, 97.8万平方公里
# Q:  日本海面积
# Answer:  97.8万平方公里
#
#
# Q:  日本海面积?
# Answer:  97.8万平方公里
#
#
# Q:  日本海的面积
# Answer:  97.8万平方公里
#
#
# FullText:  日本海, 平均水深, 1752米
# Q:  日本海的平均水深是多少?
# Answer:  1752米
#
#
# Q:  日本海有多少米水深?
# Answer:  1752米
#
#
# Q:  有多少米的日本海?
# Answer:  1752米
#
#
# FullText:  日本海, 最大水深, 3742米
# Q:  日本海的最大水深是多少?
# Answer:  3742米
#
#
# Q:  日本海最高水深多少米
# Answer:  3742米
#
#
# Q:  日本海的最高水深是多少米
# Answer:  3742米
#
#
# FullText:  日本海, 特殊地位, 西北太平洋最大陆缘海
# Q:  日本海位于哪里?
# Answer:  太平洋
#
#
# Q:  日本海位于哪个大陆?
# Answer:  太平洋
#
#
# Q:  西北太平洋最大陆的海是什么?
# Answer:  日本海
#
#
# FullText:  日本海, 又名, 鲸海（古称）朝鲜东海(韩国称）
# Q:  日本海又名什么?
# Answer:  鲸海
#
#
# Q:  日本海又叫什么?
# Answer:  鲸海
#
#
# Q:  朝鲜东海又叫做什么?
# Answer:  日本海
#
#
# FullText:  日本海, 沿岸国, 日本，俄罗斯，南北朝鲜
# Q:  日本海的边界是什么?
# { }
# Q:  日本海的哪个边界是日本海的沿岸国?
# Answer:  俄罗斯，南北朝鲜
#
#
# Q:  哪个国家在日本海边境?
# Answer:  俄罗斯，南北朝鲜
#
#
# FullText:  西班牙长枪党, 别名, 长枪会党
# Q:  长枪会党的别名是什么?
# Answer:  西班牙长枪党
#
#
# Q:  西班牙长枪党叫什么名字?
# Answer:  长枪会党
#
#
# Q:  长枪党是哪个政党?
# Answer:  西班牙
#
#
# FullText:  西班牙长枪党, 创立者, 何塞·安东尼奥·普里莫·德里维拉
# Q:  谁是西班牙长枪党的创立者?
# Answer:  德里维拉
#
#
# Q:  西班牙长枪党的创立者是谁?
# Answer:  德里维拉
#
#
# Q:  哪支军队是西班牙长的枪党?
# { }
# FullText:  西班牙长枪党, 创立时间, 1933年10月
# Q:  西班牙长枪党是什么时候创立的?
# Answer:  1933
#
#
# Q:  西班牙长的枪党是哪一年成立的?
# Answer:  1933
#
#
# Q:  1933年10月,西班牙长枪党的创立时间是什么时候?
# Answer:  西班牙长枪党, 创立时间, 1933年10月
#
#
# FullText:  西班牙长枪党, 领袖, 弗朗西斯科·佛朗哥
# Q:  西班牙长枪党的领袖是谁?
# Answer:  佛朗哥
#
#
# Q:  弗朗西斯科·佛朗哥的领袖是什么?
# Answer:  西班牙长枪党
#
#
# Q:  西班牙的长枪党是哪个党派的领袖?
# Answer:  佛朗哥
#
#
# FullText:  波兰战役, 名称, 波兰战役
# Q:  波兰战役的名称是什么?
# Answer:  波兰战役
#
#
# Q:  波兰战争的名称是什么
# Answer:  波兰战役
#
#
# Q:  战役名称是什么
# Answer:  波兰战役
#
#
# FullText:  波兰战役, 地点, 波兰西部
# Q:  波兰战役在哪里?
# Answer:  波兰西部
#
#
# Q:  波兰战争的地点是哪里?
# Answer:  波兰
#
#
# Q:  战役在波兰的哪个地区?
# Answer:  西部
#
#
# FullText:  波兰战役, 时间, 1939年9月1日至10月6日
# Q:  波兰战役是什么时候?
# Answer:  1939年
#
#
# Q:  波兰战争是什么时候开始的?
# Answer:  1939
#
#
# Q:  1939年9月1日至10月6日的战役是哪一天?
# Answer:  波兰战役
#
#
# FullText:  波兰战役, 参战方, 德国、斯洛伐克、苏联，波兰
# Q:  波兰战役的参战方是谁?
# Answer:  德国
#
#
# Q:  德国、斯洛伐克、苏联,还有哪个国家参战?
# Answer:  波兰
#
#
# Q:  波兰战争的参战者是谁?
# Answer:  德国
#
#
# FullText:  波兰战役, 结果, 德国、苏联完全胜利，二战爆发
# Q:  波兰战役是什么时候开始的?
# { }
# Q:  德国、苏联和哪个国家赢了?
# Answer:  德国、苏联
#
#
# Q:  波兰战争是哪一场?
# Answer:  波兰战役
#
#
# FullText:  波兰战役, 参战方兵力, 德国约151万人
# 波兰约100万人
# 苏联466,516–800,000人
# Q:  波兰战役的参战方是谁?
# Answer:  德国
#
#
# Q:  德国有多少人参战?
# Answer:  151万人
#
#
# Q:  谁参战了?
# Answer:  苏联
#
#
# FullText:  波兰战役, 伤亡情况, 德军伤亡3.8万人
# 波军伤亡24.4万人
# 斯洛伐克军队伤亡0.1万人
# 苏军3000-5000阵亡或失踪 8000-10000人受伤
# Q:  波兰战役有多少伤亡?
# Answer:  24.4万人
#
#
# Q:  斯洛伐克军队的伤亡是多少?
# Answer:  0.1万人
#
#
# Q:  谁伤亡了?
# Answer:  苏军
#
#
# FullText:  波兰战役, 主要指挥官, 德国：古德里安，博克，伦德施泰特波兰：希米格维，艾尔豪森
# Q:  谁是波兰战役的指挥官?
# Answer:  希米格维，艾尔豪森
#
#
# Q:  谁是德国战役的首领?
# Answer:  古德里安
#
#
# Q:  希米格和艾尔豪森是哪个国家的战役?
# Answer:  波兰
#
#
# FullText:  波兰战役, 领土变更, 波兰的领土主要被德国、苏联瓜分
# Q:  波兰战役是什么时候发生的?
# { }
# Q:  波兰的领土被哪个国家取代了?
# Answer:  苏联
#
#
# Q:  德国、苏联瓜干的领土是哪个国家的?
# Answer:  波兰
#
#
# FullText:  波兰战役, 特点, 实践了闪击战术
# Q:  波兰战役的特点是什么?
# Answer:  闪击战术
#
#
# Q:  闪击战术实践了什么战术?
# Answer:  波兰战役
#
#
# Q:  波兰战争的另一个术语是什么?
# Answer:  闪击战术
#
#
# FullText:  波兰战役, 目的, 为将来进攻苏联寻找一块跳板
# Q:  波兰战役的目的是什么?
# Answer:  为将来进攻苏联寻找一块跳板
#
#
# Q:  苏联想找什么?
# Answer:  跳板
#
#
# Q:  波兰战争的目的是什么?
# Answer:  为将来进攻苏联寻找一块跳板
#
#
# FullText:  西里西亚, 波兰文, Śląsk
# Q:  西里西亚位于哪里?
# { }
# Q:  波兰文位于哪个城市?
# { }
# Q:  西里的西亚在哪里?
# { }
# Q:  哪个城市位于西里西亚?
# { }
# FullText:  西里西亚, 德文, Schlesien
# Q:  西里西亚的德文语是什么?
# { }
# Q:  德文语的德文词是什么?
# { }
# Q:  Schlesien的德文语言是什么?
# { }
# FullText:  西里西亚, 捷克文, Slezsko
# Q:  西里西亚位于哪个城市?
# { }
# Q:  哪个城市是西里西亚的一部分?
# { }
# Q:  除了捷克文,西里西亚还有什么名字?
# { }
# FullText:  西里西亚, 英语, silesia
# Q:  西里西亚语的词是什么?
# Answer:  silesia
#
#
# Q:  英语在西里西亚是什么意思?
# { }
# Q:  什么语言可以用来形容西里西亚的语言?
# { }
# FullText:  路易·达盖尔, 国籍, 法国
# Q:  路易·达盖尔的国籍是什么?
# Answer:  法国
#
#
# Q:  路易达盖尔国籍是哪个国家的
# Answer:  法国
#
#
# FullText:  路易·达盖尔, 出生地, 法国北方的科梅伊镇
# Q:  路易·达盖尔的出生地是哪里?
# Answer:  法国
#
#
# Q:  路易达盖尔在法国的哪个地区?
# Answer:  科梅伊镇
#
#
# Q:  法国的哪个城市是路易•达盖尔出生地的?
# Answer:  科梅伊
#
#
# FullText:  路易·达盖尔, 出生日期, 1787年
# Q:  路易·达盖尔的出生日期是什么时候?
# Answer:  1787年
#
#
# Q:  路易达盖尔出生在哪个城市?
# { }
# Q:  达盖尔是哪一年出生的?
# Answer:  1787年
#
#
# FullText:  路易·达盖尔, 逝世日期, 1851年
# Q:  路易·达盖尔的逝世日期是什么时候?
# Answer:  1851年
#
#
# Q:  路易达盖尔死于哪一年?
# Answer:  1851
#
#
# Q:  达盖尔是在哪一年去世的?
# Answer:  1851
#
#
# FullText:  路易·达盖尔, 职业, 发明家
# Q:  路易·达盖尔的职业是什么?
# Answer:  发明家
#
#
# Q:  路易达盖尔发明家是哪种职业?
# Answer:  发明家
#
#
# Q:  谁发明了路易•达盖尔?
# { }
# FullText:  路易·达盖尔, 职业, 艺术家
# Q:  路易·达盖尔的职业是什么?
# Answer:  艺术家
#
#
# Q:  路易达盖尔是哪个职业的艺术家?
# Answer:  艺术家
#
#
# Q:  谁是路易达加尔的职业?
# Answer:  艺术家
#
#
# FullText:  路易·达盖尔, 职业, 化学家
# Q:  路易·达盖尔的职业是什么?
# Answer:  化学家
#
#
# Q:  路易达盖尔是什么职业?
# Answer:  化学家
#
#
# Q:  哪位化学家是路易•达盖尔?
# Answer:  路易·达盖尔
#
#
# FullText:  路易·达盖尔, 职业, 画家
# Q:  路易·达盖尔的职业是什么?
# Answer:  画家
#
#
# Q:  路易达盖尔是哪个职业的?
# Answer:  画家
#
#
# Q:  谁是路易•达盖尔?
# Answer:  路易·达盖尔
#
#
# FullText:  路易·达盖尔, 主要成就, 发明摄影术和造相机
# Q:  路易·达盖尔的主要成就是什么?
# Answer:  发明摄影术和造相机
#
#
# Q:  路易达盖尔发明了什么技术?
# Answer:  摄影术
#
#
# Q:  谁发明了摄影术?
# Answer:  路易·达盖尔
#
#
# FullText:  伊莎贝拉一世, 别名, Isabel I la Católica
# Q:  伊莎贝拉一世的别名是什么?
# { }
# Q:  谁是伊莎贝拉的别名?
# { }
# Q:  伊莎贝尔一世的绰号是什么?
# { }
# FullText:  伊莎贝拉一世, 国籍, 西班牙
# Q:  伊莎贝拉一世的国籍是什么?
# Answer:  西班牙
#
#
# Q:  伊莎比亚拉一世国籍是哪个国家?
# Answer:  西班牙
#
#
# Q:  西班牙人是谁?
# Answer:  伊莎贝拉一世
#
#
# FullText:  伊莎贝拉一世, 民族, 卡斯蒂利亚人
# Q:  伊莎贝拉一世是哪个国家的人?
# { }
# Q:  卡斯蒂利亚人叫什么名字?
# Answer:  伊莎贝拉一世
#
#
# Q:  伊莎贝尔一世的国籍是什么?
# { }
# FullText:  伊莎贝拉一世, 出生地, 牧歌镇
# Q:  伊莎贝拉一世的出生地是哪里?
# Answer:  牧歌镇
#
#
# Q:  谁是伊莎贝拉的出生地?
# Answer:  牧歌镇
#
#
# Q:  伊莎贝尔一世是哪里人?
# Answer:  牧歌镇
#
#
# FullText:  伊莎贝拉一世, 出生日期, 1451年4月22日
# Q:  伊莎贝拉一世的出生日期是什么时候?
# Answer:  1451年4月22日
#
#
# Q:  谁是伊莎贝拉的一世?
# Answer:  伊莎贝拉一世
#
#
# Q:  伊莎贝尔一世是什么时候出生的?
# Answer:  1451
#
#
# FullText:  伊莎贝拉一世, 逝世日期, 1504年11月26日
# Q:  伊莎贝拉一世的逝世日期是什么时候?
# Answer:  1504年11月26日
#
#
# Q:  谁是伊莎贝拉的一世?
# Answer:  伊莎贝拉一世
#
#
# Q:  伊莎贝尔一世是什么时候逝世的?
# Answer:  1504
#
#
# FullText:  伊莎贝拉一世, 职业, 卡斯蒂利亚女王
# Q:  伊莎贝拉一世的职业是什么?
# Answer:  卡斯蒂利亚女王
#
#
# Q:  伊莎贝尔一世是哪个国家的女王?
# Answer:  卡斯蒂利亚
#
#
# Q:  卡斯蒂利亚女王是哪一年成为伊莎贝拉的?
# { }
# FullText:  伊莎贝拉一世, 信仰, 天主教
# Q:  伊莎贝拉一世的信仰是什么?
# Answer:  天主教
#
#
# Q:  伊莎贝尔一世信仰什么宗教?
# Answer:  天主教
#
#
# Q:  谁是伊莎贝拉的一世?
# Answer:  伊莎贝拉一世
#
#
# FullText:  伊莎贝拉一世, 主要成就, 统一西班牙
# Q:  伊莎贝拉一世的成就是什么?
# Answer:  统一西班牙
#
#
# Q:  伊莎贝尔一世是哪个国家的人?
# Answer:  西班牙
#
#
# Q:  谁是伊莎贝拉的一世?
# Answer:  伊莎贝拉一世
#
#
# FullText:  伊莎贝拉一世, 主要成就, 资助哥伦布航行
# Q:  伊莎贝拉一世资助了哪个航行?
# Answer:  哥伦布
#
#
# Q:  谁资助哥伦布船行?
# Answer:  伊莎贝拉
#
#
# Q:  伊莎贝尔一世的成就是什么?
# Answer:  资助哥伦布航行
#
#
# FullText:  伊莎贝拉一世, 主要成就, 设立宗教裁判所
# Q:  伊莎贝拉一世的成就是什么?
# Answer:  设立宗教裁判所
#
#
# Q:  伊莎贝尔一世是在哪一年成立宗教法院的?
# { }
# Q:  宗教法院是什么时候成立的?
# { }
# FullText:  安东尼·万·雷汶胡克, 出生地, 荷兰台夫特镇
# Q:  安东尼·万·雷汶胡克的出生地是哪里?
# Answer:  荷兰
#
#
# Q:  荷兰台夫特镇的名称是什么?
# { }
# Q:  谁是荷兰的荷兰台夫人特镇的出生地?
# Answer:  安东尼
#
#
# FullText:  安东尼·万·雷汶胡克, 出生日期, 公元1632
# Q:  安东尼·万·雷汶胡克的出生日期是什么时候?
# Answer:  1632
#
#
# Q:  谁出生在公元1632年?
# Answer:  安东尼
#
#
# Q:  什么人出生在安东尼?
# { }
# FullText:  安东尼·万·雷汶胡克, 逝世日期, 公元1723
# Q:  安东尼·万·雷汶胡克的逝世日期是什么时候?
# Answer:  1723
#
#
# Q:  谁死于1723年?
# Answer:  安东尼·万·雷汶胡克
#
#
# Q:  安西尼·万里汶胡克死于哪一年?
# Answer:  1723
#
#
# FullText:  日本文学, 作品名称, 日本文学
# Q:  日本文学作品名称
# Answer:  日本文学
#
#
# Q:  日本文学作品名字
# Answer:  日本文学
#
#
# Q:  日本文学的作品名称
# Answer:  日本文学
#
#
# FullText:  日本文学, 含义, 日本语写作的文学作品
# Q:  日本文学是什么意思?
# Answer:  文学作品
#
#
# Q:  日本文学的含义是什么?
# Answer:  日本语写作的文学作品
#
#
# Q:  日本语写作的文学作品是什么?
# Answer:  日本文学
#
#
# FullText:  日本文学, 所属地区, 日本
# Q:  日本文学的所属地区是哪里?
# Answer:  日本
#
#
# Q:  日本文学的名称是什么?
# { }
# Q:  除了日本文学,日本文学的另一个名字是什么?
# { }
# FullText:  日本文学, 举例, 日本艺术与文学的黄金时期
# Q:  日本艺术与文学的黄金时期是什么?
# Answer:  日本文学
#
#
# Q:  日本艺术和文学的黄金时代是什么时候?
# { }
# Q:  日本文学和文学黄金时期是什么类型的艺术?
# Answer:  文学
#
#
# FullText:  塔克西拉, 所属地区, 巴基斯坦
# Q:  塔克西拉位于哪个国家?
# Answer:  巴基斯坦
#
#
# Q:  塔卡西拉在巴基斯坦的哪个地区?
# { }
# Q:  巴基斯坦哪个地区是巴基斯坦的一个地区?
# Answer:  塔克西拉
#
#
# FullText:  塔克西拉, 人口, 20万（1981）
# Q:  塔克西拉是在哪一年去世的?
# Answer:  1981
#
#
# Q:  谁是1981年总统的?
# { }
# Q:  1981年总统的百分比是多少?
# { }
# FullText:  资生堂, 所属行业, 化妆品
# Q:  资生堂化妆品哪个品牌
# Answer:  资生堂
#
#
# Q:  化妆品哪个牌子好
# Answer:  资生堂
#
#
# Q:  资生的堂化妆品那个品牌好
# Answer:  资生堂
#
#
# FullText:  资生堂, 国家, 日本
# Q:  资生堂资生堂哪个国家
# Answer:  日本
#
#
# Q:  日本资生堂的哪个国家
# { }
# Q:  韩国资生堂是哪个国家
# Answer:  日本
#
#
# Q:  香港资生堂是什么国家
# Answer:  日本
#
#
# FullText:  资生堂, 官网, http://www.shiseido.com/
# Q:  资生堂哪个网站好
# Answer:  http://www.shiseido.com/
#
#
# Q:  资生的堂那个网站好
# Answer:  资生堂
#
#
# Q:  新生堂什么网站好
# Answer:  资生堂
#
#
# FullText:  救生圈, 类别, 水上救生设备的一种
# Q:  救生圈的另一个名字是什么?
# { }
# Q:  什么类型的救生设备被称为救生圈?
# Answer:  水上救生设备
#
#
# Q:  水上救生设备的另一个术语是什么?
# Answer:  救生圈
#
#
# FullText:  救生圈, 原料, 软木、泡沫塑料
# Q:  救生圈是用什么材料做的?
# Answer:  软木
#
#
# Q:  什么材料是救生圈的原料?
# Answer:  软木
#
#
# Q:  救生的圈是什么材料?
# Answer:  软木、泡沫塑料
#
#
# FullText:  救生圈, 别称, 橡皮圈
# Q:  救生圈的另一个名字是什么?
# { }
# Q:  橡皮圈叫什么?
# Answer:  救生圈
#
#
# Q:  什么圈叫救生圈?
# Answer:  橡皮圈
#
#
# FullText:  美年达, 公司, 百事公司
# Q:  美年达的百事公司
# Answer:  百事公司
#
#
# Q:  百事达百事公司的名称
# Answer:  美年达
#
#
# Q:  美年达到百事公司名称
# Answer:  百事公司
#
#
# Q:  美的年达百事公司名字?
# Answer:  美年达
#
#
# FullText:  美年达, 类型, 果味碳酸饮料
# Q:  美年达的果汁是什么?
# Answer:  碳酸饮料
#
#
# Q:  什么类型的饮料有碳酸饮料?
# Answer:  美年达
#
#
# Q:  果味碳酸饮料的果味是什么?
# Answer:  美年达
#
#
# FullText:  美年达, 口味, 橙子，苹果，黑加仑子，柚子等
# Q:  美年达的口味是什么?
# { }
# Q:  什么水果是美年达水果的口味?
# Answer:  橙子
#
#
# Q:  水果是什么颜色的?
# { }
# FullText:  美年达, 配料, 碳酸水，白砂糖，柠檬酸等等
# Q:  美年达配料的配料是什么?
# Answer:  碳酸水，白砂糖
#
#
# Q:  什么类型的酒精是美年达的配料?
# Answer:  碳酸水
#
#
# Q:  哪个水果含有美年达?
# Answer:  柠檬
#
#
# FullText:  盐灯, 材料, 水晶盐矿石
# Q:  盐灯是用什么材料做的
# Answer:  盐矿石
#
#
# Q:  盐灯用什么材料
# Answer:  盐矿石
#
#
# Q:  什么材料是盐灯用的
# Answer:  盐矿石
#
#
# Q:  什么金属是盐灯的
# Answer:  盐矿石
#
#
# FullText:  材质, 名词解释, 物体看起来是什么质地
# Q:  质地是什么意思
# Answer:  材质
#
#
# Q:  质地是什么
# Answer:  材质
#
#
# Q:  质地的另一个词
# Answer:  材质
#
#
# Q:  质的另一个词
# Answer:  材质
#
#
# FullText:  材质, 实质, 材料和质感的结合
# Q:  质感和质感的结合是什么?
# Answer:  材质
#
#
# Q:  材料和质感结合了什么?
# Answer:  实质
#
#
# Q:  什么类型的材料与质感结合?
# Answer:  材质
#
#
# FullText:  材质, 应用领域, 建筑制造等
# Q:  建筑用什么材料
# { }
# Q:  建筑用啥材料
# Answer:  材质
#
#
# Q:  建设用什么材料?
# { }
# Q:  建筑用的什么材料
# { }
# FullText:  材质, 材质体现, 光
# Q:  颜色
# { }
# Q:  颜色?
# { }
# Q:  颜色
# { }
# FullText:  冰酒, 产地, 加拿大、德国、法国、中国等
# Q:  冰酒产地是哪里?
# Answer:  加拿大
#
#
# Q:  冰酒的产地是哪个国家?
# Answer:  加拿大
#
#
# Q:  哪个国家有冰酒生产商?
# Answer:  加拿大
#
#
# FullText:  杨林肥酒, 主要原料, 小茴香，豌豆
# Q:  杨林肥酒的原料是什么?
# Answer:  豌豆
#
#
# Q:  杨林瘦酒的原料有哪些?
# { }
# Q:  什么香烟酒的原料是杨林肥的?
# Answer:  杨林肥酒
#
#
# FullText:  杨林肥酒, 是否含防腐剂, 否
# Q:  杨林肥酒含啥物质
# Answer:  防腐剂
#
#
# Q:  杨林瘦酒含什么物质
# Answer:  防腐剂
#
#
# Q:  扬林肥酒含有什么物质
# Answer:  防腐剂
#
#
# FullText:  杨林肥酒, 主要营养成分, 葡萄糖，维生素
# Q:  杨林肥酒的主要成分是什么?
# Answer:  葡萄糖
#
#
# Q:  杨林瘦酒的成分有哪些?
# { }
# Q:  在杨林肥中,有什么营养成分?
# { }
# FullText:  杨林肥酒, 主要食用功效, 健胃润肺，补中益气
# Q:  杨林肥酒吃啥药
# Answer:  健胃润肺，补中益气
#
#
# Q:  杨林瘦酒吃什么药
# Answer:  健胃润肺，补中益气
#
#
# Q:  扬林肥酒喝什么药
# Answer:  健胃润肺，补中益气
#
#
# FullText:  杨林肥酒, 适宜人群, 体质虚弱者，中老年人
# Q:  杨林肥酒的适合人群
# Answer:  中老年人
#
#
# Q:  杨林的肥酒适合人群
# Answer:  中老年人
#
#
# FullText:  杨林肥酒, 副作用, 暂无
# Q:  杨林肥酒吃啥药
# { }
# Q:  杨林的肥酒吃什么药
# Answer:  肥酒
#
#
# Q:  张林肥酒喝什么药
# Answer:  杨林肥酒, 副作用
#
#
# FullText:  杨林肥酒, 储藏方法, 常温避光储存
# Q:  杨林肥酒储存时间
# Answer:  常温避光
#
#
# Q:  杨林的肥酒储藏时间
# Answer:  常温避光
#
#
# Q:  桉树肥酒储存在时间
# Answer:  温避光
#
#
# FullText:  宜良烤鸭, 主要原料, 烧鸭
# Q:  宜良烤鸭的原料是什么?
# Answer:  烧鸭
#
#
# Q:  宜良烧鸭的食用价值是多少
# { }
# Q:  宜良的烧鸭是什么?
# Answer:  烤鸭
#
#
# FullText:  宜良烤鸭, 是否含防腐剂, 否
# Q:  烤鸭啥牌子好
# Answer:  宜良烤鸭
#
#
# Q:  烤鸭什么牌子的好
# Answer:  宜良烤鸭
#
#
# Q:  烧鸭什么牌子好?
# Answer:  宜良烤鸭
#
#
# Q:  烧鸡什么牌子好的
# Answer:  宜良烤鸭
#
#
# FullText:  宜良烤鸭, 口味, 肥瘦相宜，皮酥脆，内香嫩
# Q:  烤鸭啥时候吃好
# { }
# Q:  烤鸭什么时候吃最好
# { }
# Q:  吃鸭哪个时候吃比较好
# { }
# FullText:  皮鞋, 材料, 天然皮革、橡胶、塑料等
# Q:  皮鞋的材料是什么?
# Answer:  天然皮革
#
#
# Q:  皮鞋是什么材料的例子?
# Answer:  皮革
#
#
# Q:  什么材料是皮鞋的原材料?
# Answer:  天然皮革
#
#
# FullText:  皮鞋, 性能, 卫生、透气、吸湿
# Q:  皮鞋哪个牌子好
# { }
# Q:  皮鞋哪个好
# { }
# Q:  皮皮鞋哪个品牌好
# { }
# FullText:  钟水饺, 主要食材, 面粉，猪肉
# Q:  钟水饺的馅料是什么?
# Answer:  猪肉
#
#
# Q:  钟水餃的馅料是啥馅料?
# Answer:  猪肉
#
#
# Q:  什么馅料是钟水饺馅料的?
# Answer:  猪肉
#
#
# FullText:  钟水饺, 分类, 川菜，小吃
# Q:  钟水饺啥地方好
# { }
# Q:  钟水餃什么地方好
# Answer:  钟水饺
#
#
# Q:  新钟水饺哪个地方好
# { }
# Q:  2017钟水饺哪些地方好
# { }
# FullText:  钟水饺, 口味, 微甜带咸
# Q:  钟水饺的口味
# Answer:  微甜带咸
#
#
# Q:  钟水餃的口味?
# Answer:  微甜带咸
#
#
# Q:  钟火锅的口味是
# Answer:  微甜带咸
#
#
# Q:  钟的水饺口味
# Answer:  微甜带咸
#
#
# FullText:  抓炒里脊, 菜品, “仿膳”
# Q:  抓炒里脊的菜品
# { }
# Q:  抓炒里的脊肉的菜品?
# { }
# Q:  吃炒里脊是啥菜品
# { }
# FullText:  抓炒里脊, 属性, 名菜
# Q:  抓炒里脊的名称
# { }
# Q:  抓炒里的脊名字
# Answer:  里脊
#
#
# Q:  拿炒里脊是什么名字
# Answer:  抓炒里脊
#
#
# Q:  吃炒里脊名字?
# Answer:  抓炒里脊
#
#
# FullText:  抓炒里脊, 出处, 慈禧下人
# Q:  慈禧下人吃啥东西
# Answer:  抓炒里脊
#
#
# Q:  慈禧上人吃什么东西?
# Answer:  抓炒里脊
#
#
# Q:  什么东西吃什么东西
# { }
# FullText:  抓炒里脊, 材料, 猪里脊肉，花生油，醋，白糖等
# Q:  里脊肉什么材料好
# Answer:  抓炒里脊, 材料, 猪里脊肉
#
#
# Q:  里脊的肉什么材料最好
# Answer:  猪里脊肉
#
#
# Q:  里的脊肉啥材料好
# Answer:  猪里脊肉
#
#
# FullText:  抓炒里脊, 制作技艺, 3步
# Q:  抓炒里脊制作技艺
# Answer:  3步
#
#
# Q:  抓炒里的脊制作技术
# Answer:  3步
#
#
# Q:  做炒里脊做技艺
# Answer:  抓炒里脊, 制作技艺, 3步
#
#
# FullText:  长生天, 蒙语读音, 腾格里
# Q:  长生天读音的书
# Answer:  腾格里
#
#
# Q:  长生天的读音是什么
# Answer:  腾格里
#
#
# Q:  长生的天读音是啥
# Answer:  腾格里
#
#
# FullText:  长生天, 性质, 民族信仰
# Q:  长生天,长生天是什么?
# { }
# Q:  长生天的性质是什么?
# Answer:  民族信仰
#
#
# Q:  “长生天”这个词是什么?
# { }
# FullText:  长生天, 民族, 蒙古民族
# Q:  长生天,民族,民族, 民族,民族
# { }
# Q:  蒙古民族,民族?
# Answer:  蒙古民族
#
#
# Q:  民族的民族
# Answer:  蒙古民族
#
#
# FullText:  长生天, 意义, 天神
# Q:  长生天是什么意思?
# Answer:  天神
#
#
# Q:  长生天的意义
# Answer:  天神
#
#
# Q:  长生的天是什么?
# { }
# Q:  什么天是长生天?
# { }
# FullText:  对夹, 主要食材, 酥饼，熏肉
# Q:  对夹是什么类型的饼干?
# Answer:  酥饼
#
#
# Q:  对夹的另一个名字是什么?
# { }
# Q:  在对夹中使用什么类型的酥饼?
# Answer:  熏肉
#
#
# FullText:  对夹, 工艺, 烤
# Q:  什么类型的对夹?
# { }
# Q:  烤箱的另一个词是什么?
# Answer:  对夹
#
#
# Q:  什么东西是用来做烤箱的?
# { }
# FullText:  对夹, 功效, 具有理气、养脾
# Q:  对夹的功效
# Answer:  理气、养脾
#
#
# Q:  对夹有什么功效
# Answer:  理气、养脾
#
#
# Q:  对于夹的功效?
# Answer:  理气、养脾
#
#
# Q:  对拿的功效
# Answer:  理气、养脾
#
#
# FullText:  张小泉剪刀, 创始人, 张小泉
# Q:  张小泉剪刀的创始人是谁?
# Answer:  张小泉
#
#
# Q:  张大泉剪刀创始人是谁
# Answer:  张小泉
#
#
# FullText:  张小泉剪刀, 类型, 传统手工艺品
# Q:  张小泉剪刀是什么类型的剪刀?
# Answer:  传统手工艺品
#
#
# Q:  张大泉剪刀的类型是什么?
# Answer:  传统手工艺品
#
#
# Q:  小泉的剪刀叫什么名字?
# Answer:  剪刀
#
#
# FullText:  张小泉剪刀, 特点, 磨工精细，刀口锋利，开闭自如
# Q:  张小泉剪刀的磨工精细
# Answer:  刀口锋利
#
#
# Q:  张大泉剪刀什么好
# { }
# Q:  张的小泉剪刀哪个好
# Answer:  张小泉
#
#
# Q:  小泉的剪刀那个好
# Answer:  张小泉剪刀
#
#
# FullText:  化妆水, 别名, 爽肤水
# Q:  化妆水哪个牌子好
# { }
# Q:  化妆水那个牌子好啊
# { }
# Q:  化妆水中哪个牌子好的
# { }
# Q:  化妆的水什么牌子好?
# { }
# Q:  什么牌子好的化妆水好
# { }
# FullText:  化妆水, 别名, 柔肤水
# Q:  化妆水的另一个名字是什么?
# Answer:  柔肤水
#
#
# Q:  化妆水是什么类型的水?
# Answer:  柔肤水
#
#
# Q:  美白水的另一个词是什么?
# Answer:  柔肤水
#
#
# FullText:  化妆水, 别名, 收敛水
# Q:  化妆水的别名是什么?
# Answer:  收敛水
#
#
# Q:  化妆水是什么类型的水?
# Answer:  收敛水
#
#
# Q:  收敛水是什么类型的水?
# Answer:  化妆水
#
#
# FullText:  化妆水, 功效, 用来清洁肌肤、保持肌肤的健康
# Q:  用什么来清洁肌肤?
# Answer:  化妆水
#
#
# Q:  化妆水的功效是什么?
# Answer:  清洁肌肤
#
#
# Q:  使用化妆水的用途是什么?
# Answer:  清洁肌肤
#
#
# FullText:  化妆水, 成分, 成分为水
# Q:  化妆水的成分是什么?
# { }
# Q:  化妆水成分是什么
# { }
# Q:  化妆水中的成分是什么
# { }
# FullText:  性格, 学科, 心理学
# Q:  心理学, 性格, 性格
# { }
# Q:  性格的
# Answer:  心理学
#
#
# Q:  性格是啥
# Answer:  心理学
#
#
# Q:  性格是什么
# { }
# FullText:  玻璃杯, 结构分类, 双层玻璃杯和单层玻璃杯
# Q:  玻璃杯的结构分类是什么?
# Answer:  双层玻璃杯
#
#
# Q:  单层玻璃杯是什么类型的玻璃杯?
# Answer:  双层玻璃杯
#
#
# Q:  双层玻璃杯是用什么做的?
# Answer:  玻璃
#
#
# FullText:  玻璃杯, 原材料, 高硼硅玻璃
# Q:  玻璃杯是什么类型的杯子
# Answer:  硅玻璃
#
#
# Q:  玻璃杯是哪种玻璃杯
# Answer:  硼硅玻璃
#
#
# Q:  什么玻璃杯是玻璃杯的
# Answer:  硼硅
#
#
# Q:  是什么玻璃杯?
# Answer:  硼硅玻璃
#
#
# FullText:  玻璃杯, 分类, 家用、公用
# Q:  玻璃杯 玻璃杯哪个好
# Answer:  玻璃杯
#
#
# Q:  玻璃杯哪个牌子好
# { }
# Q:  什么牌子玻璃杯好
# { }
# FullText:  领结, 作用, 使正式或时尚
# Q:  什么类型的领结可以用作领结?
# { }
# Q:  什么样的领结可以用来做领结的?
# { }
# Q:  什么形状的领结会使领结成为流行的?
# { }
# FullText:  领结, 祖师, 穿西服时系在衬衫领子前的横结
# Q:  领结在衬衫上穿什么颜色?
# { }
# Q:  领结穿什么颜色的衬衫?
# { }
# Q:  袖子在衬衫上的横结是什么颜色的?
# { }
# FullText:  鞋拔子, 别名, 鞋拔
# Q:  鞋拔子叫什么名字
# { }
# Q:  鞋拔子的别名
# Answer:  鞋拔子
#
#
# Q:  什么名字鞋拔子
# { }
# Q:  什么字母鞋拔子?
# { }
# FullText:  鞋拔子, 别名, 鞋溜子
# Q:  鞋拔子叫什么?
# Answer:  鞋溜子
#
#
# Q:  鞋拔子的别名是什么?
# Answer:  鞋溜子
#
#
# Q:  什么鞋拔子好
# Answer:  鞋溜子
#
#
# FullText:  鞋拔子, 特点, 卫生、方便
# Q:  鞋拔子啥牌子好
# { }
# Q:  什么牌子鞋拔子最好
# { }
# Q:  什么品牌鞋拔子好
# { }
# FullText:  鞋拔子, 出自, 《乡言解颐·物部上·杂物十事》
# Q:  鞋拔子出自哪部书?
# Answer:  乡言解颐
#
#
# Q:  鞋拔子的出自是哪部小说?
# Answer:  乡言解颐
#
#
# Q:  《鞋拔子》的作者是谁?
# { }
# FullText:  鞋拔子, 形状, 下端弧形，上端有柄
# Q:  鞋拔子上端有什么形状
# Answer:  柄
#
#
# Q:  鞋拔子的上端有啥形状
# Answer:  柄
#
#
# Q:  袜拔子上的什么形状
# Answer:  弧形
#
#
# Q:  什么鞋拔子上有那些形状
# Answer:  弧形
#
#
# FullText:  鞋拔子, 材质, 象牙的、玉的
# Q:  什么类型的鞋拔子
# Answer:  象牙
#
#
# Q:  什么颜色的鞋拔子的
# Answer:  玉的
#
#
# Q:  什么形状的袜拔子
# Answer:  象牙
#
#
# FullText:  事业单位奖金税, 含义, 对事业单位发放的各种形式一种税
# Q:  单位奖金税的含义是什么?
# Answer:  事业单位
#
#
# Q:  事业单位奖金税的定义是什么
# Answer:  事业单位奖金税, 含义, 对事业单位发放的各种形式一种税
#
#
# Q:  单位工资税是什么
# Answer:  事业单位奖金税
#
#
# FullText:  事业单位奖金税, 发布日期, 1994年1月23日
# Q:  1994年1月23日的公务员奖金税
# Answer:  事业单位奖金税, 发布日期, 1994年1月23日
#
#
# Q:  1994年1月份的公务员奖金税率
# Answer:  事业单位奖金税, 发布日期, 1994年1月23日
#
#
# Q:  1994年的公务员奖金税是多少
# Answer:  事业单位奖金税, 发布日期, 1994年1月23日
#
#
# Q:  1994年2月23日公务员奖金税?
# Answer:  事业单位奖金税, 发布日期, 1994年1月23日
#
#
# FullText:  事业单位奖金税, 实施日期, 1994年1月1日
# Q:  事业单位奖金税的实施日期是什么时候?
# Answer:  1994年1月1日
#
#
# Q:  事业单位工资税的实施时间是?
# Answer:  1994年1月1日
#
#
# Q:  1994年1月1日的事业单位奖金税是什么时候开始的?
# Answer:  1994年1月1日
#
#
# FullText:  珍珠翡翠白玉汤, 原材料, 白菜帮子、菠菜叶儿，馊豆腐
# Q:  珍珠翡翠白玉汤是什么汤
# Answer:  白玉汤
#
#
# Q:  珍珠翠翠什么汤
# Answer:  白玉汤
#
#
# Q:  翡翠翡翠什么汤?
# Answer:  白玉汤
#
#
# FullText:  珍珠翡翠白玉汤, 典故, 朱元璋
# Q:  珍珠翡翠白玉汤的典故是什么?
# Answer:  朱元璋
#
#
# Q:  珍珠玉汤的作者是谁?
# { }
# Q:  翡翠玉汤的含义是什么?
# Answer:  朱元璋
#
#
# FullText:  珍珠翡翠白玉汤, 配料, 盐和鸡精
# Q:  珍珠翡翠白玉汤的配料是什么?
# Answer:  盐和鸡精
#
#
# Q:  珍珠翠翡翠的白玉汤是什么类型的汤?
# { }
# Q:  翡翠翡翠什么汤最好
# Answer:  珍珠翡翠白玉汤
#
#
# FullText:  炖排骨, 主要食材, 猪排
# Q:  猪排骨吃什么肉
# Answer:  排骨
#
#
# Q:  猪的排骨吃啥肉
# Answer:  猪排
#
#
# Q:  鸭排骨吃哪个肉
# Answer:  猪排
#
#
# Q:  牛排骨吃哪些肉
# Answer:  猪排
#
#
# FullText:  炖排骨, 分类, 中餐，粤系
# Q:  排骨吃什么好
# Answer:  炖排骨
#
#
# Q:  排骨什么吃好
# Answer:  炖排骨
#
#
# Q:  吃排骨什么好
# Answer:  炖排骨
#
#
# FullText:  炖排骨, 口味, 鲜
# Q:  排骨的口味是什么
# Answer:  鲜
#
#
# Q:  排骨是什么口味?
# Answer:  鲜
#
#
# Q:  吃排骨什么口味
# Answer:  鲜
#
#
# FullText:  炖排骨, 调料, 味精，盐，八角，糖
# Q:  排骨什么调料
# { }
# Q:  排骨啥调料?
# { }
# Q:  吃排骨的调料
# Answer:  味精
#
#
# FullText:  森林浴, 释义, 沐浴森林里的新鲜空气
# Q:  森林浴的词是什么?
# { }
# Q:  森林浴是什么意思?
# Answer:  新鲜空气
#
#
# Q:  在森林浴中,什么类型的空气能让人们呼吸新鲜空气?
# Answer:  森林
#
#
# FullText:  森林浴, 地址, 森林
# Q:  森林浴的地址
# Answer:  森林
#
#
# Q:  森林浴在哪里
# { }
# Q:  林浴的地址?
# Answer:  森林
#
#
# FullText:  森林浴, 特色, 享受自然
# Q:  森林浴哪里最好玩
# { }
# Q:  森林浴那里最好玩
# { }
# Q:  新森林浴在哪里最好玩
# { }
# FullText:  fcuk, 创立时间, 1972年
# Q:  fcuk是什么时候创立的?
# Answer:  1972年
#
#
# Q:  fcuk创立时间是什么时候?
# Answer:  1972年
#
#
# Q:  谁创立了 fcuk?
# { }
# FullText:  fcuk, 创始人, 皮埃尔·达勒和史蒂芬·马克斯
# Q:  皮埃尔·达勒和史蒂芬·马克斯是哪个公司的创始人?
# Answer:  fcuk
#
#
# Q:  fcuk的创始人是谁?
# Answer:  皮埃尔·达勒
#
#
# Q:  谁是fcuk的创始人?
# Answer:  皮埃尔·达勒
#
#
# FullText:  fcuk, 创始人, 妮科尔·法西
# Q:  fcuk的创始人是谁?
# Answer:  妮科尔·法西
#
#
# Q:  fcuk 创始人是谁
# Answer:  妮科尔·法西
#
#
# Q:  fcuk创始人是谁
# Answer:  妮科尔·法西
#
#
# FullText:  fcuk, 所属行业, 服装、香水和化妆品
# Q:  fcuk是什么类型的化妆品?
# Answer:  香水
#
#
# Q:  fcuk属于哪个行业?
# Answer:  化妆品
#
#
# Q:  除了化妆品和化妆品,fcuk还包括什么?
# Answer:  服装
#
#
# FullText:  热得快, 俗名, 电乌龟
# Q:  热得快的俗名是什么?
# Answer:  电乌龟
#
#
# Q:  电乌龟叫什么名字?
# Answer:  热得快
#
#
# Q:  热得很快的俗称是什么?
# Answer:  电乌龟
#
#
# FullText:  热得快, 用途, 烧开水
# Q:  热得快
# Answer:  烧开水
#
#
# Q:  热热快
# Answer:  烧开水
#
#
# Q:  火热快
# { }
# FullText:  热得快, 使用场合, 寝室、出租房
# Q:  热得快的场合叫什么名字?
# Answer:  出租房
#
#
# Q:  什么类型的场合有热得快?
# Answer:  出租房
#
#
# Q:  在热得快的情况下,什么类型的房间可以使用?
# { }
# FullText:  热得快, 类型, 电器，小家电
# Q:  小家电哪个好
# Answer:  热得快
#
#
# Q:  小家电哪个好
# Answer:  热得快
#
#
# Q:  小电器哪个好
# Answer:  热得快
#
#
# FullText:  热得快, 功率, 1500~1800W
# Q:  功率
# { }
# Q:  功率?
# { }
# Q:  功率
# { }
# FullText:  莜面, 别称, 燕麦面
# Q:  莜面叫什么?
# Answer:  燕麦面
#
#
# Q:  莜面的别名是什么?
# Answer:  燕麦面
#
#
# Q:  燕面是什么意思?
# Answer:  莜面
#
#
# FullText:  莜面, 主要原料, 莜麦
# Q:  莜面主要原料是什么?
# Answer:  莜麦
#
#
# Q:  莜面的主要原料是什么
# Answer:  莜麦
#
#
# Q:  莜麦主要原料是什么
# Answer:  莜面, 主要原料, 莜麦
#
#
# FullText:  莜面, 是否含防腐剂, 否
# Q:  莜面含有什么防腐剂
# { }
# Q:  莜面的防腐剂是啥
# { }
# Q:  莜面含有什么防腐剂?
# { }
# Q:  哪些防腐剂含有莜面?
# { }
# FullText:  莜面, 主要营养成分, 钙，磷，铁，核黄素，亚油酸
# Q:  莜面的主要成分是什么?
# Answer:  钙
#
#
# Q:  莜面主要成分是什么
# Answer:  钙
#
#
# Q:  莜面的营养成分是什么
# Answer:  钙
#
#
# FullText:  莜面, 主要食用功效, 治疗和预防糖尿病、冠心病、动脉硬化、高血压
# Q:  莜面吃啥药好
# Answer:  高血压
#
#
# Q:  莜面的吃什么药最好
# Answer:  高血压
#
#
# Q:  莜面喝哪个药最好
# Answer:  高血压
#
#
# FullText:  莜面, 适宜人群, 一般人群
# Q:  莜面适宜人群
# Answer:  一般人群
#
#
# Q:  莜面适合人
# Answer:  一般人群
#
#
# Q:  莜面的适合人群
# Answer:  一般人群
#
#
# FullText:  莜面, 副作用, 食用过量容易导致胃肠道不舒，消化不良。
# Q:  莜面吃过量会导致什么?
# { }
# Q:  吃莜面会导致什么症状?
# { }
# Q:  什么东西吃过量容易导致胃肠道不舒?
# { }
# FullText:  莜面, 储藏方法, 常温
# Q:  莜面储藏在什么温度下
# Answer:  常温
#
#
# Q:  莜面的储藏在哪里?
# Answer:  常温
#
#
# Q:  莜面的储藏在哪个温度下
# Answer:  常温
#
#
# FullText:  莜面, 制作难度, 一般
# Q:  莜面制作什么技能
# { }
# Q:  莜面 制作什么术语
# { }
# Q:  莜面的制作哪个技能
# { }
# FullText:  合并报表, 别称, 合并财务报表或合并会计报表
# Q:  合并报表的另一个术语是什么?
# Answer:  合并财务报表或合并会计报表
#
#
# Q:  合并会计报表叫什么?
# Answer:  合并财务报表
#
#
# Q:  什么类型的报表叫合并财务报表?
# Answer:  合并会计报表
#
#
# FullText:  合并报表, 分类, 合并资产负债表、合并损益表
# Q:  合并报表的分类
# Answer:  资产负债表、合并损益表
#
#
# Q:  合并资产负债表 分类
# Answer:  合并损益表
#
#
# Q:  与合并债务的分类
# Answer:  合并资产负债表、合并损益表
#
#
# FullText:  合并报表, 理论, 母公司理论、实体理论和当代理论
# Q:  合并报表是什么类型的报表?
# Answer:  合并报表, 理论, 母公司理论、实体理论和当代理论
#
#
# Q:  什么类型的理论是合并的?
# Answer:  母公司理论
#
#
# Q:  合并的报表是什么?
# Answer:  合并报表
#
#
# FullText:  潮汕功夫茶, 别称, 潮州功夫茶
# Q:  潮州功夫茶的别名是什么?
# Answer:  潮汕功夫茶
#
#
# Q:  潮州的功夫茶叫什么名字
# Answer:  潮汕功夫茶
#
#
# Q:  潮汕功夫茶的另一个名字是什么?
# Answer:  潮州功夫茶
#
#
# FullText:  潮汕功夫茶, 形成, 明朝中期至清初
# Q:  潮汕茶是什么时候开始的?
# Answer:  明朝
#
#
# Q:  潮汕功夫茶是什么时候出现的?
# Answer:  明朝
#
#
# Q:  关于潮汕茶的起源是什么?
# Answer:  明朝
#
#
# FullText:  潮汕功夫茶, 起源, 唐宋朝代
# Q:  潮汕茶的起源是什么时候?
# Answer:  唐宋
#
#
# Q:  潮汕功夫茶起源于哪个朝代?
# Answer:  唐宋
#
#
# end_time:  1652691254.143255
# use time:  1801.523280620575
