# %% [markdown]
# ## 测试基于mT5的中文语料微调的问题生成预训练模型的效果

# %%
# !pip install transformers
# !pip install question_generation
# !pip install torch

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.10.0.2)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("algolet/mt5-base-chinese-qg")

model = AutoModelForSeq2SeqLM.from_pretrained("algolet/mt5-base-chinese-qg")
# Out:
# Downloading:   0%|          | 0.00/428 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.11M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/7.93M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.17G [00:00<?, ?B/s]

# %%
import torch
model.eval()
text = "在一个寒冷的冬天，赶集完回家的农夫在路边发现了一条冻僵了的蛇。他很可怜蛇，就把它放在怀里。当他身上的热气把蛇温暖以后，蛇很快苏醒了，露出了残忍的本性，给了农夫致命的伤害——咬了农夫一口。农夫临死之前说：“我竟然救了一条可怜的毒蛇，就应该受到这种报应啊！”"
text = "question generation: " + text
inputs = tokenizer(text,
                   return_tensors='pt',
                   truncation=True,
                   max_length=512)
with torch.no_grad():
  outs = model.generate(input_ids=inputs["input_ids"],
                        attention_mask=inputs["attention_mask"],
                        max_length=128,
                        no_repeat_ngram_size=4,
                        num_beams=4)
question = tokenizer.decode(outs[0], skip_special_tokens=True) 
questions = [q.strip() for q in  question.split("<sep>") if len(q.strip()) > 0]
print(questions)
# Out:
# ['在寒冷的冬天,农夫在哪里发现了一条可怜的蛇?', '农夫是如何看待蛇的?', '当农夫遇到蛇时,他做了什么?']

# %%
from question_generation import pipeline

# gpu版本
qg = pipeline("question-generation", device="cuda") 

texts = ["在一个寒冷的冬天，赶集完回家的农夫在路边发现了一条冻僵了的蛇。他很可怜蛇，就把它放在怀里。当他身上的热气把蛇温暖以后，蛇很快苏醒了，露出了残忍的本性，给了农夫致命的伤害——咬了农夫一口。农夫临死之前说：“我竟然救了一条可怜的毒蛇，就应该受到这种报应啊！”"]
qg(texts)
# Out:
# [['在寒冷的冬天,农夫在哪里发现了一条可怜的蛇?', '农夫是如何看待蛇的?', '当农夫遇到蛇时,他做了什么?']]

# %%
qa = pipeline("question-answering") 
texts = "在一个寒冷的冬天，赶集完回家的农夫在路边发现了一条冻僵了的蛇。他很可怜蛇，就把它放在怀里。当他身上的热气把蛇温暖以后，蛇很快苏醒了，露出了残忍的本性，给了农夫致命的伤害——咬了农夫一口。农夫临死之前说：“我竟然救了一条可怜的毒蛇，就应该受到这种报应啊！”"
qa({
       'question': '在寒冷的冬天,农夫在哪里发现了一条可怜的蛇?',
       'context': texts
   })
# Out:
# {'answer': '路边', 'end': 20, 'score': 1.0, 'start': 18}

# %% [markdown]
# ## 使用目前的测试数据进行测试

# %%
text_1 = '史记是我国历史上第一部纪传体通史。全书分本纪、列传、表、书、世家等五大部分,共52.65万字。书中记载了从远古到汉初3000年中各代帝王的情况、重大历史事件(本纪)和重要历史人物(列传)。因为它是以“本纪”和“列传”为最主要的内容,所以称为“纪传体”史书。史记的作者是西汉的史官司马迁。司马迁的父亲就是一位历史学家。司马迁从小喜欢读历史书,10岁就能背诵许多古文,20岁他开始到全国各地旅游,了解、调查了祖国的自然环境、风俗人情、历史文化遗产等,为他以后写史记提供了丰富的资料。'
qg(text_1)
# Out:
# ['史记中记载了哪些内容?',
#  '史记的作者是谁?',
#  '20岁司马迁开始到全国各地旅游,了解、调查了祖国的自然环境、风俗人情、历史文化遗产等,为他以后写史记提供了丰富的资料。']

# %%
qa({
       'question': '史记的作者是谁?',
       'context': text_1
   })
# Out:
# {'answer': '司马迁', 'end': 142, 'score': 0.9999998807907104, 'start': 139}

# %%
text_2 = '甲骨文是刻在龟甲兽骨上文字的简称。主要是商代王室刻在ト问用过的龟甲兽骨上的记录，是公元前1300多年到公元前1100多年之间通行的字体。1899年首次在河南安阳殷墟（殷王朝都城遗址）发现，字数大约有3500个。'
qg(text_2)
# Out:
# ['甲骨文是刻在什么地方的文字的简称?', '1899年第一次在河南安阳殷墟发现甲骨文的字数是多少?', '在殷王朝都城遗址发现的甲骨文数量是多少?']

# %%
qa([
      {
      'question': '甲骨文是刻在什么地方的文字的简称?',
       'context': text_2
       },
      {
       'question': '1899年第一次在河南安阳殷墟发现甲骨文的字数是多少?',
       'context': text_2
      },
      {
       'question': '在殷王朝都城遗址发现的甲骨文数量是多少?',
       'context': text_2
       }])
# Out:
# [{'answer': '龟甲兽骨', 'end': 10, 'score': 0.999996542930603, 'start': 6},
#  {'answer': '3500', 'end': 103, 'score': 0.9999992847442627, 'start': 99},
#  {'answer': '3500', 'end': 103, 'score': 0.9999984502792358, 'start': 99}]

# %%
# !pip install farm

# %%
from farm.evaluation.squad_evaluation import compute_f1, compute_exact 
 
label = "6000 hours"
pred = "about 6000 hours"
print(f"EM: {compute_exact(label, pred)}")
print(f"F1: {compute_f1(label, pred)}")
# Out:
# EM: 0
# F1: 0.8

# %%
label = "6000 hours"
pred = "about  dollars"
print(f"EM: {compute_exact(label, pred)}")
print(f"F1: {compute_f1(label, pred)}")
# Out:
# EM: 0
# F1: 0

# %% [markdown]
# ## 测试使用mT5的微调模型对知识图谱数据进行问题生成的效果

# %%
# !pip install transformers
# !pip install question_generation
# !pip install torch
# Out:
# Collecting transformers
#   Downloading transformers-4.17.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 27.0 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 58.8 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 72.0 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.63.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 5.9 MB/s
# Collecting tokenizers!=0.11.3,>=0.11.1
#   Downloading tokenizers-0.11.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 59.7 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.4.0 pyyaml-6.0 sacremoses-0.0.47 tokenizers-0.11.6 transformers-4.17.0
# Collecting question_generation
#   Downloading question_generation-1.0.5-py3-none-any.whl (34 kB)
# Requirement already satisfied: transformers>=4.12.5 in /usr/local/lib/python3.7/dist-packages (from question_generation) (4.17.0)
# Collecting datasets>=1.15.1
#   Downloading datasets-1.18.3-py3-none-any.whl (311 kB)
#      |████████████████████████████████| 311 kB 57.0 MB/s
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.7/dist-packages (from question_generation) (1.10.0+cu111)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 63.4 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (4.11.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (1.3.5)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (6.0.1)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.2.0-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 75.5 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (0.70.12.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (21.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (0.4.0)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 66.8 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (1.21.5)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (4.63.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (2.23.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (0.3.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.15.1->question_generation) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.15.1->question_generation) (3.10.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.15.1->question_generation) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets>=1.15.1->question_generation) (3.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.15.1->question_generation) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.15.1->question_generation) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.15.1->question_generation) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.15.1->question_generation) (3.0.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.12.5->question_generation) (2019.12.20)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.12.5->question_generation) (0.11.6)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers>=4.12.5->question_generation) (0.0.47)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.15.1->question_generation) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 60.4 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.15.1->question_generation) (21.4.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 83.5 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.9 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets>=1.15.1->question_generation) (3.7.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets>=1.15.1->question_generation) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets>=1.15.1->question_generation) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets>=1.15.1->question_generation) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.12.5->question_generation) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.12.5->question_generation) (7.1.2)
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, fsspec, aiohttp, xxhash, datasets, question-generation
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 datasets-1.18.3 frozenlist-1.3.0 fsspec-2022.2.0 multidict-6.0.2 question-generation-1.0.5 xxhash-3.0.0 yarl-1.7.2
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.10.0.2)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("algolet/mt5-base-chinese-qg")

model = AutoModelForSeq2SeqLM.from_pretrained("algolet/mt5-base-chinese-qg")
# Out:
# Downloading:   0%|          | 0.00/428 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.11M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/7.93M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.17G [00:00<?, ?B/s]

# %% [markdown]
# ### 生成问题

# %%
from question_generation import pipeline

# gpu版本
qg = pipeline("question-generation", device="cuda") 

texts = ["卡宾枪弹、原产地、美国", '卡宾枪弹、生产公司、温彻斯特公司', '底特律、面积、370.2平方公里','王羲之、所处时代、东晋', '范宽、主要作品、溪山行旅图']
for text in texts:
  print(qg(text))
# Out:
# ['卡宾枪弹的原产地是哪里?', '卡宾的枪弹原产地是什么?', '美国哪个州的卡宾枪枪弹生产?']
# ['卡宾枪弹制造公司位于哪个城市?', '哪个公司生产卡宾枪?', '温彻斯特的卡宾枪厂叫什么名字?']
# ['底特律有多少平方公里?', '有多少平方公里的底特律?', '哪个城市有底特律的面积?']
# ['王羲之、王羲之,王羲之是哪个时代的人?', '谁是王羲之的祖先?', '东晋的王羲之是哪一年死的?']
# ['范宽主要的作品是什么?', '范宽的主要作品是什么?', '“溪山行旅图”的作者是谁?']

# %% [markdown]
# ### 使用文本、问题进行答案生成

# %%
qa = pipeline("question-answering") 
qa([
      {
      'question': '卡宾枪弹的原产地是哪里?',
       'context': "卡宾枪弹、原产地、美国"
       },
      {
       'question': '底特律有多少平方公里?',
       'context': '底特律、面积、370.2平方公里'
      },
      {
       'question': '范宽主要的作品是什么?',
       'context': '范宽、主要作品、溪山行旅图'
       }])
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/669 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/263k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.21G [00:00<?, ?B/s]
# [{'answer': '美国', 'end': 11, 'score': 0.9999997615814209, 'start': 9},
#  {'answer': '370.2平方公里', 'end': 16, 'score': 0.9999971389770508, 'start': 7},
#  {'answer': '溪山行旅图', 'end': 13, 'score': 0.9999985694885254, 'start': 8}]

# %% [markdown]
# ## 对文本数据预处理，然后验证问题生成效果

# %%
import pandas as pd
import csv
import json

from question_generation import pipeline

# gpu版本
qg = pipeline("question-generation", device="cpu") 

data_list = []

with open('./drive/MyDrive/NLP/NLP_Corpus/Chinese_culture.csv', 'r', encoding='utf-8-sig') as csvfile:
    csvReader = csv.DictReader(csvfile)
    for row in csvReader:
        context = row['line']
        print(qg(context), '\n.')
# Out:
# ['中国传统绘画又被称为什么?', '中国传统的绘画又称什么?', '国画历史悠久,在东周墓葬中出土过最早的帛画作是什么?', '在五代十国以后,中国文人艺术家得到了很高的社会地位,为什么国画题材多以王宫贵族肖像或生活记录等?']
# .
# ['《女史箴图》长卷的作者是谁?', '顾恺之的画线条连绵流畅,如“春蚕吐丝”?', '谁写的《女士箴图》?', '谁是顾恺之多才、工诗赋,善书法,被时人称为“才绝、画绝、痴绝”?']
# .
# ['宋太宗太平兴国五年(980年)全国有多少户?', '宋徽宗崇宁元年(1102年)全国有几户', '元丰(1078年—1085年)年间,全国有多少户']
# .
# ['太极拳与形意拳和八卦掌并称中国三大内家拳?', '张三丰对太极拳的贡献是什么?', '谁考证了太极拳创始者?']
# .
# ['王羲之在书法史上取得的成就影响巨大,被后人誉为古今之冠,受到后人誉为什么?', '为什么王羲之曾受录为正一道士,颇受正一符影响?', '《兰亭集序》等帖,皆为后人临摹?']
# .
# ['临沂市是哪个省下辖的地级市?', '沂山、蒙山、尼山三大山脉分布于北部,南部为平原,还有什么河流?', '临沂的地势是怎样的?']
# .
# ['三皇五帝时期,黄河泛滥时,谁负责治水?', '大禹治水是什么时候发生的?', '谁是舜帝的儿子?']
# .
# ['中秋节从嫦娥奔月这个传说而来的节日是什么?', '中国传统节日是从什么而来的?', '古代民间传说叫什么名字?']
# .
# ['《庄子·齐物论》的十日是指什么?', '十日的说法最早可见于哪本书?', '《山海经·海外西经》中的十日指的是什么?', '谁派遣神射手羿射下其中九个太阳?']
# .
# ['民间认为织女聪明美丽、多才多艺,在七月七晚间向织女乞求智巧,可以除去笨拙,变得眼明手巧,故又叫什么?', '七夕传统节日是从牛郎织女的故事而来的?', '什么是七夕的传统节日?']
# .
# ['猪肉是什么时候祭祀的?', '猪肉的社会风俗是什么?', '什么节日是猪肉的祭祀?', '什么是猪肉?']
# .
# ['赛龙舟是哪个地区的地方民俗活动?', '2010年亚洲运动会首次成为亚运会中的正式比赛项目是什么时候?', '现时龙舟竞赛已发展为一项水上体育运动,在世界各地有哪些地方亦有定期举行?', '现在龙舟竞赛的简称是什么?']
# .
# ['屈原的父亲叫什么名字?', '屈原与昭氏、景氏并称王族三姓,分别是哪个?', '“忽忘身之贱贫”是什么意思?']
# .
# ['秦国是什么时候迁都咸阳的?', '秦王政于哪一年攻灭六国?', '前335年,秦国迁都了什么地方?']
# .
# ['商鞅变法是什么时候在秦国实施的政治改革?', '秦国富国强兵是什么时候开始的?', '商鞅是在哪一年在秦国实行的政治改革的?']
# .
# ['库页岛主要河流有哪些?', '库页屿在中国古代称之为什么?', '在库页岛上的主要民族有哪些?']
# .
# ['传说中仓颉在黄帝时期造的字是战国时期流行的什么书?', '传说仓颉是黄帝的右史,被流传是发明文字的始祖,又被称为什么?', '为什么传说仓颉是在黄帝时代造的字?', '黄帝感他功绩过人,乃赐以“仓”姓,意为君上一人,人下一君?']
# .
# ['战国时期又被称为什么时代?', '战国时代是什么时候结束的?', '东周在周赧王五十九年被秦国所灭亡,所以东周不完全战国时代?']
# .
# ['《史记》与后来的《汉书》、《后汉书》、《三国志》合称了什么?', '《太史公书》是哪个时期的任职太史令的司马迁(太史令)编写的纪传体史书,记载自传说中的黄帝至汉武帝太初年间共多少百年的中国历史?', '谁编写了史记?']
# .
# ['在战国时代老子的《道德经》中,将阴阳五行视为政教制度的设立依据和根源?', '《春秋繁露》的作者是谁?', '阴阳理论已渗透到哪些方面?']
# .

# %%
with open('./drive/MyDrive/NLP/NLP_Corpus/Life_and_art.csv', 'r', encoding='utf-8-sig') as csvfile:
    csvReader = csv.DictReader(csvfile)
    for row in csvReader:
        context = row['line']
        print(qg(context), '\n.')
# Out:
# ['中国古代货币或古罗马苏币是什么?', '古钱币指的是什么?', '“古钱币”这个词的起源是什么?']
# .
# ['在旅行时购买或收集并带回家中的物品,只要有纪念意义,都叫什么?', '除了纪念品之外,还有什么其他形式的纪念品?', '纪念品是保存记忆而取得的物品吗?']
# .
# ['川渝火锅的调味是由什么组成的?', '川渝麻辣火锅的主要菜品与北方火锅差异大,主要以什么为主要原料?', '四川辣椒最辣的辣椒是什么?']
# .
# ['寿喜烧又被称为什么?', '寿喜燒一般被视为冬季传统料理,常在什么时间食用?', '什么是寿喜烧?']
# .
# ['《美食侦探王》是哪个国家的漫画作品?', '台湾纬来日本台于哪一年播出《大胃王神探》?', '2006年由原作改编的电视剧叫什么名字?']
# .
# ['古希腊饮食的基础是什么?', '哪一种酒精是古希腊的饮食的基础?', '古古希腊主要的谷物是什么?']
# .
# ['茴香的叶子是什么颜色的?', '茴香是什么类型的植物?', '什么类型的草本植物可以生长到2.5米的高度?']
# .
# ['大英博物馆的缘起可追溯到哪一世纪?', '英国通过在海外殖民扩张收获了大量文物,使得大英博物馆在伦敦的蒙塔古宫落成?', '汉斯·斯隆爵士去世前立下遗嘱,将他所收藏的珍贵物什全部捐赠给国家,从而奠定了大英博物馆的基础?']
# .
# ['世界扑克大赛和世界扑克巡回赛的主赛事项目是什么?', '美国多数赌场内最受欢迎的扑克牌游戏是什么?', '“无限注德州扑克”是什么类型的游戏?']
# .
# ['腓尼基人是哪个民族的邻居?', '希伯来字母和拉丁字母同源于腓尼基人的哪一类字母?', '在全盛期,腓尼基控制了什么贸易?']
# .
# ['傣族的民间传统舞蹈是什么?', '南亚孔雀舞的傣族版本是什么?', '亚洲的传统民族舞蹈模仿了什么?', '在亚洲的不同地区发展出不同传统的孔雀舞?']
# .
# ['西双版纳傣族自治州的首府在哪里?', '东面与缅甸相连,东南与哪个国家接壤?', '该州的总面积是多少平方公里?', '自治州首府是哪里?']
# .
# ['《英雄》是何时在中国大陆上映的?', '2002年12月14日在中国大陆上映,中国票房是多少?', '电影《英雄》的主题曲演唱者是谁?']
# .
# ['红河哈尼梯田的代表作是什么?', '哈尼的梯田分布在什么地方?', '华丽的山岭雕刻是哪个国家的梯田?']
# .
# ['天山山脉横亘了哪些地区?', '天山峰的最高海拔是多少?', '中国中部最大的一条山脉是什么?']
# .
# ['塔里木盆地位于什么地方?', '塔里的木盆地与准噶尔盆地隔开,南北相对,海拔高度是多少?', '土著塔里树的边缘是什么?', '中国面积最大的内陆盆地是什么?']
# .
# ['雅丹地貌的俗称是什么?', '雅丹的另一个术语是什么?', '“雅丹”在维吾尔语中的意思是什么?']
# .
# ['景泰蓝的学名是什么?', '景太蓝又被称为什么?', '世传景泰蓝大行于哪一年?', '19世纪景泰蓝技艺流入民间,成为什么?']
# .
# ['高山流水是哪个朝代的古琴曲?', '高山流水是哪一年收录的?', '管平湖所演奏的流水是哪一年?', '哪一年管平湖演奏的流水被美国国家航空航天局作为中国音乐作品的代表收录进旅行者金唱片中?']
# .
# ['《吕氏春秋》的作者是谁?', '《吕姓春秋》共多少卷?', '中国古代书的起源是什么?']
# .

# %%
qa = pipeline("question-answering") 

with open('./drive/MyDrive/NLP/NLP_Corpus/KG-test.csv', 'r', encoding='utf-8-sig') as csvfile:
    csvReader = csv.DictReader(csvfile)
    for row in csvReader:
        context = row['content']
        questions = qg(context)
        for q in questions:
            print('question: ', q)
            answer = qa({
                'question': str(q),
                'context': str(row)
            })
            print('answer: ', answer, '\n')
# Out:
# question:  卡宾枪弹的原产地是哪里?
# answer:  {'answer': '美国', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  卡宾的枪弹原产地是什么?
# answer:  {'answer': '美国', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  美国哪个州的卡宾枪枪弹生产?
# answer:  {}
#
# question:  卡宾枪弹的弹壳有多长?
# answer:  {'answer': '33mm', 'start': 35, 'end': 39, 'score': 0.9999985694885254}
#
# question:  什么类型的枪弹有直径33mm的弹壳?
# answer:  {'answer': '卡宾枪弹', 'start': 26, 'end': 30, 'score': 1.0}
#
# question:  枪弹弹的直径是多少?
# answer:  {}
#
# question:  卡宾枪弹制造公司位于哪个城市?
# answer:  {'answer': '温彻斯特', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  哪个公司生产卡宾枪?
# answer:  {'answer': '温彻斯特公司', 'start': 36, 'end': 42, 'score': 1.0}
#
# question:  温彻斯特的卡宾枪厂叫什么名字?
# answer:  {'answer': '温彻斯特公司', 'start': 36, 'end': 42, 'score': 1.0}
#
# question:  《八爪女》的出品时间是?
# answer:  {'answer': '1983年', 'start': 39, 'end': 44, 'score': 1.0}
#
# question:  八爪女的出品日期是?
# answer:  {'answer': '1983年', 'start': 39, 'end': 44, 'score': 1.0}
#
# question:  第一批八爪女出品时间?
# answer:  {'answer': '1983年', 'start': 39, 'end': 44, 'score': 1.0}
#
# question:  谁是《美国偶像》的主演?
# answer:  {}
#
# question:  谁是美国偶像的导演?
# answer:  {}
#
# question:  约翰·格兰的职业是什么?
# answer:  {'answer': '导演', 'start': 34, 'end': 36, 'score': 1.0}
#
# question:  越南北部红河流域是哪个?
# answer:  {'answer': '交趾', 'start': 26, 'end': 28, 'score': 1.0}
#
# question:  越南的哪个地区是红色河流域?
# answer:  {'answer': '交趾', 'start': 26, 'end': 28, 'score': 1.0}
#
# question:  交趾郡的地理位置是哪里?
# answer:  {'answer': '越南北部红河流域', 'start': 35, 'end': 43, 'score': 1.0}
#
# question:  丹娘的别名是什么?
# answer:  {'answer': '卓雅', 'start': 26, 'end': 28, 'score': 1.0}
#
# question:  丹娘别名叫什么?
# answer:  {'answer': '卓雅', 'start': 26, 'end': 28, 'score': 1.0}
#
# question:  卓雅别名叫做什么?
# answer:  {'answer': '丹娘', 'start': 32, 'end': 34, 'score': 1.0}
#
# question:  苏联的游击队员叫什么名字?
# answer:  {'answer': '卓雅', 'start': 26, 'end': 28, 'score': 0.9999996423721313}
#
# question:  苏联游击队员是哪个国家的游击队员?
# answer:  {'answer': '苏联', 'start': 32, 'end': 34, 'score': 1.0}
#
# question:  游击队员的职业是什么?
# answer:  {'answer': '卓雅', 'start': 26, 'end': 28, 'score': 0.9985417127609253}
#
# question:  张春平的出生地是哪里?
# answer:  {'answer': '辽宁鞍山', 'start': 34, 'end': 38, 'score': 1.0}
#
# question:  东北鞍山的张春平出生地在哪里?
# answer:  {'answer': '辽宁鞍山', 'start': 34, 'end': 38, 'score': 1.0}
#
# question:  辽宁鞍山市张春平的名字是什么?
# answer:  {'answer': '张春平', 'start': 26, 'end': 29, 'score': 0.9999998807907104}
#
# question:  底特律哪个城市是底特律的汽车之城?
# answer:  {'answer': 'content', 'start': 15, 'end': 22, 'score': 0.9996260404586792}
#
# question:  汽车之城位于底特律吗?
# answer:  {}
#
# question:  哪个城市有汽车之城吗?
# answer:  {'answer': '底特律', 'start': 26, 'end': 29, 'score': 1.0}
#
# question:  底特律的气候条件是什么?
# answer:  {'answer': '温带大陆性气候', 'start': 35, 'end': 42, 'score': 1.0}
#
# question:  什么类型的气候有温带大陆性气候?
# answer:  {'answer': '温带大陆性气候', 'start': 35, 'end': 42, 'score': 0.9999608993530273}
#
# question:  哪个大陆的气候条件是底特律最温带的?
# answer:  {'answer': '温带大陆性气候', 'start': 35, 'end': 42, 'score': 1.0}
#
# question:  底特律有多少平方公里?
# answer:  {'answer': '370.2平方公里', 'start': 33, 'end': 42, 'score': 1.0}
#
# question:  有多少平方公里的底特律?
# answer:  {'answer': '370.2平方公里', 'start': 33, 'end': 42, 'score': 1.0}
#
# question:  哪个城市有底特律的面积?
# answer:  {'answer': "OrderedDict([('content', '底特律", 'start': 0, 'end': 29, 'score': 0.9998747110366821}
#
# question:  新桥村有多少人?
# answer:  {'answer': '97人', 'start': 33, 'end': 36, 'score': 1.0}
#
# question:  有多少人住在新桥村?
# answer:  {'answer': '97人', 'start': 33, 'end': 36, 'score': 1.0}
#
# question:  新桥村有几人?
# answer:  {'answer': '97人', 'start': 33, 'end': 36, 'score': 1.0}
#
# question:  新桥村的海拔是多少米?
# answer:  {'answer': '1520米', 'start': 33, 'end': 38, 'score': 1.0}
#
# question:  新桥村海拔多少米?
# answer:  {'answer': '1520米', 'start': 33, 'end': 38, 'score': 1.0}
#
# question:  谷爱玲的国籍是什么?
# answer:  {'answer': '中国', 'start': 33, 'end': 35, 'score': 1.0}
#
# question:  日本国籍的谷爱玲是什么人?
# answer:  {'answer': '中国', 'start': 33, 'end': 35, 'score': 0.9999889135360718}
#
# question:  中国国籍谷爱玲是哪个国家的人?
# answer:  {'answer': '中国', 'start': 33, 'end': 35, 'score': 0.9999943971633911}
#
# question:  谷爱玲的年龄
# answer:  {'answer': '19岁', 'start': 33, 'end': 36, 'score': 1.0}
#
# question:  谷爱莉的年龄
# answer:  {'answer': '19岁', 'start': 33, 'end': 36, 'score': 1.0}
#
# question:  19岁谷爱玲多大
# answer:  {'answer': '19岁', 'start': 33, 'end': 36, 'score': 0.9999786615371704}
#
# question:  19岁的谷爱玲是多大
# answer:  {'answer': '19岁', 'start': 33, 'end': 36, 'score': 0.9999127388000488}
#
# question:  古井贡酒厂位于哪里?
# answer:  {'answer': '李集村', 'start': 26, 'end': 29, 'score': 1.0}
#
# question:  李集村的著名酒厂叫什么名字?
# answer:  {'answer': '古井贡酒酒厂', 'start': 35, 'end': 41, 'score': 1.0}
#
# question:  酒厂的地址是哪里?
# answer:  {'answer': '李集村', 'start': 26, 'end': 29, 'score': 1.0}
#
# question:  沈阳的别名是什么
# answer:  {'answer': '奉天', 'start': 32, 'end': 34, 'score': 1.0}
#
# question:  沈阳的字母
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 1.0}
#
# question:  沈阳叫什么名字
# answer:  {'answer': '奉天', 'start': 32, 'end': 34, 'score': 1.0}
#
# question:  沈阳的名字是什么
# answer:  {'answer': '奉天', 'start': 32, 'end': 34, 'score': 1.0}
#
# question:  杜甫的出生地是哪里?
# answer:  {'answer': '河南巩义', 'start': 33, 'end': 37, 'score': 1.0}
#
# question:  杜甫在河南的出生地叫什么名字?
# answer:  {'answer': '巩义', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  河南杜甫出生地在哪里?
# answer:  {'answer': '巩义', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  杜甫的别名是什么?
# answer:  {'answer': '诗圣', 'start': 32, 'end': 34, 'score': 1.0}
#
# question:  杜甫的名字是什么?
# answer:  {'answer': '诗圣', 'start': 32, 'end': 34, 'score': 1.0}
#
# question:  “杜甫”这个词是什么?
# answer:  {'answer': '诗圣', 'start': 32, 'end': 34, 'score': 1.0}
#
# question:  王羲之、王羲之,王羲之是哪个时代的人?
# answer:  {'answer': '东晋', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  谁是王羲之的祖先?
# answer:  {}
#
# question:  东晋的王羲之是哪一年死的?
# answer:  {}
#
# question:  范宽、范宽和范宽是哪个时期
# answer:  {'answer': '北宋', 'start': 34, 'end': 36, 'score': 1.0}
#
# question:  范宽与范宽的相遇是哪个时期?
# answer:  {'answer': '北宋', 'start': 34, 'end': 36, 'score': 1.0}
#
# question:  在范宽时代,范宽与谁有相似之处
# answer:  {'answer': "OrderedDict([('content', '范宽、所处时代、北宋", 'start': 0, 'end': 36, 'score': 0.934851884841919}
#
# question:  范宽主要的作品是什么?
# answer:  {'answer': '溪山行旅图', 'start': 34, 'end': 39, 'score': 1.0}
#
# question:  范宽的主要作品是什么?
# answer:  {'answer': '溪山行旅图', 'start': 34, 'end': 39, 'score': 1.0}
#
# question:  “溪山行旅图”的作者是谁?
# answer:  {'answer': '范宽', 'start': 26, 'end': 28, 'score': 1.0}
#
# question:  范宽的出生地是哪里?
# answer:  {'answer': '陕西华原', 'start': 33, 'end': 37, 'score': 1.0}
#
# question:  范宽出生地在什么地方?
# answer:  {'answer': '陕西华原', 'start': 33, 'end': 37, 'score': 1.0}
#
# question:  陕西省哪个省有范宽?
# answer:  {'answer': '陕西华原', 'start': 33, 'end': 37, 'score': 1.0}
#
# question:  早春图的作者是谁?
# answer:  {'answer': '郭熙', 'start': 33, 'end': 35, 'score': 1.0}
#
# question:  《早春图》作者是谁
# answer:  {'answer': '郭熙', 'start': 33, 'end': 35, 'score': 1.0}
#
# question:  早春画作者是谁
# answer:  {'answer': '郭熙', 'start': 33, 'end': 35, 'score': 1.0}
#
# question:  台北故宫的现藏地点在哪里?
# answer:  {'answer': '台北故宫', 'start': 33, 'end': 37, 'score': 0.9999990463256836}
#
# question:  早春图在台北的哪个地方?
# answer:  {'answer': '台北故宫', 'start': 33, 'end': 37, 'score': 1.0}
#
# question:  台北的早春图在哪里?
# answer:  {'answer': '台北故宫', 'start': 33, 'end': 37, 'score': 1.0}

# %% [markdown]
# ## 测试基于知识图谱自带标签筛选的数据

# %%
# !pip install transformers
# !pip install question_generation
# !pip install torch

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("algolet/mt5-base-chinese-qg")

model = AutoModelForSeq2SeqLM.from_pretrained("algolet/mt5-base-chinese-qg")

from question_generation import pipeline

# gpu版本
qg = pipeline("question-generation", device="cpu") 

qa = pipeline("question-answering")
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/669 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/263k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.21G [00:00<?, ?B/s]

# %%
with open('./drive/MyDrive/NLP/NLP_Corpus/kg_base-label.csv', 'r', encoding='utf-8-sig') as csvfile:
    csvReader = csv.DictReader(csvfile)
    for row in csvReader:
        context1 = row['实体']
        context2 = row['属性']
        context3 = row['值']
        full_context = context1 + '的'+ context2 +  '是：'+  context3
        with open('./kg-base-label.txt', 'a') as test_file:
            test_file.write(full_context)
            print('full_context: ', full_context)
            questions = qg(full_context)
            for q in questions:
                test_file.write(q)
                print('question: ', q)
                answer = qa({
                    'question': str(q),
                    'context': str(row)
                })
                test_file.write(str(answer))
                test_file.write('\n')
                print('answer: ', answer, '\n')
# Out:
# full_context:  电解质的描述是：电解质是溶于水溶液中或在熔融状态下就能够导电的化合物。
# question:  电解质溶于水溶液中或在熔融状态下会产生什么?
# answer:  {'answer': '导电', 'start': 84, 'end': 86, 'score': 0.9999998807907104}
#
# question:  什么类型的电解质会产生电解质?
# answer:  {}
#
# question:  在溶融状态下,电解质能导电什么?
# answer:  {'answer': '水溶液', 'start': 70, 'end': 73, 'score': 0.9999912977218628}
#
# full_context:  电解质的中文名是：电解质
# question:  电解质的中文名是什么?
# answer:  {'answer': '电解质', 'start': 35, 'end': 38, 'score': 0.9999974966049194}
#
# question:  在电解质中,电解质是什么意思?
# answer:  {}
#
# question:  什么是电解质?
# answer:  {}
#
# full_context:  电解质的外文名是：Electrolyte
# question:  电解质的外文名是什么?
# answer:  {'answer': '电解质', 'start': 35, 'end': 38, 'score': 0.9999980926513672}
#
# question:  什么外文名是电解质?
# answer:  {'answer': "OrderedDict([('实体序号', ''), ('实体', '电解质", 'start': 0, 'end': 38, 'score': 0.9995280504226685}
#
# question:  电解体的外文名字是什么?
# answer:  {'answer': '电解质', 'start': 35, 'end': 38, 'score': 1.0}
#
# full_context:  电解质的属性是：化合物
# question:  电解质属性的属性是什么?
# answer:  {}
#
# question:  什么属性是电解质的属性?
# answer:  {}
#
# question:  化合物的属性是什么
# answer:  {}
#
# full_context:  电解质的分类是：强电解质、弱电解质
# question:  弱电解质的分类
# answer:  {}
#
# question:  强电解质是什么
# answer:  {'answer': '强电解质、弱电解质', 'start': 63, 'end': 72, 'score': 0.9947358965873718}
#
# question:  弱的电解质是啥
# answer:  {}
#
# question:  弱 电解质叫什么
# answer:  {}
#
# full_context:  碳酸氢钠的描述是：碳酸氢钠，化学式NaHCO?，俗称小苏打。
# question:  碳酸氢钠的化学式是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999998807907104}
#
# question:  碳化氢钠的俗称是什么?
# answer:  {'answer': '小苏打', 'start': 82, 'end': 85, 'score': 1.0}
#
# question:  NaHCO是什么意思?
# answer:  {'answer': '碳酸氢钠', 'start': 36, 'end': 40, 'score': 0.9999998807907104}
#
# full_context:  碳酸氢钠的中文名是：碳酸氢钠
# question:  碳酸氢钠的中文名是什么?
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}
#
# question:  碳化氢钠的英文名是什么
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 0.9999997615814209}
#
# question:  碳化的氢钠中文名是什么
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}
#
# full_context:  碳酸氢钠的英文名是：Sodium Bicarbonate
# question:  碳酸氢钠的英文名是什么?
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}
#
# question:  碳化氢钠英文名是什么
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}
#
# question:  碳氢氢钠的中文名是什么
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}
#
# full_context:  碳酸氢钠的别称是：小苏打，重碳酸钠，酸式碳酸钠，重曹，Baking Soda
# question:  碳酸氢钠的别名是什么?
# answer:  {'answer': '小苏打', 'start': 64, 'end': 67, 'score': 1.0}
#
# question:  重碳酸钠叫什么?
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}
#
# question:  轻碳酸钠的别称是什么?
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 0.9999998807907104}
#
# full_context:  碳酸氢钠的化学式是：NaHCO?
# question:  碳酸氢钠的化学式是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999998807907104}
#
# question:  NaHCO代表什么?
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}
#
# question:  氢钠是什么?
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}
#
# full_context:  碳酸氢钠的分子量是：84.01
# question:  碳酸氢钠的百分比是多少?
# answer:  {}
#
# question:  碳化氢钠的化学量是多少?
# answer:  {'answer': '84.01', 'start': 65, 'end': 70, 'score': 0.9999535083770752}
#
# full_context:  碳酸氢钠的CAS登录号是：144-55-8
# question:  碳酸氢钠的CAS编号是多少?
# answer:  {'answer': '144', 'start': 68, 'end': 71, 'score': 0.9999970197677612}
#
# question:  碳化氢钠的 CAS号码是多少?
# answer:  {'answer': '144', 'start': 68, 'end': 71, 'score': 0.9999995231628418}
#
# question:  144-55-8的碳酸氢钾的CAS编号是什么?
# answer:  {}
#
# full_context:  碳酸氢钠的EINECS登录号是：205-633-8
# question:  碳酸氢钠的EINECS编号是多少?
# answer:  {'answer': '205', 'start': 71, 'end': 74, 'score': 0.9999972581863403}
#
# question:  碳化氢钠的什么值号是?
# answer:  {}
#
# question:  氢钠的哪个值号是多少?
# answer:  {}
#
# full_context:  碳酸氢钠的熔点是：270℃（分解）
# question:  碳酸氢钠的熔点是多少?
# answer:  {'answer': '270℃', 'start': 64, 'end': 68, 'score': 0.9999996423721313}
#
# question:  碳化氢钠的冷却点是多少°C?
# answer:  {'answer': '270℃', 'start': 64, 'end': 68, 'score': 0.9999963045120239}
#
# question:  氢钠熔点是多少度?
# answer:  {'answer': '270℃', 'start': 64, 'end': 68, 'score': 0.9999998807907104}
#
# full_context:  碳酸氢钠的水溶性是：7.8g/100ml，18℃
# question:  碳酸氢钠的溶性值是多少?
# answer:  {'answer': '7.8g/100ml', 'start': 65, 'end': 75, 'score': 0.9999891519546509}
#
# question:  碳化氢钠的水溶性值多少?
# answer:  {'answer': '7.8g/100ml', 'start': 65, 'end': 75, 'score': 0.9999974966049194}
#
# question:  氢钠水溶性值多少钱?
# answer:  {}
#
# full_context:  碳酸氢钠的密度是：2.159 g/c? （固体）
# question:  碳酸氢钠的固体含量是多少?
# answer:  {'answer': '2.159', 'start': 64, 'end': 69, 'score': 0.9999768733978271}
#
# question:  碳化氢钠的含义是什么?
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}
#
# question:  什么化合物的含义是多少?
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 0.9999796152114868}
#
# full_context:  碳酸氢钠的外观是：白色粉末或单斜晶结晶性粉末
# question:  碳酸氢钠的外观是什么样的?
# answer:  {'answer': '白色粉末', 'start': 64, 'end': 68, 'score': 1.0}
#
# question:  碳化氢钠的颜色是什么?
# answer:  {'answer': '白色', 'start': 64, 'end': 66, 'score': 1.0}
#
# question:  单斜晶结晶的粉末是什么颜色的?
# answer:  {'answer': '白色', 'start': 64, 'end': 66, 'score': 1.0}
#
# full_context:  碳酸氢钠的应用是：俗称小苏打 可用于烹饪起发面食
# question:  碳酸氢钠的烹饪方式是什么?
# answer:  {'answer': '面食', 'start': 77, 'end': 79, 'score': 1.0}
#
# question:  小苏打的食物叫什么?
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}
#
# question:  什么食物可以用来烹饪小苏打?
# answer:  {'answer': '面食', 'start': 77, 'end': 79, 'score': 1.0}
#
# full_context:  碳酸氢钠的属性是：化学试剂
# question:  碳酸氢钠的属性是什么?
# answer:  {'answer': '化学试剂', 'start': 64, 'end': 68, 'score': 1.0}
#
# question:  氢钠的化学试剂是什么
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}
#
# question:  什么化学试剂可以用碳酸氢钾来试剂?
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 0.9999985694885254}
#
# question:  化学试剂用什么氢钠来试剂氢钠?
# answer:  {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}
#
# full_context:  两性氧化物的描述是：两性氧化物（Amphoteric Oxide）两性氧化物是指遇强酸呈碱性，遇强碱呈酸性的氧化物，既能与酸作用，又能与碱作用。
# question:  两性氧化物的名称是什么?
# answer:  {'answer': "OrderedDict([('实体序号', '3'), ('实体', '两性氧化物", 'start': 0, 'end': 41, 'score': 0.9965634942054749}
#
# question:  什么类型的氧化物能与碱作用?
# answer:  {'answer': '两性氧化物', 'start': 36, 'end': 41, 'score': 1.0}
#
# question:  两性氧物的描述是什么?
# answer:  {'answer': '遇强酸呈碱性，遇强碱呈酸性的氧化物', 'start': 96, 'end': 113, 'score': 0.999998927116394}
#
# full_context:  两性氧化物的中文名是：两性氧化物
# question:  两性氧化物的中文名是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 1.0}
#
# question:  二性氧化物的名字是什么
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999998807907104}
#
# question:  两性氧物的中文名字是什么?
# answer:  {'answer': '氧化物', 'start': 37, 'end': 40, 'score': 0.9999997615814209}
#
# full_context:  两性氧化物的外文名是：Amphoteric Oxide
# question:  两性氧化物的外文名是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999990463256836}
#
# question:  二性氧化物外文名叫什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999915361404419}
#
# question:  三性氧化物的名字是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9888381958007812}
#
# full_context:  两性氧化物的特点是：既能与酸作用，又能与碱作用
# question:  两性氧化物能与碱作用
# answer:  {}
#
# question:  二性氧化物可以与碱的作用
# answer:  {}
#
# question:  两性氧物能与什么作用
# answer:  {'answer': '碱', 'start': 75, 'end': 76, 'score': 1.0}
#
# question:  两性的氧化物能和什么作用
# answer:  {'answer': '碱', 'start': 75, 'end': 76, 'score': 1.0}
#
# full_context:  两性氧化物的组成是：活动性较低的金属的氧化物
# question:  两性氧化物的组成是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999996423721313}
#
# question:  金属的氧化物是什么类型的化合物?
# answer:  {'answer': '两性氧化物', 'start': 35, 'end': 40, 'score': 0.9999997615814209}
#
# question:  什么类型的氧化物是由金属组成的?
# answer:  {'answer': '两性氧化物', 'start': 35, 'end': 40, 'score': 0.9999997615814209}
#
# full_context:  两性氧化物的典例是：Al2O3、ZnO
# question:  al2O3、ZnO3、Al2O3等于什么?
# answer:  {'answer': '氧化物', 'start': 37, 'end': 40, 'score': 0.999996542930603}
#
# question:  两性氧化物的例子是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999996423721313}
#
# question:  二性氧化物是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 1.0}
#
# full_context:  两性氧化物的应用是：化学分析
# question:  两性氧化物的应用是什么?
# answer:  {'answer': '化学分析', 'start': 65, 'end': 69, 'score': 1.0}
#
# question:  什么类型的氧化物在化学方面被广泛使用?
# answer:  {'answer': '两性氧化物', 'start': 35, 'end': 40, 'score': 0.9999998807907104}
#
# question:  二性氧化物的用途是什么?
# answer:  {'answer': '化学分析', 'start': 65, 'end': 69, 'score': 1.0}
#
# full_context:  公因数的描述是：公因数，亦称“公约数”。
# question:  公因数的另一个术语是什么?
# answer:  {'answer': '公约数', 'start': 71, 'end': 74, 'score': 1.0}
#
# question:  公约数又被称为什么?
# answer:  {'answer': '公因数', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  什么是公因数?
# answer:  {'answer': '公约数', 'start': 71, 'end': 74, 'score': 0.9999995231628418}
#
# full_context:  公因数的中文名是：公因数
# question:  公因数的中文名是什么?
# answer:  {'answer': '实体序号', 'start': 15, 'end': 19, 'score': 0.999976396560669}
#
# question:  在公因数中,公因数是什么意思?
# answer:  {}
#
# question:  什么是公因数?
# answer:  {'answer': '值', 'start': 59, 'end': 60, 'score': 0.9999665021896362}
#
# full_context:  公因数的外文名是：Common factor
# question:  公因数的外文名是什么?
# answer:  {'answer': 'factor', 'start': 71, 'end': 77, 'score': 0.9999940395355225}
#
# question:  什么类型的公因数有外文名?
# answer:  {'answer': '实体', 'start': 15, 'end': 17, 'score': 0.9999357461929321}
#
# question:  用什么术语来形容公因数?
# answer:  {}
#
# full_context:  公因数的性质是：科学
# question:  公因数的性质是什么?
# answer:  {'answer': '属性', 'start': 44, 'end': 46, 'score': 0.9999840259552002}
#
# question:  什么性质的公因数性质是科学?
# answer:  {'answer': '实体', 'start': 15, 'end': 17, 'score': 0.9999901056289673}
#
# question:  科学性质公因数是什么?
# answer:  {'answer': '实体', 'start': 15, 'end': 17, 'score': 0.9999996423721313}
#
# full_context:  公因数的类别是：数学
# question:  公因数的另一个术语是什么?
# answer:  {'answer': '实体序号', 'start': 15, 'end': 19, 'score': 0.9999730587005615}
#
# question:  数学和数学的分支叫什么?
# answer:  {}
#
# question:  什么类型的数有公因数?
# answer:  {'answer': '实体', 'start': 15, 'end': 17, 'score': 0.9998016953468323}
#
# full_context:  公因数的别称是：公约数
# question:  公约数的别称是什么?
# answer:  {'answer': '公因数', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  公因数的别名是什么?
# answer:  {'answer': '公约数', 'start': 63, 'end': 66, 'score': 1.0}
#
# full_context:  暗物质[物理名词]的描述是：暗物质（Dark matter）是理论上提出的可能存在于宇宙中的一种不可见的物质，它可能是宇宙物质的主要组成部分，但又不属于构成可见天体的任何一种目前已知的物质。
# question:  暗物质的物理名词是什么?
# answer:  {}
#
# question:  暗物质是宇宙物质的主要组成部分吗?
# answer:  {'answer': '可能是宇宙物质的主要组成部分', 'start': 112, 'end': 126, 'score': 0.9999992847442627}
#
# question:  什么类型的物质不属于构成可见天体的任何已知的物质?
# answer:  {'answer': '暗物质', 'start': 36, 'end': 39, 'score': 1.0}
#
# full_context:  暗物质[物理名词]的中文名是：暗物质
# question:  暗物质这个词的中文名是什么?
# answer:  {'answer': '实体', 'start': 15, 'end': 17, 'score': 0.9999966621398926}
#
# question:  暗物质的中文名叫什么?
# answer:  {'answer': '实体', 'start': 15, 'end': 17, 'score': 0.9999984502792358}
#
# question:  什么词是暗物质?
# answer:  {'answer': '物理名词', 'start': 39, 'end': 43, 'score': 0.9999990463256836}
#
# full_context:  暗物质[物理名词]的外文名是：Dark matter
# question:  暗物质的外文名是什么?
# answer:  {'answer': "OrderedDict([('实体序号', ''), ('实体', '暗物质", 'start': 0, 'end': 38, 'score': 0.9999672174453735}
#
# question:  暗物质外文名叫什么?
# answer:  {'answer': "OrderedDict([('实体", 'start': 0, 'end': 17, 'score': 0.9997753500938416}
#
# question:  物理名词的外文名称是什么?
# answer:  {'answer': '暗物质', 'start': 35, 'end': 38, 'score': 0.9999834299087524}
#
# full_context:  暗物质[物理名词]的别称是：不可见物质
# question:  暗物质的别称是什么?
# answer:  {'answer': '不可见物质', 'start': 69, 'end': 74, 'score': 1.0}
#
# question:  暗物质是什么意思?
# answer:  {'answer': '不可见物质', 'start': 69, 'end': 74, 'score': 1.0}
#
# question:  什么词的别称是不可见物质?
# answer:  {'answer': '暗物质', 'start': 35, 'end': 38, 'score': 1.0}
#
# full_context:  暗物质[物理名词]的发现者是：弗里兹·扎维奇
# question:  暗物质的发现者是谁?
# answer:  {'answer': '弗里兹·扎维奇', 'start': 70, 'end': 77, 'score': 1.0}
#
# question:  谁发现了暗物质?
# answer:  {'answer': '弗里兹·扎维奇', 'start': 70, 'end': 77, 'score': 1.0}
#
# question:  弗里兹·扎维奇的物理名词是什么?
# answer:  {'answer': '暗物质', 'start': 35, 'end': 38, 'score': 1.0}
#
# full_context:  暗物质[物理名词]的质量是：宇宙的96%
# question:  暗物质的质量是多少?
# answer:  {'answer': '96%', 'start': 72, 'end': 75, 'score': 0.999995231628418}
#
# question:  宇宙的质量是多少
# answer:  {'answer': '96%', 'start': 72, 'end': 75, 'score': 1.0}
#
# question:  宇宙质量的百分比是多少
# answer:  {'answer': '96%', 'start': 72, 'end': 75, 'score': 1.0}
#
# full_context:  暗物质[物理名词]的类属是：天文学
# question:  暗物质的另一个术语是什么?
# answer:  {'answer': '实体', 'start': 15, 'end': 17, 'score': 0.9999909400939941}
#
# question:  暗物质这个词的另一个词是什么?
# answer:  {'answer': '实体', 'start': 15, 'end': 17, 'score': 0.9999998807907104}
#
# question:  “暗物质”这个词的词是什么意思?
# answer:  {'answer': '物理名词', 'start': 39, 'end': 43, 'score': 1.0}
#
# full_context:  暗物质[物理名词]的探测最佳时间是：地球满月的时候,云层内
# question:  暗物质的探测最佳时间是什么时候?
# answer:  {'answer': '满月', 'start': 75, 'end': 77, 'score': 1.0}
#
# question:  暗物质探测的最佳时间是什么?
# answer:  {'answer': '满月', 'start': 75, 'end': 77, 'score': 1.0}
#
# question:  地球满月的时候,云层覆盖了什么?
# answer:  {'answer': '暗物质', 'start': 35, 'end': 38, 'score': 0.9999974966049194}
#
# full_context:  黄道十二宫[希腊星座划分]的描述是：十二宫（zodiac）一词来自希腊语zodiakos，意思是动物园。
# question:  十二宫的意思是什么?
# answer:  {'answer': '动物园', 'start': 104, 'end': 107, 'score': 1.0}
#
# question:  希腊语十二宫是什么意思?
# answer:  {'answer': '动物园', 'start': 104, 'end': 107, 'score': 1.0}
#
# question:  黄道十二宫的定义是什么?
# answer:  {'answer': '星座', 'start': 44, 'end': 46, 'score': 1.0}
#
# full_context:  黄道十二宫[希腊星座划分]的中文名是：黄道十二宫
# question:  黄道十二宫的中文名是什么?
# answer:  {'answer': '星座', 'start': 43, 'end': 45, 'score': 1.0}
#
# question:  希腊星座划分的星座是哪个?
# answer:  {'answer': '黄道十二宫', 'start': 35, 'end': 40, 'score': 0.9999995231628418}
#
# question:  什么星座划分了希腊星座?
# answer:  {'answer': '黄道', 'start': 35, 'end': 37, 'score': 1.0}
#
# full_context:  黄道十二宫[希腊星座划分]的外文名是：zodiac
# question:  黄道十二宫的外文名是什么?
# answer:  {'answer': '星座', 'start': 43, 'end': 45, 'score': 0.9999998807907104}
#
# question:  希腊十二宫外文名叫什么?
# answer:  {'answer': '黄道', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  什么星座的外文名字是什么?
# answer:  {}
#
# full_context:  黄道十二宫[希腊星座划分]的希腊语是：zodiakos
# question:  黄道十二宫的希腊语是什么?
# answer:  {}
#
# question:  希腊语叫什么名字?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999998807907104}
#
# question:  什么术语可以用来形容十二宫?
# answer:  {'answer': '黄道十二宫[希腊星座', 'start': 35, 'end': 45, 'score': 0.9999864101409912}
#
# full_context:  黄道十二宫[希腊星座划分]的意思是：动物园
# question:  黄道十二宫的意思是什么?
# answer:  {'answer': '动物园', 'start': 73, 'end': 76, 'score': 1.0}
#
# question:  希腊十二宫是什么意思?
# answer:  {'answer': '星座', 'start': 43, 'end': 45, 'score': 1.0}
#
# question:  什么星座的意思是动物园?
# answer:  {}
#
# full_context:  黄道十二宫[希腊星座划分]的信息是：要用指南针定位
# question:  黄道十二宫是哪个星座
# answer:  {'answer': '希腊星座', 'start': 41, 'end': 45, 'score': 0.99985671043396}
#
# question:  黄道12宫是那个星座
# answer:  {'answer': '希腊星座', 'start': 41, 'end': 45, 'score': 0.9897796511650085}
#
# question:  什么星座是黄道的星座
# answer:  {'answer': '黄道十二宫[希腊星座', 'start': 35, 'end': 45, 'score': 0.9999532699584961}
#
# question:  哪个星座是希腊十二宫
# answer:  {'answer': '希腊星座', 'start': 41, 'end': 45, 'score': 0.999933123588562}
#
# full_context:  原子能的描述是：原子能又称“核能”。
# question:  核能又叫什么?
# answer:  {'answer': '原子能', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  核能的另一个名字是什么?
# answer:  {'answer': '原子能', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  原子能的另一个术语是什么?
# answer:  {'answer': '核能', 'start': 70, 'end': 72, 'score': 1.0}
#
# full_context:  原子能的中文名是：原子能
# question:  原子能的中文名是什么?
# answer:  {'answer': "OrderedDict([('实体序号', ''), ('实体', '原子能", 'start': 0, 'end': 38, 'score': 0.9999855756759644}
#
# question:  原子能这个中文名是什么
# answer:  {'answer': '原子能', 'start': 35, 'end': 38, 'score': 0.9999562501907349}
#
# question:  什么中文名是原子能?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999818801879883}
#
# full_context:  原子能的别名是：核能
# question:  核能的别名是什么?
# answer:  {'answer': '原子能', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  核能叫什么名字?
# answer:  {}
#
# question:  原子能叫什么?
# answer:  {'answer': '核能', 'start': 63, 'end': 65, 'score': 1.0}
#
# full_context:  原子能的解释是：原子核发生变化时释放的能量
# question:  原子核发生变化时释放的能量是什么?
# answer:  {'answer': '原子能', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  原子核变化时释放什么能量?
# answer:  {'answer': '原子能', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  什么能量释放了能量?
# answer:  {'answer': '原子能', 'start': 35, 'end': 38, 'score': 0.9999943971633911}
#
# full_context:  原子能的例如如是：重核裂变和轻核聚变所释放的能量
# question:  重核聚变和轻核聚变释放的能量是什么?
# answer:  {'answer': '原子能', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  原子能的例子是什么?
# answer:  {'answer': '核聚变', 'start': 70, 'end': 73, 'score': 1.0}
#
# full_context:  算术平均数的描述是：算术平均数（ arithmetic mean），又称均值，是统计学中最基本、最常用的一种平均指标，分为简单算术平均数、加权算术平均数。
# question:  算术平均数又被称为什么?
# answer:  {'answer': '均值', 'start': 92, 'end': 94, 'score': 1.0}
#
# question:  算术的平均数又叫什么?
# answer:  {'answer': '均值', 'start': 92, 'end': 94, 'score': 1.0}
#
# question:  计算术平均数的描述是什么?
# answer:  {'answer': '均值', 'start': 92, 'end': 94, 'score': 0.9999994039535522}
#
# full_context:  算术平均数的中文名是：算术平均数
# question:  算术平均数的中文名是什么?
# answer:  {'answer': '算术平均数', 'start': 35, 'end': 40, 'score': 0.9999980926513672}
#
# question:  算术的平均数叫什么?
# answer:  {'answer': '算术平均数', 'start': 35, 'end': 40, 'score': 0.9999997615814209}
#
# question:  计算术平均数是什么?
# answer:  {}
#
# full_context:  算术平均数的外文名是：Arithmetic mean
# question:  算术平均数的外文名是什么?
# answer:  {'answer': 'mean', 'start': 77, 'end': 81, 'score': 0.9999781847000122}
#
# question:  算术的平均数叫什么?
# answer:  {'answer': '算术平均数', 'start': 35, 'end': 40, 'score': 0.9999995231628418}
#
# question:  数学的平均数是什么?
# answer:  {'answer': '算术平均数', 'start': 35, 'end': 40, 'score': 1.0}
#
# full_context:  算术平均数的又称是：均值
# question:  算术平均数的另一个术语是什么?
# answer:  {'answer': '均值', 'start': 65, 'end': 67, 'score': 0.9999966621398926}
#
# question:  算术的平均数叫什么?
# answer:  {'answer': '均值', 'start': 65, 'end': 67, 'score': 1.0}
#
# question:  计算术平均数又称什么?
# answer:  {'answer': '均值', 'start': 65, 'end': 67, 'score': 1.0}
#
# full_context:  算术平均数的分类是：简单算术平均数、加权算术平均数
# question:  算术平均数的分类是什么?
# answer:  {'answer': '简单算术平均数', 'start': 65, 'end': 72, 'score': 1.0}
#
# question:  算术的平均数分类是什么
# answer:  {'answer': '简单算术平均数', 'start': 65, 'end': 72, 'score': 1.0}
#
# question:  算力平均数分类的分类是什么
# answer:  {'answer': '简单算术平均数', 'start': 65, 'end': 72, 'score': 1.0}
#
# full_context:  算术平均数的适用于是：数值型数据
# question:  算术平均数的另一个术语是什么?
# answer:  {'answer': '数值', 'start': 66, 'end': 68, 'score': 0.9999021291732788}
#
# question:  什么类型的数值是数值型的数据?
# answer:  {'answer': '算术平均数', 'start': 35, 'end': 40, 'score': 1.0}
#
# question:  数值型数据是什么?
# answer:  {'answer': '算术平均数', 'start': 35, 'end': 40, 'score': 0.9999997615814209}
#
# full_context:  算术平均数的相关学科是：统计学
# question:  算术平均数的学科是什么?
# answer:  {'answer': '统计学', 'start': 67, 'end': 70, 'score': 1.0}
#
# question:  算术的平均数有哪些?
# answer:  {}
#
# question:  数学的平均数是什么?
# answer:  {'answer': '算术平均数', 'start': 35, 'end': 40, 'score': 1.0}
#
# full_context:  有理数的描述是：有理数是“数与代数”领域中的重要内容之一，在现实生活中有广泛的应用，是继续学习实数、代数式、方程、不等式、直角坐标系、函数、统计等数学内容以及相关学科知识的基础。
# question:  什么是有理数?
# answer:  {'answer': '实数', 'start': 103, 'end': 105, 'score': 0.9999985694885254}
#
# question:  有理数在现实生活中有广泛的应用吗?
# answer:  {'answer': '在现实生活中有广泛的应用', 'start': 85, 'end': 97, 'score': 1.0}
#
# question:  什么类型的有理数是“数与代数”领域中的重要组成部分?
# answer:  {'answer': '实数', 'start': 103, 'end': 105, 'score': 0.9999984502792358}
#
# full_context:  有理数的中文名是：有理数
# question:  有理数的中文名是什么?
# answer:  {'answer': '有理数', 'start': 35, 'end': 38, 'score': 0.9999978542327881}
#
# question:  什么字母代表有理数?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999998807907104}
#
# question:  有理的中文名叫什么?
# answer:  {'answer': '有理数', 'start': 35, 'end': 38, 'score': 1.0}
#
# full_context:  有理数的外文名是：rational number
# question:  理数的外文名是什么?
# answer:  {'answer': '有理数', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  理数外文名叫什么?
# answer:  {'answer': '有理数', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  在理数中用什么术语来形容理数?
# answer:  {'answer': '有理数', 'start': 35, 'end': 38, 'score': 0.999830961227417}
#
# full_context:  有理数的提出者是：毕达哥拉斯
# question:  毕达哥拉斯的理数提出者是谁?
# answer:  {'answer': '毕达哥拉斯', 'start': 64, 'end': 69, 'score': 1.0}
#
# question:  达哥拉斯有理数的提出者是哪个?
# answer:  {'answer': '毕达哥拉斯', 'start': 64, 'end': 69, 'score': 1.0}
#
# question:  谁是第一个提出理数的提倡者?
# answer:  {'answer': '毕达哥拉斯', 'start': 64, 'end': 69, 'score': 1.0}
#
# full_context:  有理数的提出时间是：约公元前580年至公元前500年间
# question:  有理数的提出时间是什么时候?
# answer:  {'answer': '公元前580年', 'start': 66, 'end': 73, 'score': 0.9999680519104004}
#
# question:  公元前500年到500年间有理数的时间是?
# answer:  {}
#
# question:  有多少理数提出时间是公元前580年至500年间?
# answer:  {}
#
# full_context:  有理数的所属范围是：实数
# question:  有理数的所属范围是什么?
# answer:  {'answer': '实体', 'start': 15, 'end': 17, 'score': 1.0}
#
# question:  什么类型的理数是实数的?
# answer:  {'answer': '有理数', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  有理的所属范围是哪些?
# answer:  {'answer': '有理数', 'start': 35, 'end': 38, 'score': 1.0}
#
# full_context:  有理数的应用学科是：数学
# question:  理数的应用学科
# answer:  {'answer': '数学', 'start': 65, 'end': 67, 'score': 1.0}
#
# question:  理数的应用学科
# answer:  {'answer': '数学', 'start': 65, 'end': 67, 'score': 1.0}
#
# question:  数学的应用学科?
# answer:  {'answer': '有理数', 'start': 35, 'end': 38, 'score': 0.9998666048049927}
#
# question:  数学用什么学科
# answer:  {'answer': '应用学科', 'start': 50, 'end': 54, 'score': 0.9999996423721313}
#
# full_context:  扇形图的描述是：扇形图，又称扇形统计图，它是用整个圆表示总数，用圆内各个扇形的大小表示各部分数量占总数的百分数。
# question:  扇形图又被称为什么?
# answer:  {'answer': '扇形统计图', 'start': 71, 'end': 76, 'score': 1.0}
#
# question:  扇形的描述是用什么来表示总数的百分数?
# answer:  {}
#
# question:  在扇形图中,扇形图的描述是什么?
# answer:  {'answer': '大小', 'start': 96, 'end': 98, 'score': 0.9999998807907104}
#
# full_context:  扇形图的中文名是：扇形图
# question:  扇形图的中文名是什么?
# answer:  {'answer': '扇形图', 'start': 35, 'end': 38, 'score': 0.9999963045120239}
#
# question:  画形图的英文名是什么
# answer:  {'answer': '扇形图', 'start': 35, 'end': 38, 'score': 0.9292534589767456}
#
# question:  画图的中文名字是什么?
# answer:  {}
#
# full_context:  扇形图的外文名是：sectordiagram
# question:  扇形图的外文名是什么?
# answer:  {'answer': 'sectordiagram', 'start': 64, 'end': 77, 'score': 0.9997569918632507}
#
# question:  扇形画的外文名字是什么?
# answer:  {'answer': "OrderedDict([('实体序号', ''), ('实体', '扇形图", 'start': 0, 'end': 38, 'score': 0.9999600648880005}
#
# question:  sectordiagram的外文名称是什么?
# answer:  {'answer': '扇形图', 'start': 35, 'end': 38, 'score': 0.9999972581863403}
#
# full_context:  扇形图的别名是：扇形统计图
# question:  扇形图的别名是什么?
# answer:  {'answer': '扇形统计图', 'start': 63, 'end': 68, 'score': 1.0}
#
# question:  扇形的别名叫什么?
# answer:  {'answer': '扇形图', 'start': 35, 'end': 38, 'score': 0.9999942779541016}
#
# question:  什么类型的图有扇形图?
# answer:  {'answer': '统计图', 'start': 65, 'end': 68, 'score': 0.9999977350234985}
#
# full_context:  扇形图的换算公式是：圆心角的度数=百分比×360度
# question:  扇形图的换算公式是什么?
# answer:  {'answer': '圆心角的度数=百分比', 'start': 65, 'end': 75, 'score': 0.9999985694885254}
#
# question:  圆心角的度数是多少?
# answer:  {'answer': '百分比×360度', 'start': 72, 'end': 80, 'score': 0.9999997615814209}
#
# question:  什么形状的换算方法是扇形图的一个换算公式?
# answer:  {'answer': '圆', 'start': 65, 'end': 66, 'score': 0.9999997615814209}
#
# full_context:  扇形图的作用是：使杂乱无章的数据变得清晰透彻
# question:  扇形图的作用是什么?
# answer:  {'answer': '清晰透彻', 'start': 73, 'end': 77, 'score': 0.9999967813491821}
#
# question:  什么类型的图是扇形图的例子?
# answer:  {'answer': '实体', 'start': 15, 'end': 17, 'score': 0.9999480247497559}
#
# question:  除了杂乱无章,扇形图还有什么作用?
# answer:  {'answer': '清晰透彻', 'start': 73, 'end': 77, 'score': 1.0}
#
# full_context:  扇形图的应用学科是：统计学
# question:  什么是扇形图?
# answer:  {'answer': '统计', 'start': 65, 'end': 67, 'score': 0.99986732006073}
#
# question:  扇形图的应用学科是什么?
# answer:  {'answer': '统计学', 'start': 65, 'end': 68, 'score': 1.0}
#
# question:  什么类型的图是扇形图的?
# answer:  {'answer': '统计', 'start': 65, 'end': 67, 'score': 0.9999977350234985}
#
# full_context:  亚健康的描述是：我国很多学者都提出过亚健康的评价方法或诊断标准，其中陈国元、陈青山、刘保延、陶茂萱等学者提出的评价方法或诊断标准具有一定的影响力。
# question:  哪些学者提出过亚健康评价方法或诊断标准?
# answer:  {'answer': '陈国元、陈青山、刘保延、陶茂萱', 'start': 91, 'end': 106, 'score': 1.0}
#
# question:  哪些学者提出了亚健康评价标准?
# answer:  {'answer': '陈国元、陈青山、刘保延、陶茂萱', 'start': 91, 'end': 106, 'score': 1.0}
#
# question:  陈国元、陈青山、刘保延、陶茂萱等学者提出过什么?
# answer:  {}
#
# full_context:  亚健康的别称是：次健康，第三状态，中间状态，游移状态，灰色状态，潜病状态等
# question:  亚健康的别称是什么?
# answer:  {'answer': '次健康', 'start': 63, 'end': 66, 'score': 1.0}
#
# question:  亚健康的别称是什么
# answer:  {'answer': '次健康', 'start': 63, 'end': 66, 'score': 1.0}
#
# question:  亚健康的另一个别称叫什么?
# answer:  {'answer': '次健康', 'start': 63, 'end': 66, 'score': 1.0}
#
# question:  什么类型的健康有亚健康别称?
# answer:  {'answer': '次健康', 'start': 63, 'end': 66, 'score': 0.999984622001648}
#
# full_context:  亚健康的英文名称是：subhealthy
# question:  亚健康的英文名称是什么
# answer:  {'answer': 'subhealthy', 'start': 65, 'end': 75, 'score': 0.9999947547912598}
#
# question:  亚健康英文的英文名称是
# answer:  {'answer': 'subhealthy', 'start': 65, 'end': 75, 'score': 0.9999986886978149}
#
# question:  亚健康的英文名称是什么?
# answer:  {'answer': 'subhealthy', 'start': 65, 'end': 75, 'score': 0.9999889135360718}
#
# full_context:  亚健康的就诊科室是：内科
# question:  亚健康哪家医院最好看
# answer:  {'answer': '内科', 'start': 65, 'end': 67, 'score': 0.987548828125}
#
# question:  亚健康哪个医院最好看?
# answer:  {'answer': '内科', 'start': 65, 'end': 67, 'score': 0.8001194000244141}
#
# question:  亚健康的哪个科最好看
# answer:  {'answer': '内科', 'start': 65, 'end': 67, 'score': 1.0}
#
# full_context:  亚健康的常见症状是：记忆力下降，注意力不集中，.思维缓慢，反应迟钝，不良情绪，不自信，安全感不够
# question:  亚健康有哪些症状
# answer:  {}
#
# question:  亚健康有那些症状
# answer:  {}
#
# question:  什么症状是亚健康有症状
# answer:  {}
#
# question:  哪个健康有症状亚健康
# answer:  {'answer': '亚健康', 'start': 35, 'end': 38, 'score': 0.9995074272155762}
#
# full_context:  亚健康的传染性是：无
# question:  亚健康传染性是什么?
# answer:  {}
#
# question:  亚健康的传染性是什么样的?
# answer:  {}
#
# question:  什么类型的传染性有亚健康?
# answer:  {}
#
# full_context:  过敏性鼻炎的描述是：过敏性鼻炎即变应性鼻炎，是指特应性个体接触变应原后，主要由IgE介导的介质（主要是组胺）释放，并有多种免疫活性细胞和细胞因子等参与的鼻黏膜非感染性炎性疾病。
# question:  过敏性鼻炎的名称是什么?
# answer:  {'answer': '变应性鼻炎', 'start': 73, 'end': 78, 'score': 1.0}
#
# question:  过敏性的鼻炎是什么类型的疾病?
# answer:  {'answer': '变应性鼻炎', 'start': 73, 'end': 78, 'score': 0.9999998807907104}
#
# question:  变应性鼻炎指的是什么?
# answer:  {'answer': '过敏性鼻炎', 'start': 37, 'end': 42, 'score': 1.0}
#
# full_context:  过敏性鼻炎的别称是：变应性鼻炎
# question:  过敏性鼻炎的别称是什么?
# answer:  {'answer': '变应性鼻炎', 'start': 65, 'end': 70, 'score': 1.0}
#
# question:  变应性鼻炎叫什么?
# answer:  {'answer': '过敏性鼻炎', 'start': 35, 'end': 40, 'score': 1.0}
#
# question:  过敏性的鼻炎的另一个术语是什么?
# answer:  {'answer': '变应性鼻炎', 'start': 65, 'end': 70, 'score': 1.0}
#
# full_context:  过敏性鼻炎的英文名称是：allergic rhinitis
# question:  过敏性鼻炎的英文名称是什么?
# answer:  {'answer': '过敏性鼻炎', 'start': 35, 'end': 40, 'score': 0.9999969005584717}
#
# question:  过敏的鼻炎英文名称是什么
# answer:  {'answer': '过敏性鼻炎', 'start': 35, 'end': 40, 'score': 1.0}
#
# question:  哮喘的英文名是什么
# answer:  {}
#
# full_context:  过敏性鼻炎的就诊科室是：耳鼻喉科
# question:  过敏性鼻炎的医院在哪里?
# answer:  {'answer': '耳鼻喉科', 'start': 67, 'end': 71, 'score': 0.9999997615814209}
#
# question:  过敏的鼻炎的诊所叫什么?
# answer:  {'answer': '耳鼻喉科', 'start': 67, 'end': 71, 'score': 0.9999997615814209}
#
# question:  什么医院有过敏性哮喘的诊所?
# answer:  {'answer': '耳鼻喉科', 'start': 67, 'end': 71, 'score': 0.9999911785125732}
#
# full_context:  过敏性鼻炎的多发群体是：老人、过敏体质者
# question:  过敏性鼻炎的多发群体是什么?
# answer:  {'answer': '老人', 'start': 67, 'end': 69, 'score': 1.0}
#
# question:  过敏体质的鼻炎多发群体是哪些?
# answer:  {'answer': '老人', 'start': 67, 'end': 69, 'score': 1.0}
#
# question:  什么类型的鼻炎有过敏性哮喘?
# answer:  {'answer': '过敏性鼻炎', 'start': 35, 'end': 40, 'score': 1.0}
#
# full_context:  过敏性鼻炎的常见病因是：由基因与环境互相作用而诱发
# question:  过敏性鼻炎的常见病因是什么?
# answer:  {'answer': '基因', 'start': 68, 'end': 70, 'score': 1.0}
#
# question:  过敏性的鼻炎的例子是什么?
# answer:  {'answer': '过敏性鼻炎', 'start': 35, 'end': 40, 'score': 0.9999984502792358}
#
# full_context:  过敏性鼻炎的常见症状是：阵发性喷嚏、清水样鼻涕、鼻塞和鼻痒
# question:  过敏性鼻炎的症状是什么?
# answer:  {'answer': '喷嚏', 'start': 70, 'end': 72, 'score': 1.0}
#
# question:  过敏的鼻炎症状有哪些?
# answer:  {'answer': '阵发性喷嚏、清水样鼻涕、鼻塞和鼻痒', 'start': 67, 'end': 84, 'score': 1.0}
#
# question:  什么类型的鼻炎有过敏的症状?
# answer:  {'answer': '过敏性鼻炎', 'start': 35, 'end': 40, 'score': 1.0}
#
# full_context:  糖尿病的描述是：糖尿病是一组以高血糖为特征的代谢性疾病。
# question:  糖尿病的例子是什么?
# answer:  {'answer': '高血糖', 'start': 72, 'end': 75, 'score': 0.9999995231628418}
#
# question:  糖尿病是什么类型的疾病?
# answer:  {'answer': '高血糖', 'start': 72, 'end': 75, 'score': 1.0}
#
# question:  什么类型的疾病是糖尿病的代谢性疾病?
# answer:  {'answer': '高血糖', 'start': 72, 'end': 75, 'score': 1.0}
#
# full_context:  糖尿病的英文名称是：diabetes mellitus，DM
# question:  糖尿病的英文名称是什么?
# answer:  {'answer': '糖尿病', 'start': 35, 'end': 38, 'score': 0.9999818801879883}
#
# question:  糖尿病的另一个名字是什么?
# answer:  {'answer': "OrderedDict([('实体序号', ''), ('实体', '糖尿病", 'start': 0, 'end': 38, 'score': 0.9906743168830872}
#
# question:  dm代表什么?
# answer:  {}
#
# full_context:  糖尿病的就诊科室是：内科，内分泌科
# question:  糖尿病的就诊科是什么
# answer:  {'answer': '内科', 'start': 65, 'end': 67, 'score': 1.0}
#
# question:  糖尿病的诊所是
# answer:  {'answer': '内分泌科', 'start': 68, 'end': 72, 'score': 0.9999984502792358}
#
# question:  糖尿病诊所是哪个
# answer:  {'answer': '内分泌科', 'start': 68, 'end': 72, 'score': 0.9926217794418335}
#
# question:  糖尿病患者的就诊院是哪个
# answer:  {'answer': '内科，内分泌科', 'start': 65, 'end': 72, 'score': 0.9997542500495911}
#
# full_context:  糖尿病的常见症状是：多饮、多尿、多食和体重减轻
# question:  糖尿病的常见症状是什么?
# answer:  {'answer': '多饮、多尿', 'start': 65, 'end': 70, 'score': 1.0}
#
# question:  多饮、多饮和体重减轻的症状有哪些?
# answer:  {'answer': '糖尿病', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  糖尿病常见的症状是什么
# answer:  {'answer': '多饮、多尿', 'start': 65, 'end': 70, 'score': 1.0}
#
# full_context:  糖尿病的传染性是：无
# question:  糖尿病的传染性是什么?
# answer:  {'answer': '糖尿病', 'start': 35, 'end': 38, 'score': 0.9998822212219238}
#
# question:  糖尿病传染性是什么样的?
# answer:  {}
#
# question:  什么类型的糖尿病有传染性?
# answer:  {'answer': "OrderedDict([('实体序号', ''), ('实体', '糖尿病", 'start': 0, 'end': 38, 'score': 0.9990313053131104}
#
# full_context:  膳食纤维的描述是：膳食纤维是一种多糖，它既不能被胃肠道消化吸收，也不能产生能量。
# question:  膳食纤维不能被胃肠道消化,它不能产生什么?
# answer:  {'answer': '能量', 'start': 94, 'end': 96, 'score': 1.0}
#
# question:  什么可以用来消化食物的纤维?
# answer:  {'answer': '膳食纤维', 'start': 37, 'end': 41, 'score': 0.9999997615814209}
#
# question:  食物中的纤维是什么?
# answer:  {'answer': '糖', 'start': 74, 'end': 75, 'score': 1.0}
#
# full_context:  地沟油的描述是：地沟油，泛指在生活中存在的各类劣质油，如回收的食用油、反复使用的炸油等。
# question:  地沟油指的是什么?
# answer:  {'answer': '食用油', 'start': 88, 'end': 91, 'score': 1.0}
#
# question:  什么是地沟油?
# answer:  {'answer': '食用油', 'start': 88, 'end': 91, 'score': 0.9999996423721313}
#
# question:  在生活中存在的各种劣质油中,地沟油被称为什么?
# answer:  {'answer': '食用油', 'start': 88, 'end': 91, 'score': 0.9999998807907104}
#
# full_context:  地沟油的中文名是：地沟油
# question:  地沟油的中文名是什么?
# answer:  {'answer': '地沟油', 'start': 35, 'end': 38, 'score': 0.9999988079071045}
#
# question:  什么词可以用来描述地沟油?
# answer:  {'answer': "OrderedDict([('实体", 'start': 0, 'end': 17, 'score': 0.9966301321983337}
#
# question:  什么是地沟油这个词?
# answer:  {'answer': '中文名', 'start': 50, 'end': 53, 'score': 0.9998898506164551}
#
# full_context:  地沟油的本质是：劣质油
# question:  地沟油的本质是什么?
# answer:  {'answer': '劣质油', 'start': 63, 'end': 66, 'score': 0.9999998807907104}
#
# question:  地沟的本质是啥?
# answer:  {'answer': '地沟油', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  什么类型的油是地沟油?
# answer:  {'answer': '劣质油', 'start': 63, 'end': 66, 'score': 0.9999996423721313}
#
# full_context:  地沟油的来源是：酒店等
# question:  地沟油的来源是什么?
# answer:  {'answer': '酒店', 'start': 63, 'end': 65, 'score': 0.9999997615814209}
#
# question:  除了酒店和酒店,地沟油还包括什么?
# answer:  {'answer': '实体', 'start': 15, 'end': 17, 'score': 1.0}
#
# question:  酒店和酒店的起源是什么?
# answer:  {'answer': '地沟油', 'start': 35, 'end': 38, 'score': 0.9607766270637512}
#
# full_context:  地沟油的危害是：影响身体健康
# question:  地沟油对身体的健康有什么影响?
# answer:  {'answer': '影响身体健康', 'start': 63, 'end': 69, 'score': 0.9998446702957153}
#
# question:  什么类型的油对身体健康有影响
# answer:  {'answer': '地沟油', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  什么毒品对身体健康有什么影响
# answer:  {'answer': '地沟油', 'start': 35, 'end': 38, 'score': 0.9999997615814209}
#
# full_context:  五谷[食物]的描述是：平常俗称的“五谷”所指的五种谷物。
# question:  五谷叫什么?
# answer:  {'answer': '谷物', 'start': 82, 'end': 84, 'score': 1.0}
#
# question:  五谷指的是什么?
# answer:  {'answer': '谷物', 'start': 82, 'end': 84, 'score': 1.0}
#
# question:  什么被称为“五谷”?
# answer:  {'answer': '谷物', 'start': 82, 'end': 84, 'score': 1.0}
#
# full_context:  五谷[食物]的中文名是：五谷
# question:  五谷食物的中文名是什么?
# answer:  {'answer': '五谷', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  五谷的中文名叫什么?
# answer:  {'answer': '五谷[食物', 'start': 35, 'end': 40, 'score': 0.9999977350234985}
#
# question:  食物的中文名字是什么?
# answer:  {'answer': '五谷', 'start': 35, 'end': 37, 'score': 1.0}
#
# full_context:  五谷[食物]的外文名是：whole grains
# question:  五谷的外文名是什么?
# answer:  {'answer': '五谷[食物', 'start': 35, 'end': 40, 'score': 0.9999698400497437}
#
# question:  五谷外文名叫什么?
# answer:  {'answer': '五谷', 'start': 35, 'end': 37, 'score': 0.9999785423278809}
#
# question:  食物的外文名称是什么?
# answer:  {'answer': '五谷', 'start': 35, 'end': 37, 'score': 0.9999996423721313}
#
# full_context:  五谷[食物]的别称是：五谷杂粮
# question:  五谷食物的别名是什么?
# answer:  {'answer': '五谷杂粮', 'start': 66, 'end': 70, 'score': 1.0}
#
# question:  五谷的食物叫什么?
# answer:  {'answer': '五谷杂粮', 'start': 66, 'end': 70, 'score': 1.0}
#
# question:  什么食物叫五谷?
# answer:  {'answer': '五谷杂粮', 'start': 66, 'end': 70, 'score': 1.0}
#
# full_context:  五谷[食物]的主要原料是：无
# question:  五谷食物的主要原料是什么?
# answer:  {'answer': '五谷', 'start': 35, 'end': 37, 'score': 0.9999991655349731}
#
# question:  五谷吃什么食物?
# answer:  {'answer': '五谷', 'start': 35, 'end': 37, 'score': 0.9999680519104004}
#
# question:  什么食物的主要原料是五谷?
# answer:  {'answer': '五谷', 'start': 35, 'end': 37, 'score': 0.999937891960144}
#
# full_context:  五谷[食物]的是否含防腐剂是：否
# question:  五谷的防腐剂是什么
# answer:  {}
#
# question:  五谷吃防腐剂是啥
# answer:  {'answer': '防腐剂', 'start': 56, 'end': 59, 'score': 0.997141420841217}
#
# question:  什么食物防腐剂有啥
# answer:  {'answer': '五谷[食物', 'start': 35, 'end': 40, 'score': 0.9999978542327881}
#
# question:  六谷吃什么防腐剂
# answer:  {'answer': '含', 'start': 55, 'end': 56, 'score': 0.9999972581863403}
#
# full_context:  五谷[食物]的主要营养成分是：蛋白质，淀粉
# question:  五谷的主要营养成分是什么?
# answer:  {'answer': '蛋白质', 'start': 70, 'end': 73, 'score': 1.0}
#
# question:  五谷的营养成分有哪些?
# answer:  {'answer': '蛋白质', 'start': 70, 'end': 73, 'score': 1.0}
#
# question:  在五谷中,蛋白质和淀粉的含义是什么?
# answer:  {'answer': '营养成分', 'start': 55, 'end': 59, 'score': 1.0}
#
# full_context:  五谷[食物]的适宜人群是：所有人群
# question:  五谷吃什么食物好
# answer:  {'answer': '五谷', 'start': 35, 'end': 37, 'score': 0.9999792575836182}
#
# question:  五谷喝什么食物好啊
# answer:  {'answer': '五谷', 'start': 35, 'end': 37, 'score': 0.999920129776001}
#
# question:  六谷吃啥食物好
# answer:  {'answer': '五谷', 'start': 35, 'end': 37, 'score': 0.9999974966049194}
#
# full_context:  五谷[食物]的组成是：稻、黍、稷、麦、豆
# question:  五谷食物的组成部分是什么?
# answer:  {'answer': '稻、黍', 'start': 66, 'end': 69, 'score': 1.0}
#
# question:  五谷的食物中有多少是五谷的组成部分?
# answer:  {'answer': '黍', 'start': 68, 'end': 69, 'score': 1.0}
#
# question:  三谷食物中有多少是由五谷组成的?
# answer:  {}
#
# full_context:  婴儿肥的描述是：婴儿肥就是指已经脱离婴儿时代，但脸看起来还是像婴儿一样肉嘟嘟的，高发于圆脸和鹅蛋脸，绝不会出现于菱形脸、方脸、锥子脸中。
# question:  婴儿肥的例子是什么?
# answer:  {'answer': '鹅蛋脸', 'start': 103, 'end': 106, 'score': 0.9999998807907104}
#
# question:  婴儿肥是什么类型的脸?
# answer:  {'answer': '鹅蛋脸', 'start': 103, 'end': 106, 'score': 1.0}
#
# question:  什么类型的脸有婴儿肥?
# answer:  {'answer': '圆脸和鹅蛋脸', 'start': 100, 'end': 106, 'score': 1.0}
#
# full_context:  婴儿肥的中文名是：婴儿肥
# question:  婴儿肥的中文名是什么?
# answer:  {'answer': '婴儿肥', 'start': 35, 'end': 38, 'score': 0.9999855756759644}
#
# question:  婴儿肥这个中文名叫什么?
# answer:  {'answer': '婴儿肥', 'start': 35, 'end': 38, 'score': 0.9999697208404541}
#
# question:  宝宝肥的中文名字是什么?
# answer:  {'answer': '婴儿肥', 'start': 35, 'end': 38, 'score': 1.0}
#
# full_context:  婴儿肥的外文名是：baby fat
# question:  婴儿肥的外文名是什么?
# answer:  {'answer': 'baby fat', 'start': 64, 'end': 72, 'score': 0.9999856948852539}
#
# question:  婴儿肥外文名叫什么?
# answer:  {'answer': 'baby fat', 'start': 64, 'end': 72, 'score': 0.9999902248382568}
#
# question:  宝宝肥外文名字是什么?
# answer:  {'answer': '婴儿肥', 'start': 35, 'end': 38, 'score': 1.0}
#
# full_context:  婴儿肥的注意是：已经脱离婴儿时代
# question:  婴儿肥的另一个名字是什么?
# answer:  {'answer': '婴儿时代', 'start': 67, 'end': 71, 'score': 0.9999873638153076}
#
# question:  婴儿肥是什么时候脱离婴儿时期的?
# answer:  {'answer': '已经', 'start': 63, 'end': 65, 'score': 0.9999867677688599}
#
# question:  什么类型的肥料已经脱离婴儿时代?
# answer:  {'answer': '婴儿肥', 'start': 35, 'end': 38, 'score': 1.0}
#
# full_context:  婴儿肥的发生部位是：脸部
# question:  婴儿肥的症状
# answer:  {'answer': '脸部', 'start': 65, 'end': 67, 'score': 0.9999161958694458}
#
# question:  婴儿肥症状
# answer:  {'answer': '脸部', 'start': 65, 'end': 67, 'score': 0.9999549388885498}
#
# question:  宝宝肥的症状?
# answer:  {'answer': '肥', 'start': 37, 'end': 38, 'score': 0.9989946484565735}
#
# full_context:  荔波大小七孔的描述是：荔波大小七孔分为小七孔景区和大七孔景区。
# question:  荔波大小七孔分为几个部分?
# answer:  {'answer': "OrderedDict([('实体序号', '18'), ('实体', '荔波大小七", 'start': 0, 'end': 42, 'score': 0.9999994039535522}
#
# question:  荔波的大小七孔有多少个景点
# answer:  {'answer': '18', 'start': 23, 'end': 25, 'score': 0.999998927116394}
#
# question:  荔浦大小七孔有几个景点
# answer:  {}
#
# full_context:  荔波大小七孔的中文名称是：荔波大小七孔
# question:  荔波大小七孔的中文名称是什么?
# answer:  {'answer': '实体', 'start': 15, 'end': 17, 'score': 0.9999997615814209}
#
# question:  荔波的大小七孔中文名称是什么
# answer:  {'answer': '实体', 'start': 15, 'end': 17, 'score': 0.9999992847442627}
#
# full_context:  荔波大小七孔的别名是：荔波七小孔
# question:  荔波七孔的别名
# answer:  {}
#
# question:  荔波7孔别名
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999997615814209}
#
# full_context:  荔波大小七孔的行政区类别是：贵州荔波
# question:  荔波市区有多少个行政区?
# answer:  {'answer': '七', 'start': 39, 'end': 40, 'score': 1.0}
#
# question:  荔波的行政区别是什么
# answer:  {'answer': "行政区类别'), ('值', '贵州荔波", 'start': 53, 'end': 73, 'score': 0.9999998807907104}
#
# full_context:  荔波大小七孔的所属地区是：中国西南
# question:  荔波大小七孔的所在地是哪里?
# answer:  {'answer': '荔波', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  荔波的大小七孔属于哪个地区?
# answer:  {'answer': '中国西南', 'start': 68, 'end': 72, 'score': 1.0}
#
# question:  日本的哪个地区是荔波最大的七孔?
# answer:  {'answer': '中国西南', 'start': 68, 'end': 72, 'score': 0.9987645149230957}
#
# full_context:  荔波大小七孔的政府驻地是：玉屏街道红船社区
# question:  荔波七孔的政府驻地是哪里?
# answer:  {'answer': '玉屏街道', 'start': 68, 'end': 72, 'score': 1.0}
#
# question:  荔波政府驻地在哪里?
# answer:  {'answer': '玉屏街道', 'start': 68, 'end': 72, 'score': 1.0}
#
# question:  红船社区位于荔波的哪个区?
# answer:  {'answer': '玉屏', 'start': 68, 'end': 70, 'score': 1.0}
#
# full_context:  荔波大小七孔的电话区号是：854
# question:  荔波七孔的电话号码
# answer:  {'answer': '854', 'start': 68, 'end': 71, 'score': 0.9999996423721313}
#
# question:  荔波7孔的电话号
# answer:  {'answer': "854')])", 'start': 68, 'end': 75, 'score': 0.9999960660934448}
#
# question:  荔浦七孔电话号码
# answer:  {'answer': '854', 'start': 68, 'end': 71, 'score': 0.9999990463256836}
#
# full_context:  荔波大小七孔的邮政区码是：558400
# question:  荔波的邮政区码
# answer:  {'answer': '558400', 'start': 68, 'end': 74, 'score': 0.9999995231628418}
#
# question:  荔波邮政区的码是
# answer:  {}
#
# question:  荔浦邮政的区码
# answer:  {}
#
# full_context:  荔波大小七孔的地理位置是：贵州西南部
# question:  荔波八孔的地理位置
# answer:  {'answer': '贵州西南部', 'start': 68, 'end': 73, 'score': 1.0}
#
# question:  荔波七孔哪个地理位置
# answer:  {'answer': '贵州西南部', 'start': 68, 'end': 73, 'score': 1.0}
#
# full_context:  荔波大小七孔的面积是：60平方公里
# question:  荔波七孔的面积是多少?
# answer:  {'answer': '60平方公里', 'start': 66, 'end': 72, 'score': 1.0}
#
# question:  荔波的七孔面积是多少平方公里?
# answer:  {'answer': '60', 'start': 66, 'end': 68, 'score': 1.0}
#
# question:  5孔的面积有多大?
# answer:  {}
#
# full_context:  荔波大小七孔的人口是：3400人（2012年）
# question:  荔波大小七孔的人口是多少?
# answer:  {'answer': '3400人', 'start': 66, 'end': 71, 'score': 1.0}
#
# question:  荔波的七孔有多少人?
# answer:  {'answer': '3400人', 'start': 66, 'end': 71, 'score': 1.0}
#
# question:  2012年荔波有多少孔?
# answer:  {'answer': '七孔', 'start': 39, 'end': 41, 'score': 1.0}
#
# full_context:  荔波大小七孔的气候条件是：亚热带湿润性季风气候
# question:  荔波七孔的气候条件是什么?
# answer:  {'answer': '亚热带湿润性季风气候', 'start': 68, 'end': 78, 'score': 1.0}
#
# question:  荔波的气候条件是什么样的?
# answer:  {'answer': '亚热带湿润性季风气候', 'start': 68, 'end': 78, 'score': 1.0}
#
# question:  除了季风,荔波还有什么类型的季风?
# answer:  {'answer': '亚热带湿润性季风气候', 'start': 68, 'end': 78, 'score': 0.9999997615814209}
#
# full_context:  荔波大小七孔的著名景点是：大七孔桥、梦塘、恐怖峡、天生桥
# question:  荔波大小七孔的著名景点是什么?
# answer:  {'answer': '大七孔桥', 'start': 68, 'end': 72, 'score': 1.0}
#
# question:  荔波的大小七孔桥叫什么名字?
# answer:  {'answer': '天生桥', 'start': 80, 'end': 83, 'score': 1.0}
#
# question:  大七孔桥位于荔波的哪个地区?
# answer:  {'answer': '梦塘', 'start': 73, 'end': 75, 'score': 1.0}
#
# full_context:  荔波大小七孔的机场是：贵阳龙洞堡国际机场荔波飞机场
# question:  荔波六孔机场
# answer:  {}
#
# question:  荔波七孔机场
# answer:  {}
#
# full_context:  荔波大小七孔的火车站是：都匀站 都匀东站 麻尾火车站
# question:  荔波六孔的火车站
# answer:  {'answer': '都匀站', 'start': 67, 'end': 70, 'score': 1.0}
#
# question:  荔波七孔的火车站?
# answer:  {'answer': '都匀站', 'start': 67, 'end': 70, 'score': 1.0}
#
# question:  荔浦六孔的车站
# answer:  {'answer': '都匀站', 'start': 67, 'end': 70, 'score': 1.0}
#
# full_context:  荔波大小七孔的车牌代码是：贵J
# question:  荔波车牌号
# answer:  {'answer': '七', 'start': 39, 'end': 40, 'score': 0.9999291896820068}
#
# question:  荔波的车牌号?
# answer:  {}
#
# question:  荔浦车牌号是
# answer:  {}
#
# full_context:  荔波大小七孔的景区级别是：AAAAA级景区
# question:  荔波八孔的等级
# answer:  {'answer': 'AAAAA级景区', 'start': 68, 'end': 76, 'score': 0.9999994039535522}
#
# question:  荔波七孔的级别
# answer:  {'answer': 'AAAAA级景区', 'start': 68, 'end': 76, 'score': 1.0}
#
# question:  荔浦七孔的等级?
# answer:  {'answer': 'AAAAA级景区', 'start': 68, 'end': 76, 'score': 0.9999940395355225}
#
# full_context:  荔波大小七孔的地貌是：中国喀斯特
# question:  荔波的地貌
# answer:  {'answer': '喀斯特', 'start': 68, 'end': 71, 'score': 1.0}
#
# question:  荔波是什么地貌?
# answer:  {'answer': '喀斯特', 'start': 68, 'end': 71, 'score': 1.0}
#
# question:  荔浦是什么地貌
# answer:  {'answer': '喀斯特', 'start': 68, 'end': 71, 'score': 1.0}
#
# full_context:  天妇罗的描述是：天妇罗是日式料理中的油炸食品，用面粉、鸡蛋与水和成浆，将新鲜的鱼虾和时令蔬菜裹上浆放入油锅炸成金黄色。
# question:  天妇罗是用什么材料做的?
# answer:  {'answer': '面粉、鸡蛋', 'start': 81, 'end': 86, 'score': 0.9999996423721313}
#
# question:  在天妇罗中,鱼虾和时令蔬菜在油锅炸成什么颜色?
# answer:  {'answer': '金黄色', 'start': 112, 'end': 115, 'score': 1.0}
#
# question:  什么食物是天妇罗的油炸食品?
# answer:  {'answer': '鱼虾', 'start': 96, 'end': 98, 'score': 1.0}
#
# full_context:  天妇罗的中文名是：天妇罗
# question:  天妇罗的中文名是什么?
# answer:  {'answer': '天妇罗', 'start': 35, 'end': 38, 'score': 0.9999990463256836}
#
# question:  谁的中文名是天妇罗?
# answer:  {'answer': "OrderedDict([('实体序号', ''), ('实体', '天妇罗", 'start': 0, 'end': 38, 'score': 0.9889623522758484}
#
# question:  天妇羅的中文名叫什么?
# answer:  {'answer': '天妇罗', 'start': 35, 'end': 38, 'score': 0.9999994039535522}
#
# full_context:  天妇罗的英文名是：tempura
# question:  天妇罗的英文名是什么?
# answer:  {'answer': 'tempura', 'start': 64, 'end': 71, 'score': 0.9999996423721313}
#
# question:  谁的英文名是天妇罗?
# answer:  {'answer': 'tempura', 'start': 64, 'end': 71, 'score': 0.9988654851913452}
#
# question:  哪个词在天妇罗语中被称为什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999985694885254}
#
# full_context:  天妇罗的主要食材是：海鲜，蔬菜，水果，北极虾
# question:  天妇罗的主要食材是什么?
# answer:  {'answer': '海鲜', 'start': 65, 'end': 67, 'score': 1.0}
#
# question:  天产罗的主要食材有哪些?
# answer:  {'answer': '海鲜，蔬菜，水果，北极虾', 'start': 65, 'end': 77, 'score': 1.0}
#
# question:  海鲜,蔬菜,水果,水果,还有什么?
# answer:  {'answer': '北极虾', 'start': 74, 'end': 77, 'score': 1.0}
#
# full_context:  天妇罗的分类是：日本料理
# question:  天妇罗的分类是什么?
# answer:  {'answer': '日本料理', 'start': 63, 'end': 67, 'score': 1.0}
#
# question:  日本料理的名称是什么?
# answer:  {'answer': '日本料理', 'start': 63, 'end': 67, 'score': 1.0}
#
# question:  哪个国家的料理有天妇罗?
# answer:  {'answer': '日本', 'start': 63, 'end': 65, 'score': 1.0}
#
# full_context:  天妇罗的口味是：油炸食品
# question:  天妇罗口味的口味是什么?
# answer:  {'answer': '油炸食品', 'start': 63, 'end': 67, 'score': 1.0}
#
# question:  什么食物是油炸食品的口味?
# answer:  {'answer': '天妇罗', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  油炸食品是什么口味的?
# answer:  {'answer': '天妇罗', 'start': 35, 'end': 38, 'score': 0.9999988079071045}
#
# full_context:  天妇罗的配料是：面粉、鸡蛋
# question:  天妇罗配料的配料是什么?
# answer:  {'answer': '面粉、鸡蛋', 'start': 63, 'end': 68, 'score': 1.0}
#
# question:  吃天妇罗的配料有哪些?
# answer:  {'answer': '面粉、鸡蛋', 'start': 63, 'end': 68, 'score': 1.0}
#
# question:  什么东西是天妇罗最合适的?
# answer:  {'answer': '鸡蛋', 'start': 66, 'end': 68, 'score': 0.9999972581863403}
#
# full_context:  天妇罗的起源国是：葡萄牙
# question:  天妇罗的起源国是哪里?
# answer:  {'answer': '葡萄牙', 'start': 64, 'end': 67, 'score': 1.0}
#
# question:  葡萄牙的起源国是什么?
# answer:  {'answer': '天妇罗', 'start': 35, 'end': 38, 'score': 0.9999996423721313}
#
# question:  哪个国家的天妇罗起源于葡萄牙?
# answer:  {'answer': '葡萄牙', 'start': 64, 'end': 67, 'score': 1.0}
#
# full_context:  天妇罗的日语假名是：てんぷら　テンプラ
# question:  天妇罗的日语假名是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999996423721313}
#
# question:  日语的假名叫什么?
# answer:  {'answer': '天妇罗', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  天的妇罗日语假名的日语是什么?
# answer:  {'answer': '天妇罗', 'start': 35, 'end': 38, 'score': 1.0}
#
# full_context:  天妇罗的日语名是：天麩羅/天ぷら/天婦羅
# question:  天妇罗的日语名是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999997615814209}
#
# question:  在天妇罗,天妇罗日语名叫什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999998807907104}
#
# question:  日语中天妇罗语的例子是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999997615814209}
#
# full_context:  天妇罗的罗马音是：tenpura
# question:  天妇罗的罗马音叫什么名字?
# answer:  {'answer': 'tenpura', 'start': 64, 'end': 71, 'score': 0.9999995231628418}
#
# question:  罗马音的另一个名字是什么?
# answer:  {'answer': '天妇罗', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  谁唱了天妇罗罗马音?
# answer:  {}
#
# full_context:  热干面的描述是：热干面（Hot dry noodles）是中国十大面条之一，是湖北武汉最出名的小吃之一，有多种做法。
# question:  热干面是啥地方的面条
# answer:  {'answer': '湖北武汉', 'start': 96, 'end': 100, 'score': 1.0}
#
# question:  热干面的什么地方有面条?
# answer:  {'answer': '湖北武汉', 'start': 96, 'end': 100, 'score': 1.0}
#
# question:  什么地方有热干面的面条
# answer:  {'answer': '湖北武汉', 'start': 96, 'end': 100, 'score': 1.0}
#
# full_context:  热干面的中文名是：热干面
# question:  热干面的中文名是什么?
# answer:  {'answer': '热干面', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  热干面中文名是什么
# answer:  {'answer': '热干面', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  什么中文名是热干面?
# answer:  {'answer': '热干面', 'start': 35, 'end': 38, 'score': 0.9999929666519165}
#
# full_context:  热干面的英文名是：Hot dry noodles
# question:  热干面的英文名是什么?
# answer:  {'answer': 'dry noodles', 'start': 68, 'end': 79, 'score': 0.9999979734420776}
#
# question:  热干面英文名叫什么?
# answer:  {'answer': 'dry noodles', 'start': 68, 'end': 79, 'score': 0.9999984502792358}
#
# question:  “热干面”的英文名是什么
# answer:  {'answer': 'dry noodles', 'start': 68, 'end': 79, 'score': 0.9999977350234985}
#
# full_context:  热干面的主要食材是：油拌熟碱面，酱油备食材的名称，萝卜（或榨菜）丁，葱花，芝麻酱，香油，味精，精盐，辣椒油，香辣酱
# question:  热干面最常用的食材是什么?
# answer:  {'answer': '萝卜', 'start': 80, 'end': 82, 'score': 1.0}
#
# question:  辣椒面最常吃的食材是什么
# answer:  {'answer': '萝卜', 'start': 80, 'end': 82, 'score': 0.9999971389770508}
#
# question:  用辣椒面做什么?
# answer:  {'answer': '热干面', 'start': 35, 'end': 38, 'score': 0.9998247027397156}
#
# full_context:  热干面的分类是：早餐，面食，武汉特色小吃
# question:  武汉吃啥小吃
# answer:  {'answer': '热干面', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  武汉吃什么小吃?
# answer:  {'answer': '热干面', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  武汉什么小吃
# answer:  {'answer': '热干面', 'start': 35, 'end': 38, 'score': 1.0}
#
# full_context:  热干面的口味是：咸，鲜，辣，酸。
# question:  热干面的口味是什么?
# answer:  {'answer': '咸', 'start': 63, 'end': 64, 'score': 1.0}
#
# question:  热干面口味的口味是什么样的?
# answer:  {'answer': '咸', 'start': 63, 'end': 64, 'score': 1.0}
#
# question:  在热干面吃什么口味?
# answer:  {'answer': '咸', 'start': 63, 'end': 64, 'score': 1.0}
#
# full_context:  热干面的辅料是：鲜辣味粉、醋、芝麻酱、肉末。
# question:  热干面辅料的辅料是什么?
# answer:  {}
#
# question:  热干面的辅料有哪些?
# answer:  {'answer': '芝麻酱', 'start': 70, 'end': 73, 'score': 1.0}
#
# question:  除了芝麻酱,还有什么辅料可以用来做热干面?
# answer:  {'answer': '肉末', 'start': 74, 'end': 76, 'score': 1.0}
#
# full_context:  热干面的译名是：ReganMian
# question:  热干面的译名是什么?
# answer:  {'answer': '热干面', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  热干面的译名是什么
# answer:  {'answer': '热干面', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  什么字母的译名是热干面的?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 1.0}
#
# full_context:  热干面的荣誉是：中国十大面条首位
# question:  中国十大面条排名
# answer:  {'answer': '首位', 'start': 69, 'end': 71, 'score': 0.9999997615814209}
#
# question:  中国十大面的排名
# answer:  {'answer': '首位', 'start': 69, 'end': 71, 'score': 1.0}
#
# question:  中国的十大面条排行
# answer:  {}
#
# question:  中国最突出的面条
# answer:  {'answer': '中国十大面条', 'start': 63, 'end': 69, 'score': 1.0}
#
# full_context:  热干面的风行地区是：湖北武汉，以及全国各地
# question:  武汉的风行地区
# answer:  {'answer': '湖北武汉', 'start': 65, 'end': 69, 'score': 1.0}
#
# question:  武汉的热干点
# answer:  {'answer': '热干面', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  武汉的热干点是
# answer:  {'answer': '热干面', 'start': 35, 'end': 38, 'score': 0.999969482421875}
#
# question:  武汉热干的地区
# answer:  {'answer': '湖北', 'start': 65, 'end': 67, 'score': 1.0}
#
# full_context:  唐宋古文运动的描述是：唐宋古文运动是指唐代中期以及宋朝提倡古文、反对骈文为特点的文体改革运动。
# question:  唐宋古文运动指的是什么?
# answer:  {'answer': '文体改革运动', 'start': 97, 'end': 103, 'score': 0.9999998807907104}
#
# question:  唐宋的古文运动是什么时候开始的?
# answer:  {'answer': '唐代', 'start': 76, 'end': 78, 'score': 0.9999997615814209}
#
# question:  宋朝的文体改革运动叫什么名字?
# answer:  {'answer': '唐宋古文运动', 'start': 37, 'end': 43, 'score': 1.0}
#
# full_context:  唐宋古文运动的中文名是：唐宋古文运动
# question:  唐宋古文运动的中文名是什么?
# ...
#
# question:  大禹的治水是哪个时期
# answer:  {'answer': '三皇五帝时期', 'start': 74, 'end': 80, 'score': 0.9999608993530273}
#
# full_context:  大禹治水[历史典故]的地点是：黄河流域
# question:  大禹治水的地点是哪里?
# answer:  {'answer': '黄河流域', 'start': 70, 'end': 74, 'score': 1.0}
#
# question:  大禹的治水地点在哪里?
# answer:  {'answer': '黄河流域', 'start': 70, 'end': 74, 'score': 1.0}
#
# question:  黄河流域的另一个名字是什么?
# answer:  {'answer': '大禹治水', 'start': 35, 'end': 39, 'score': 1.0}
#
# full_context:  大禹治水[历史典故]的最后结果是：对洪水进行疏导，治理好的黄河
# question:  大禹治水的最终结果是什么?
# answer:  {'answer': '黄河', 'start': 84, 'end': 86, 'score': 1.0}
#
# question:  大禹的治水结果是什么
# answer:  {'answer': '黄河', 'start': 84, 'end': 86, 'score': 1.0}
#
# question:  清河治水的最后结果是什么
# answer:  {'answer': '黄河', 'start': 84, 'end': 86, 'score': 0.9999995231628418}
#
# full_context:  大禹治水[历史典故]的意义是：中国古代国家历史的开端
# question:  大禹治水的意义是什么?
# answer:  {'answer': '中国古代国家历史的开端', 'start': 70, 'end': 81, 'score': 0.9999997615814209}
#
# question:  中国古代国家历史的开端是什么时候开始的?
# answer:  {'answer': '大禹治水', 'start': 35, 'end': 39, 'score': 0.9999288320541382}
#
# question:  谁治水是中国古代国家的历史的开端?
# answer:  {'answer': '大禹', 'start': 35, 'end': 37, 'score': 1.0}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的描述是：京剧，曾称平剧，是中国五大戏曲剧种之一，腔调以西皮、二黄为主，用胡琴和锣鼓等伴奏，被视为中国国粹，位列中国戏曲三鼎甲“榜首”。
# question:  中国戏剧艺术国粹的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 37, 'end': 39, 'score': 1.0}
#
# question:  中国戏曲三鼎甲“榜首”?
# answer:  {'answer': '京剧', 'start': 37, 'end': 39, 'score': 1.0}
#
# question:  中国五大戏曲剧种之一是什么?
# answer:  {'answer': '京剧', 'start': 37, 'end': 39, 'score': 1.0}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的中文名称是：京剧或平剧
# question:  中国戏剧艺术国粹的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  什么是京剧?
# answer:  {'answer': '平剧', 'start': 82, 'end': 84, 'score': 1.0}
#
# question:  什么类型的戏剧被称为平剧?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的地理标志是：安庆、北京
# question:  中国戏剧艺术国粹的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  中国的戏剧艺术艺术国粹是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  北京的地理标志是什么?
# answer:  {'answer': '安庆', 'start': 79, 'end': 81, 'score': 0.9999998807907104}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的批准时间是：2006年
# question:  中国戏剧艺术国粹的正式批准时间是什么时候?
# answer:  {'answer': '2006年', 'start': 79, 'end': 84, 'score': 1.0}
#
# question:  京剧的批准时间是多久?
# answer:  {'answer': '2006年', 'start': 79, 'end': 84, 'score': 0.9999991655349731}
#
# question:  谁批准了京剧?
# answer:  {}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的非遗级别是：人类非物质文化遗产
# question:  中国戏剧艺术国粹的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  谁是非遗级别的典型代表?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  中国的非遗级别是什么?
# answer:  {'answer': '人类非物质文化遗产', 'start': 79, 'end': 88, 'score': 1.0}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的遗产类别是：传统戏剧
# question:  中国戏剧艺术国粹的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  传统戏剧是什么类型的艺术?
# answer:  {'answer': '中国戏剧艺术', 'start': 38, 'end': 44, 'score': 1.0}
#
# question:  中国的戏剧艺术国的典型代表是什么类型的戏剧?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的遗产编号是：Ⅳ-28
# question:  中国戏剧艺术国粹的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  京剧的遗产编号是多少?
# answer:  {'answer': '28', 'start': 81, 'end': 83, 'score': 1.0}
#
# question:  中国的戏剧艺术国家粹是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的申报地区是：中国京剧院，北京市，天津市等
# question:  中国戏剧艺术国粹的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  中国的京剧院是哪个国家的?
# answer:  {}
#
# question:  中国京剧院的申报地区是哪个?
# answer:  {'answer': '北京', 'start': 85, 'end': 87, 'score': 1.0}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的外文名是：Beijing Opera；Peking Opera
# question:  京剧的外文名是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 0.9999972581863403}
#
# question:  中国戏剧艺术国粹的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  “北京 Opera”的外文名字是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9998168349266052}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的发源地是：安庆市、徽州府
# question:  中国戏剧艺术国粹的发源地是哪里?
# answer:  {'answer': '安庆', 'start': 78, 'end': 80, 'score': 1.0}
#
# question:  哪个城市是京剧艺术的典型代表?
# answer:  {'answer': '安庆', 'start': 78, 'end': 80, 'score': 1.0}
#
# question:  中国的戏剧艺术国的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的时代人物是：程长庚、谭鑫培、梅兰芳
# question:  谁是中国戏剧艺术国粹的典型代表?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  谁是京剧的时代人物?
# answer:  {'answer': '程长庚', 'start': 79, 'end': 82, 'score': 1.0}
#
# question:  京剧是哪个国家的艺术国粹?
# answer:  {'answer': '中国', 'start': 38, 'end': 40, 'score': 1.0}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的针对人群是：京剧爱好者、戏迷
# question:  谁是中国戏剧艺术国粹的典型代表?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  中国戏剧的艺术国粹代表什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  中国的戏剧艺术国家粹的代表是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的意义是：中国国剧、三大国粹之一
# question:  中国戏剧艺术国粹的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  中国国剧、三大国粹之一是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  “中国国剧”这个词的含义是什么?
# answer:  {'answer': '国粹', 'start': 44, 'end': 46, 'score': 1.0}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的起源是：徽剧、昆曲及汉剧
# question:  中国戏剧艺术国粹的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  中国的戏剧艺术国的起源是什么?
# answer:  {'answer': '汉', 'start': 83, 'end': 84, 'score': 0.9980575442314148}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的发展兴盛地是：北京
# question:  中国的戏剧艺术国粹是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  中国戏剧艺术国的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  北京剧的兴盛地是哪里?
# answer:  {'answer': '北京', 'start': 80, 'end': 82, 'score': 1.0}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的主要流派是：谭派、梅派、荀派
# question:  中国戏剧艺术国粹的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  京剧的艺术国粹代表什么?
# answer:  {'answer': '京剧', 'start': 35, 'end': 37, 'score': 1.0}
#
# question:  谁是京剧艺术的典型代表?
# answer:  {'answer': '谭', 'start': 79, 'end': 80, 'score': 1.0}
#
# full_context:  清明节[中华民族的传统节日]的描述是：清明节又叫踏青节，在仲春与暮春之交。
# question:  清明节又叫什么?
# answer:  {'answer': '踏青节', 'start': 81, 'end': 84, 'score': 1.0}
#
# question:  踏青节在仲春和暮春之交的日期是什么时候?
# answer:  {}
#
# question:  中国传统节日的名称是什么?
# answer:  {'answer': '清明节', 'start': 37, 'end': 40, 'score': 1.0}
#
# full_context:  清明节[中华民族的传统节日]的中文名是：清明节
# question:  清明节的中文名是什么?
# answer:  {'answer': '清明节', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  中华民族的传统节日是什么?
# answer:  {'answer': '清明节', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  “清明节”是什么意思?
# answer:  {'answer': '中华民族的传统节日', 'start': 39, 'end': 48, 'score': 1.0}
#
# full_context:  清明节[中华民族的传统节日]的英文名是：Tomb-Sweeping Day
# question:  清明节的英文名是什么?
# answer:  {'answer': "OrderedDict([('实体序号', ''), ('实体', '清明节", 'start': 0, 'end': 38, 'score': 0.9999666213989258}
#
# question:  Tomb-Sweeping Day这个词的英文名字是什么?
# answer:  {}
#
# question:  清明节日的英文名称是什么?
# answer:  {'answer': '清明节', 'start': 35, 'end': 38, 'score': 0.9999992847442627}
#
# full_context:  清明节[中华民族的传统节日]的节日时间是：一般在公历4月5日前后，春分后第15日
# question:  清明节是哪一天?
# answer:  {'answer': '4月5日', 'start': 81, 'end': 85, 'score': 1.0}
#
# question:  清明的节日时间是什么时候?
# answer:  {'answer': '4月5日', 'start': 81, 'end': 85, 'score': 1.0}
#
# question:  在清明节之前,清明节是什么时候开始的?
# answer:  {'answer': '4月5日', 'start': 81, 'end': 85, 'score': 0.9999995231628418}
#
# full_context:  清明节[中华民族的传统节日]的节日类型是：中国传统节日
# question:  清明节是什么类型的节日?
# answer:  {'answer': '中国传统节日', 'start': 76, 'end': 82, 'score': 1.0}
#
# question:  中国传统节日的名称是什么?
# answer:  {'answer': '清明节', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  中国人传统节日的词是什么?
# answer:  {'answer': '清明节', 'start': 35, 'end': 38, 'score': 1.0}
#
# full_context:  清明节[中华民族的传统节日]的流行地区是：中国、越南、韩国
# question:  清明节的流行地区是什么?
# answer:  {'answer': '中国', 'start': 76, 'end': 78, 'score': 1.0}
#
# question:  清明节日的流行地区是哪些?
# answer:  {'answer': '中国', 'start': 76, 'end': 78, 'score': 1.0}
#
# question:  中国人的传统节日是什么?
# answer:  {'answer': '清明节', 'start': 35, 'end': 38, 'score': 1.0}
#
# full_context:  清明节[中华民族的传统节日]的节日起源是：祭祀
# question:  清明节的传统节日是什么?
# answer:  {'answer': '清明节', 'start': 35, 'end': 38, 'score': 0.9999998807907104}
#
# question:  清明节日的起源是什么?
# answer:  {}
#
# question:  “清明节”这个词是什么意思?
# answer:  {'answer': '中华民族的传统节日', 'start': 39, 'end': 48, 'score': 0.9999998807907104}
#
# full_context:  清明节[中华民族的传统节日]的节日活动是：禁火、扫墓、踏青、荡秋千、踢蹴鞠、打马球、插柳
# question:  清明节的传统节日是什么?
# answer:  {'answer': '扫墓', 'start': 79, 'end': 81, 'score': 1.0}
#
# question:  清明节日的节日活动是什么?
# answer:  {'answer': '扫墓', 'start': 79, 'end': 81, 'score': 1.0}
#
# question:  “清明节”这个词是什么?
# answer:  {'answer': '传统节日', 'start': 44, 'end': 48, 'score': 1.0}
#
# full_context:  清明节[中华民族的传统节日]的节日意义是：以扫墓、祭拜等形式纪念祖先
# question:  清明节的节日意义是什么?
# answer:  {'answer': '纪念祖先', 'start': 85, 'end': 89, 'score': 1.0}
#
# question:  清明的节日是什么?
# answer:  {'answer': '清明节', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  “清明节”的节日是怎么来的?
# answer:  {}
#
# full_context:  清明节[中华民族的传统节日]的起源是：山西绵山
# question:  清明节的起源是什么?
# answer:  {'answer': '山西绵山', 'start': 74, 'end': 78, 'score': 0.9999879598617554}
#
# question:  清明节日的起源是哪里?
# answer:  {'answer': '山西', 'start': 74, 'end': 76, 'score': 1.0}
#
# question:  四川的清明节起源于哪里?
# answer:  {'answer': '山西', 'start': 74, 'end': 76, 'score': 1.0}
#
# full_context:  清明节[中华民族的传统节日]的前一个节气是：春分
# question:  清明节的前一个节气是什么?
# answer:  {'answer': '春分', 'start': 77, 'end': 79, 'score': 1.0}
#
# question:  清明的传统节日是什么?
# answer:  {'answer': '清明节', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  “清明节”的节气是什么时候?
# answer:  {'answer': '春分', 'start': 77, 'end': 79, 'score': 0.9999998807907104}
#
# full_context:  清明节[中华民族的传统节日]的后一个节气是：谷雨
# question:  清明节的后果是什么?
# answer:  {'answer': '谷雨', 'start': 77, 'end': 79, 'score': 1.0}
#
# question:  什么节气是清明节的重要组成部分?
# answer:  {'answer': '谷雨', 'start': 77, 'end': 79, 'score': 0.9999998807907104}
#
# question:  清明节日的后果是啥?
# answer:  {'answer': '谷雨', 'start': 77, 'end': 79, 'score': 1.0}
#
# full_context:  七言律诗的描述是：七言律诗是中国传统诗歌的一种体裁，属于近体诗范畴，起源于南朝齐永明时沈约等讲究声律、对偶的新体诗，至初唐沈佺期、宋之问等进一步发展定型，至盛唐杜甫手中成熟。
# question:  七言律诗起源于哪个朝代?
# answer:  {'answer': '唐', 'start': 117, 'end': 118, 'score': 0.9999997615814209}
#
# question:  三言律诗的起源是哪里?
# answer:  {}
#
# question:  七言诗的描述是什么时候开始的?
# answer:  {'answer': '唐', 'start': 117, 'end': 118, 'score': 0.9999970197677612}
#
# full_context:  七言律诗的中文名是：七言律诗
# question:  七言律诗的中文名是什么?
# answer:  {'answer': '七言律诗', 'start': 35, 'end': 39, 'score': 0.9992384910583496}
#
# question:  七名律诗的英文名是什么
# answer:  {'answer': "OrderedDict([('实体序号', ''), ('实体', '七言律诗", 'start': 0, 'end': 39, 'score': 0.9647045731544495}
#
# question:  六言律诗中文名是什么
# answer:  {}
#
# full_context:  七言律诗的简称是：七言律
# question:  七言律诗的简称是什么?
# answer:  {'answer': "OrderedDict([('实体序号', ''), ('实体', '七言律", 'start': 0, 'end': 38, 'score': 0.9999856948852539}
#
# question:  七言诗的简称是啥?
# answer:  {'answer': '七言律诗', 'start': 35, 'end': 39, 'score': 0.9999998807907104}
#
# question:  六言律诗的意思是什么?
# answer:  {'answer': '七言律诗', 'start': 35, 'end': 39, 'score': 0.8630263805389404}
#
# full_context:  七言律诗的简称是：七律
# question:  七律律诗的简称是什么?
# answer:  {'answer': '七言律', 'start': 35, 'end': 38, 'score': 0.9999985694885254}
#
# question:  七律诗的字母是什么?
# answer:  {}
#
# question:  7律诗的意思是什么?
# answer:  {'answer': '七言律诗', 'start': 35, 'end': 39, 'score': 0.9999998807907104}
#
# full_context:  七言律诗的字数是：五十六字
# question:  七言律诗的字数是多少?
# answer:  {'answer': '五十六字', 'start': 64, 'end': 68, 'score': 1.0}
#
# question:  六言律诗字数是多少
# answer:  {'answer': '五十六字', 'start': 64, 'end': 68, 'score': 1.0}
#
# question:  七言语的字数是几
# answer:  {'answer': '五十六字', 'start': 64, 'end': 68, 'score': 1.0}
#
# full_context:  七言律诗的起源年代是：南北朝
# question:  七言律诗起源于哪个朝代?
# answer:  {'answer': '南北朝', 'start': 66, 'end': 69, 'score': 1.0}
#
# question:  七言七言的起源是哪个朝代的?
# answer:  {'answer': '南北朝', 'start': 66, 'end': 69, 'score': 1.0}
#
# question:  五言律诗的起源是什么?
# answer:  {'answer': '南北朝', 'start': 66, 'end': 69, 'score': 0.999998927116394}
#
# full_context:  七言律诗的流行年代是：唐代
# question:  七言律诗的流行年代是什么时候?
# answer:  {'answer': '唐代', 'start': 66, 'end': 68, 'score': 1.0}
#
# question:  七行律诗的典型流行年代是什么?
# answer:  {'answer': '唐代', 'start': 66, 'end': 68, 'score': 1.0}
#
# question:  哪一种律诗最流行的时期是唐代?
# answer:  {'answer': '七言律诗', 'start': 35, 'end': 39, 'score': 1.0}
#
# full_context:  七言律诗的代表作是：《黄鹤楼》《登高》《安定城楼》
# question:  七言律诗的代表作是什么?
# answer:  {'answer': '黄鹤楼', 'start': 66, 'end': 69, 'score': 1.0}
#
# question:  《黄鹤楼》的代表作叫什么名字?
# answer:  {'answer': '黄鹤楼》《登高', 'start': 66, 'end': 73, 'score': 1.0}
#
# question:  七名律诗代表作有哪些?
# answer:  {'answer': '黄鹤楼》《登高》《安定城楼》', 'start': 66, 'end': 80, 'score': 1.0}
#
# full_context:  造纸术[中国历史]的描述是：造纸术是中国四大发明之一，纸是中国古代劳动人民长期经验的积累和智慧的结晶，它是人类文明史上的一项杰出的发明创造。
# question:  造纸术是人类文明史上的哪一种发明?
# answer:  {'answer': '四大发明', 'start': 77, 'end': 81, 'score': 0.9998990297317505}
#
# question:  中国历史上的哪种发明创造了造纸术?
# answer:  {}
#
# question:  中国的哪一种发明是人类文明历史上的杰出的发明?
# answer:  {'answer': '造纸术', 'start': 37, 'end': 40, 'score': 1.0}
#
# full_context:  造纸术[中国历史]的中文名是：造纸术
# question:  造纸术的中文名是什么?
# answer:  {'answer': '造纸术', 'start': 35, 'end': 38, 'score': 0.9999997615814209}
#
# question:  中国历史的造纸术名字是什么?
# answer:  {'answer': "OrderedDict([('实体序号', ''), ('实体', '造纸术", 'start': 0, 'end': 38, 'score': 0.9999860525131226}
#
# question:  “造纸术”这个词是什么意思?
# answer:  {'answer': '中国历史', 'start': 39, 'end': 43, 'score': 0.9999840259552002}
#
# full_context:  造纸术[中国历史]的外文名是：papermaking technology
# question:  造纸术的外文名是什么?
# answer:  {'answer': 'technology', 'start': 82, 'end': 92, 'score': 0.9999985694885254}
#
# question:  中国历史的造纸术叫什么?
# answer:  {}
#
# question:  中国的造纸术是什么?
# answer:  {}
#
# full_context:  造纸术[中国历史]的英文名是：Papermaking technology
# question:  造纸术的英文名是什么?
# answer:  {'answer': 'technology', 'start': 82, 'end': 92, 'score': 0.9999998807907104}
#
# question:  中国历史的造纸术叫什么?
# answer:  {'answer': "OrderedDict([('实体序号', ''), ('实体', '造纸术", 'start': 0, 'end': 38, 'score': 0.9999314546585083}
#
# question:  中国的造纸术语是什么?
# answer:  {'answer': '造纸术', 'start': 35, 'end': 38, 'score': 1.0}
#
# full_context:  造纸术[中国历史]的改进人是：蔡伦
# question:  造纸术的术语是什么?
# answer:  {'answer': '造纸术', 'start': 35, 'end': 38, 'score': 0.999981164932251}
#
# question:  中国历史最古老的造纸术人是谁?
# answer:  {'answer': '蔡伦', 'start': 70, 'end': 72, 'score': 1.0}
#
# question:  中国的造纸术家是谁?
# answer:  {'answer': '蔡伦', 'start': 70, 'end': 72, 'score': 1.0}
#
# full_context:  造纸术[中国历史]的古代原料是：树皮、麻头及敝布、鱼网等
# question:  造纸术的古代原料是什么?
# answer:  {'answer': '树皮', 'start': 71, 'end': 73, 'score': 1.0}
#
# question:  中国历史最古老的造纸材料是什么
# answer:  {'answer': '树皮', 'start': 71, 'end': 73, 'score': 1.0}
#
# question:  中国历史上的造纸术是什么?
# answer:  {}
#
# full_context:  造纸术[中国历史]的古代工艺是：挫、捣、炒、烘
# question:  造纸术的古代工艺是什么?
# answer:  {'answer': '造纸术', 'start': 35, 'end': 38, 'score': 0.9999995231628418}
#
# question:  造纸的古代工艺叫什么?
# answer:  {'answer': '造纸术', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  中国历史的造纸术是什么?
# answer:  {'answer': '造纸术', 'start': 35, 'end': 38, 'score': 0.9999562501907349}
#
# full_context:  造纸术[中国历史]的地位是：中国古代四大发明之一
# question:  中国古代四大发明之一是什么?
# answer:  {'answer': '造纸术', 'start': 35, 'end': 38, 'score': 1.0}
#
# question:  造纸术是什么时候发明的?
# answer:  {'answer': '中国', 'start': 39, 'end': 41, 'score': 0.9995161294937134}
#
# question:  中国古代十大发明之一是造纸术的?
# answer:  {}
#
# full_context:  造纸术[中国历史]的发明时间是：西汉时期
# question:  造纸术的发明时间是什么时候?
# answer:  {'answer': '西汉', 'start': 71, 'end': 73, 'score': 1.0}
#
# question:  中国历史最古老的造纸术是什么?
# answer:  {'answer': "OrderedDict([('实体序号', ''), ('实体', '造纸术", 'start': 0, 'end': 38, 'score': 0.9945064187049866}
#
# question:  中国的造纸术是什么时候发明的?
# answer:  {'answer': '西汉', 'start': 71, 'end': 73, 'score': 1.0}
#
# full_context:  造纸术[中国历史]的改进时期是：东汉时期
# question:  造纸术是什么时候开始的?
# answer:  {'answer': '东汉', 'start': 71, 'end': 73, 'score': 1.0}
#
# question:  中国历史最古老的时期是什么时候?
# answer:  {'answer': '东汉', 'start': 71, 'end': 73, 'score': 0.9986968636512756}
#
# question:  中国的造纸术时期是什么?
# answer:  {'answer': '东汉', 'start': 71, 'end': 73, 'score': 1.0}

# %% [markdown]
# ## 问题生成的json数据格式设计的测试

# %%
# !pip install transformers
# !pip install question_generation
# !pip install torch
# Out:
# Collecting transformers
#   Downloading transformers-4.17.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 31.7 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 5.0 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.63.0)
# Collecting tokenizers!=0.11.3,>=0.11.1
#   Downloading tokenizers-0.11.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 63.1 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 71.6 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 62.4 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.4.0 pyyaml-6.0 sacremoses-0.0.49 tokenizers-0.11.6 transformers-4.17.0
# Collecting question_generation
#   Downloading question_generation-1.0.5-py3-none-any.whl (34 kB)
# Collecting datasets>=1.15.1
#   Downloading datasets-2.0.0-py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 49.9 MB/s
# Requirement already satisfied: transformers>=4.12.5 in /usr/local/lib/python3.7/dist-packages (from question_generation) (4.17.0)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.7/dist-packages (from question_generation) (1.10.0+cu111)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 60.7 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (4.11.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (2.23.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (0.70.12.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (1.21.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (1.3.5)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (6.0.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (4.63.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (0.4.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 45.1 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (21.3)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.2.0-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 72.1 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets>=1.15.1->question_generation) (0.3.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.15.1->question_generation) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.15.1->question_generation) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.15.1->question_generation) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets>=1.15.1->question_generation) (3.0.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.15.1->question_generation) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.15.1->question_generation) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.15.1->question_generation) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.15.1->question_generation) (2021.10.8)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 76.2 MB/s
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers>=4.12.5->question_generation) (0.0.49)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.12.5->question_generation) (0.11.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.12.5->question_generation) (2019.12.20)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.15.1->question_generation) (2.0.12)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 62.0 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.4 MB/s
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.15.1->question_generation) (21.4.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 73.8 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets>=1.15.1->question_generation) (3.7.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets>=1.15.1->question_generation) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets>=1.15.1->question_generation) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets>=1.15.1->question_generation) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.12.5->question_generation) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.12.5->question_generation) (1.1.0)
# Installing collected packages: multidict, frozenlist, yarl, urllib3, asynctest, async-timeout, aiosignal, fsspec, aiohttp, xxhash, responses, datasets, question-generation
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 datasets-2.0.0 frozenlist-1.3.0 fsspec-2022.2.0 multidict-6.0.2 question-generation-1.0.5 responses-0.18.0 urllib3-1.25.11 xxhash-3.0.0 yarl-1.7.2
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.10.0.2)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("algolet/mt5-base-chinese-qg")

model = AutoModelForSeq2SeqLM.from_pretrained("algolet/mt5-base-chinese-qg")

from question_generation import pipeline

# gpu版本
qg = pipeline("question-generation", device="cpu") 

qa = pipeline("question-answering")
# Out:
# Downloading:   0%|          | 0.00/428 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.11M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/7.93M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.17G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/669 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/263k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.21G [00:00<?, ?B/s]

# %% [markdown]
# ### 测试新的数据填充格式

# %%
import json
import csv

filename = './drive/MyDrive/Database/qa-results/split0-diliweizhi-100.json'


with open(filename, 'r') as file:
    test_file = json.load(file)

# test_file.append(x)
# test_file[0]['qa_bank'].append(y)

with open('./drive/MyDrive/Database/split0-diliweizhi.csv', 'r', encoding='utf-8-sig') as csvfile:
    csvReader = csv.DictReader(csvfile)
    i = 0
    for row in csvReader:
        y = {
            '_id':'',
            'text':'',
            'qa_pair':[]}
        i = i + 1
        if i < 101:
            context1 = row['实体']
            context2 = row['属性']
            context3 = row['值']
            full_context = context1 + '的'+ context2 +  '是：'+  context3
            with open(filename, 'w') as file:
                y['_id'] = i
                questions = qg(full_context)
                for q in questions:
                    z = {
                        'q':'',
                         'a':''
                    }
                    y['text'] = full_context
                    answer = qa({
                        'question': str(q),
                        'context': str(row)
                    })
                    print(answer)
                    if answer == {}:
                        pass
                    else:
                        z['q'] = q
                        z['a'] = answer['answer']
                        y['qa_pair'].append(z)
                test_file.append(y)
                json.dump(test_file, file, ensure_ascii=False)
        else: 
            break
# Out:
# {'answer': '浙江省温州市雁荡山', 'start': 63, 'end': 72, 'score': 1.0}
# {'answer': '浙江省温州市雁荡山', 'start': 63, 'end': 72, 'score': 1.0}
# {'answer': '雁荡山', 'start': 69, 'end': 72, 'score': 1.0}
# {'answer': '云步桥', 'start': 64, 'end': 67, 'score': 1.0}
# {'answer': '云步桥', 'start': 64, 'end': 67, 'score': 1.0}
# {'answer': '云步桥', 'start': 64, 'end': 67, 'score': 0.9999997615814209}
# {'answer': '浙江省温州乐清', 'start': 62, 'end': 69, 'score': 1.0}
# {'answer': '浙江省温州乐清', 'start': 62, 'end': 69, 'score': 1.0}
# {'answer': '浙江省温州乐清', 'start': 62, 'end': 69, 'score': 1.0}
# {'answer': '浙江', 'start': 63, 'end': 65, 'score': 1.0}
# {'answer': '浙江省温州', 'start': 63, 'end': 68, 'score': 1.0}
# {'answer': '浙江', 'start': 63, 'end': 65, 'score': 1.0}
# {'answer': '香港', 'start': 38, 'end': 40, 'score': 1.0}
# {}
# {'answer': '新界', 'start': 35, 'end': 37, 'score': 1.0}
# {'answer': '鄂西北', 'start': 67, 'end': 70, 'score': 1.0}
# {}
# {'answer': '鄂西', 'start': 67, 'end': 69, 'score': 1.0}
# {'answer': '内蒙古中西部', 'start': 64, 'end': 70, 'score': 1.0}
# {'answer': '内蒙古中西部', 'start': 64, 'end': 70, 'score': 1.0}
# {'answer': '内蒙古中西部', 'start': 64, 'end': 70, 'score': 1.0}
# {'answer': '四川', 'start': 67, 'end': 69, 'score': 1.0}
# {'answer': '四川', 'start': 67, 'end': 69, 'score': 1.0}
# {}
# {'answer': '中国西南边陲，青藏高原', 'start': 64, 'end': 75, 'score': 0.9999998807907104}
# {'answer': '中国西南边陲，青藏高原', 'start': 64, 'end': 75, 'score': 1.0}
# {'answer': '西南边陲', 'start': 66, 'end': 70, 'score': 1.0}
# {'answer': '江苏', 'start': 39, 'end': 41, 'score': 1.0}
# {'answer': '江苏', 'start': 39, 'end': 41, 'score': 1.0}
# {'answer': '镇江', 'start': 36, 'end': 38, 'score': 1.0}
# {'answer': '江苏南通', 'start': 39, 'end': 43, 'score': 1.0}
# {'answer': '江苏南通', 'start': 39, 'end': 43, 'score': 1.0}
# {'answer': '南通', 'start': 41, 'end': 43, 'score': 1.0}
# {'answer': '江苏', 'start': 39, 'end': 41, 'score': 1.0}
# {'answer': '南通', 'start': 36, 'end': 38, 'score': 1.0}
# {'answer': "OrderedDict([('', '10735'), ('实体', '南通[江苏省", 'start': 0, 'end': 42, 'score': 0.9999961853027344}
# {'answer': '南通', 'start': 36, 'end': 38, 'score': 1.0}
# {'answer': '铁岭', 'start': 66, 'end': 68, 'score': 1.0}
# {'answer': '昌图县', 'start': 69, 'end': 72, 'score': 1.0}
# {'answer': '铁岭', 'start': 66, 'end': 68, 'score': 1.0}
# {'answer': '8844.43米', 'start': 77, 'end': 85, 'score': 1.0}
# {'answer': '珠穆朗玛峰', 'start': 71, 'end': 76, 'score': 1.0}
# {'answer': '珠穆朗玛峰', 'start': 71, 'end': 76, 'score': 1.0}
# {'answer': '-154.31米', 'start': 80, 'end': 88, 'score': 0.9999996423721313}
# {'answer': '吐鲁番', 'start': 71, 'end': 74, 'score': 0.9999992847442627}
# {'answer': '吐鲁番', 'start': 71, 'end': 74, 'score': 1.0}
# {'answer': '河北省', 'start': 65, 'end': 68, 'score': 1.0}
# {'answer': '河北省', 'start': 65, 'end': 68, 'score': 1.0}
# {'answer': '河北省', 'start': 65, 'end': 68, 'score': 1.0}
# {'answer': '湖北省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '湖北省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '湖北省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '湖北省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '浙江', 'start': 66, 'end': 68, 'score': 1.0}
# {'answer': '浙江', 'start': 66, 'end': 68, 'score': 1.0}
# {'answer': '中部', 'start': 69, 'end': 71, 'score': 1.0}
# {'answer': '茅台酒', 'start': 36, 'end': 39, 'score': 0.9999977350234985}
# {'answer': '茅台酒', 'start': 36, 'end': 39, 'score': 1.0}
# {'answer': '茅台', 'start': 36, 'end': 38, 'score': 1.0}
# {'answer': '广东省西南部雷州半岛', 'start': 65, 'end': 75, 'score': 1.0}
# {'answer': '广东', 'start': 65, 'end': 67, 'score': 1.0}
# {'answer': '雷州半岛', 'start': 71, 'end': 75, 'score': 1.0}
# {'answer': '邯郸', 'start': 69, 'end': 71, 'score': 1.0}
# {'answer': '河北省邯郸市西南', 'start': 66, 'end': 74, 'score': 1.0}
# {'answer': '河北省邯郸', 'start': 66, 'end': 71, 'score': 1.0}
# {'answer': '浙江省杭州市西湖区', 'start': 75, 'end': 84, 'score': 1.0}
# {'answer': '西湖区', 'start': 81, 'end': 84, 'score': 1.0}
# {'answer': '浙江杭州', 'start': 40, 'end': 44, 'score': 1.0}
# {'answer': '杭州灵隐寺', 'start': 42, 'end': 47, 'score': 1.0}
# {'answer': '浙江省杭州', 'start': 39, 'end': 44, 'score': 1.0}
# {'answer': '浙江省杭州市', 'start': 39, 'end': 45, 'score': 1.0}
# {'answer': "OrderedDict([('', '13834'), ('实体', '西湖[浙江省杭州市", 'start': 0, 'end': 45, 'score': 0.9999957084655762}
# {}
# {'answer': "OrderedDict([('', '13898'), ('实体', '百慕大", 'start': 0, 'end': 39, 'score': 0.9999985694885254}
# {'answer': '百慕大', 'start': 36, 'end': 39, 'score': 1.0}
# {'answer': '贵阳', 'start': 67, 'end': 69, 'score': 1.0}
# {'answer': '黔灵公园', 'start': 36, 'end': 40, 'score': 0.9999995231628418}
# {'answer': '贵阳市', 'start': 67, 'end': 70, 'score': 0.9999996423721313}
# {'answer': '江苏省无锡市滨湖区马山镇', 'start': 67, 'end': 79, 'score': 1.0}
# {'answer': '江苏省无锡', 'start': 67, 'end': 72, 'score': 1.0}
# {'answer': '江苏省无锡市滨湖区马山镇', 'start': 67, 'end': 79, 'score': 1.0}
# {'answer': '贵州西南部', 'start': 69, 'end': 74, 'score': 1.0}
# {'answer': '贵州西南部', 'start': 69, 'end': 74, 'score': 1.0}
# {'answer': '江苏', 'start': 39, 'end': 41, 'score': 1.0}
# {'answer': '江苏', 'start': 39, 'end': 41, 'score': 1.0}
# {'answer': '江苏省', 'start': 71, 'end': 74, 'score': 1.0}
# {'answer': '湖南湘西', 'start': 41, 'end': 45, 'score': 1.0}
# {'answer': '湖南湘西', 'start': 41, 'end': 45, 'score': 1.0}
# {'answer': '湖南湘西', 'start': 41, 'end': 45, 'score': 1.0}
# {'answer': '富士山', 'start': 71, 'end': 74, 'score': 1.0}
# {'answer': '富士山', 'start': 71, 'end': 74, 'score': 0.9999788999557495}
# {'answer': '富士山', 'start': 71, 'end': 74, 'score': 1.0}
# {'answer': '贵阳市花溪区石板镇', 'start': 66, 'end': 75, 'score': 1.0}
# {'answer': '贵阳市花溪区石板镇', 'start': 66, 'end': 75, 'score': 1.0}
# {'answer': '石板镇', 'start': 72, 'end': 75, 'score': 1.0}
# {'answer': '花溪区石板镇', 'start': 69, 'end': 75, 'score': 1.0}
# {'answer': '贵州省贵阳', 'start': 67, 'end': 72, 'score': 1.0}
# {'answer': '贵州省贵阳市花溪区', 'start': 67, 'end': 76, 'score': 1.0}
# {'answer': '贵州省贵阳', 'start': 67, 'end': 72, 'score': 1.0}
# {'answer': '中原地区', 'start': 65, 'end': 69, 'score': 0.9999994039535522}
# {'answer': '中原地区', 'start': 65, 'end': 69, 'score': 0.9999998807907104}
# {'answer': '豫剧', 'start': 36, 'end': 38, 'score': 0.9999998807907104}
# {}
# {'answer': '杭州市西湖区西湖中部偏南', 'start': 75, 'end': 87, 'score': 1.0}
# {}
# {'answer': '中部偏南', 'start': 83, 'end': 87, 'score': 1.0}
# {}
# {'answer': '老城红旗路', 'start': 69, 'end': 74, 'score': 0.9999998807907104}
# {'answer': '遵义会议会址', 'start': 36, 'end': 42, 'score': 1.0}
# {'answer': '贵州', 'start': 66, 'end': 68, 'score': 1.0}
# {'answer': '贵州中部', 'start': 66, 'end': 70, 'score': 1.0}
# {'answer': '贵州', 'start': 66, 'end': 68, 'score': 1.0}
# {'answer': '马湾海峡', 'start': 80, 'end': 84, 'score': 1.0}
# {}
# {}
# {'answer': '青海省', 'start': 40, 'end': 43, 'score': 1.0}
# {'answer': '青海省', 'start': 40, 'end': 43, 'score': 1.0}
# {'answer': '青海湖', 'start': 36, 'end': 39, 'score': 1.0}
# {'answer': '东海之滨', 'start': 85, 'end': 89, 'score': 1.0}
# {'answer': '东海之滨', 'start': 85, 'end': 89, 'score': 1.0}
# {'answer': '东海之滨', 'start': 85, 'end': 89, 'score': 1.0}
# {'answer': '河南洛阳', 'start': 54, 'end': 58, 'score': 1.0}
# {'answer': '河南洛阳', 'start': 54, 'end': 58, 'score': 1.0}
# {'answer': '河南洛阳', 'start': 54, 'end': 58, 'score': 1.0}
# {'answer': '河南嵩山', 'start': 53, 'end': 57, 'score': 1.0}
# {'answer': '河南嵩山', 'start': 53, 'end': 57, 'score': 1.0}
# {'answer': '河南省郑州市登封市', 'start': 88, 'end': 97, 'score': 1.0}
# {'answer': '北京', 'start': 68, 'end': 70, 'score': 1.0}
# {'answer': '天安门广场', 'start': 36, 'end': 41, 'score': 1.0}
# {'answer': '天安门', 'start': 36, 'end': 39, 'score': 1.0}
# {'answer': '武昌区自由路', 'start': 69, 'end': 75, 'score': 1.0}
# {'answer': '武昌区', 'start': 69, 'end': 72, 'score': 1.0}
# {'answer': '武昌区', 'start': 69, 'end': 72, 'score': 1.0}
# {'answer': '武昌区', 'start': 69, 'end': 72, 'score': 1.0}
# {'answer': '武汉', 'start': 70, 'end': 72, 'score': 1.0}
# {'answer': '武汉市武汉市汉阳区', 'start': 70, 'end': 79, 'score': 1.0}
# {'answer': '硚口区', 'start': 36, 'end': 39, 'score': 0.9999990463256836}
# {'answer': '硚口区', 'start': 36, 'end': 39, 'score': 0.9999998807907104}
# {'answer': '硚口区', 'start': 36, 'end': 39, 'score': 0.9999969005584717}
# {'answer': '硚口区', 'start': 36, 'end': 39, 'score': 0.999997615814209}
# {'answer': '武汉', 'start': 81, 'end': 83, 'score': 1.0}
# {'answer': '黄鹤楼', 'start': 36, 'end': 39, 'score': 1.0}
# {'answer': '湖北省武汉市', 'start': 78, 'end': 84, 'score': 1.0}
# {'answer': '武汉市东部', 'start': 70, 'end': 75, 'score': 1.0}
# {}
# {'answer': '武汉市东部', 'start': 70, 'end': 75, 'score': 1.0}
# {'answer': '京剧', 'start': 36, 'end': 38, 'score': 1.0}
# {'answer': '京剧', 'start': 36, 'end': 38, 'score': 1.0}
# {'answer': '安庆', 'start': 80, 'end': 82, 'score': 0.9999971389770508}
# {'answer': '北京市昌平区', 'start': 66, 'end': 72, 'score': 1.0}
# {}
# {'answer': '北京市昌平区', 'start': 66, 'end': 72, 'score': 1.0}
# {'answer': '中宁县石空镇西北的双龙山南麓', 'start': 68, 'end': 82, 'score': 1.0}
# {'answer': '石空寺石窟', 'start': 36, 'end': 41, 'score': 1.0}
# {'answer': '双龙山', 'start': 77, 'end': 80, 'score': 1.0}
# {'answer': '银川', 'start': 67, 'end': 69, 'score': 1.0}
# {'answer': '银川市兴庆区', 'start': 67, 'end': 73, 'score': 1.0}
# {'answer': '银川市兴庆区', 'start': 67, 'end': 73, 'score': 1.0}
# {'answer': '南亚', 'start': 74, 'end': 76, 'score': 1.0}
# {'answer': '雅鲁藏布江', 'start': 36, 'end': 41, 'score': 1.0}
# {'answer': '南亚', 'start': 74, 'end': 76, 'score': 0.9999998807907104}
# {'answer': '东北中部', 'start': 81, 'end': 85, 'score': 1.0}
# {'answer': '东北中部', 'start': 81, 'end': 85, 'score': 1.0}
# {'answer': '四川', 'start': 87, 'end': 89, 'score': 1.0}
# {'answer': '四川', 'start': 87, 'end': 89, 'score': 1.0}
# {'answer': '峨眉山', 'start': 36, 'end': 39, 'score': 1.0}
# {'answer': '四川省、云南', 'start': 81, 'end': 87, 'score': 1.0}
# {'answer': '四川', 'start': 81, 'end': 83, 'score': 1.0}
# {'answer': '茶马古道', 'start': 36, 'end': 40, 'score': 1.0}
# {'answer': '乌鲁木齐', 'start': 36, 'end': 40, 'score': 1.0}
# {'answer': '乌鲁木齐', 'start': 36, 'end': 40, 'score': 1.0}
# {'answer': '乌鲁木齐', 'start': 36, 'end': 40, 'score': 1.0}
# {'answer': '云南', 'start': 39, 'end': 41, 'score': 1.0}
# {'answer': '云南', 'start': 39, 'end': 41, 'score': 1.0}
# {'answer': "OrderedDict([('', '21853'), ('实体', '丽江[云南省辖地级市", 'start': 0, 'end': 46, 'score': 0.999997615814209}
# {'answer': '广东省广州市', 'start': 40, 'end': 46, 'score': 1.0}
# {'answer': '广东省', 'start': 40, 'end': 43, 'score': 1.0}
# {'answer': '白云区', 'start': 80, 'end': 83, 'score': 1.0}
# {'answer': '陕西', 'start': 74, 'end': 76, 'score': 1.0}
# {'answer': '陕西省', 'start': 74, 'end': 77, 'score': 1.0}
# {'answer': '陕西省渭南市', 'start': 74, 'end': 80, 'score': 1.0}
# {'answer': '贵州', 'start': 40, 'end': 42, 'score': 1.0}
# {'answer': '贵州省铜仁市', 'start': 40, 'end': 46, 'score': 1.0}
# {'answer': '贵州铜仁市', 'start': 77, 'end': 82, 'score': 0.9999467134475708}
# {'answer': '贵州省铜仁市', 'start': 40, 'end': 46, 'score': 1.0}
# {'answer': '陕西', 'start': 39, 'end': 41, 'score': 1.0}
# {'answer': '陕西省', 'start': 39, 'end': 42, 'score': 1.0}
# {}
# {}
# {'answer': '长春', 'start': 36, 'end': 38, 'score': 0.9999998807907104}
# {'answer': '东北平原', 'start': 79, 'end': 83, 'score': 1.0}
# {}
# {'answer': '长春', 'start': 36, 'end': 38, 'score': 0.9999998807907104}
# {'answer': '甘肃省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '甘肃省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '酒泉市', 'start': 42, 'end': 45, 'score': 0.999996542930603}
# {'answer': '四川省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '四川省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '康定', 'start': 36, 'end': 38, 'score': 1.0}
# {'answer': '云南省', 'start': 70, 'end': 73, 'score': 1.0}
# {'answer': '云南', 'start': 70, 'end': 72, 'score': 1.0}
# {'answer': '云南省', 'start': 70, 'end': 73, 'score': 1.0}
# {'answer': '北京市海淀区苏家坨镇', 'start': 73, 'end': 83, 'score': 1.0}
# {'answer': '北京市海淀区苏家坨镇', 'start': 73, 'end': 83, 'score': 1.0}
# {'answer': '中国大陆', 'start': 78, 'end': 82, 'score': 1.0}
# {'answer': '东南沿海', 'start': 82, 'end': 86, 'score': 0.9999998807907104}
# {'answer': "OrderedDict([('', '22203'), ('实体', '台湾", 'start': 0, 'end': 38, 'score': 0.9999974966049194}
# {'answer': '玉山', 'start': 79, 'end': 81, 'score': 1.0}
# {'answer': '玉山', 'start': 79, 'end': 81, 'score': 1.0}
# {'answer': '3952', 'start': 86, 'end': 90, 'score': 1.0}
# {'answer': '福建省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '福建省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '福建省', 'start': 39, 'end': 42, 'score': 0.8121287822723389}
# {'answer': '长城', 'start': 36, 'end': 38, 'score': 1.0}
# {'answer': '长城', 'start': 36, 'end': 38, 'score': 1.0}
# {'answer': '长城', 'start': 36, 'end': 38, 'score': 1.0}
# {'answer': '河南省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '河南省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '河南', 'start': 39, 'end': 41, 'score': 1.0}
# {'answer': '西班牙', 'start': 41, 'end': 44, 'score': 1.0}
# {'answer': '瓦伦西亚', 'start': 36, 'end': 40, 'score': 1.0}
# {'answer': '西班牙第三', 'start': 41, 'end': 46, 'score': 0.9999979734420776}
# {'answer': '九寨沟县', 'start': 74, 'end': 78, 'score': 1.0}
# {'answer': '漳扎镇境内', 'start': 78, 'end': 83, 'score': 1.0}
# {'answer': '意大利半岛', 'start': 72, 'end': 77, 'score': 1.0}
# {'answer': '意大利', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': "OrderedDict([('', '22729'), ('实体', '罗马", 'start': 0, 'end': 38, 'score': 0.9999986886978149}
# {'answer': '22739', 'start': 19, 'end': 24, 'score': 0.9999998807907104}
# {'answer': '意大利首都', 'start': 39, 'end': 44, 'score': 1.0}
# {'answer': "OrderedDict([('', '22739'), ('实体', '罗马", 'start': 0, 'end': 38, 'score': 0.9999982118606567}
# {'answer': '意大利', 'start': 41, 'end': 44, 'score': 1.0}
# {'answer': '佛罗伦萨', 'start': 36, 'end': 40, 'score': 1.0}
# {'answer': '佛罗伦萨', 'start': 36, 'end': 40, 'score': 1.0}
# {'answer': '中国东南', 'start': 65, 'end': 69, 'score': 1.0}
# {'answer': '中国东南', 'start': 65, 'end': 69, 'score': 1.0}
# {'answer': '中国东南', 'start': 65, 'end': 69, 'score': 0.9999978542327881}
# {'answer': '都江堰市', 'start': 90, 'end': 94, 'score': 1.0}
# {'answer': '四川省', 'start': 84, 'end': 87, 'score': 1.0}
# {}
# {}
# {'answer': '北部', 'start': 41, 'end': 43, 'score': 1.0}
# {'answer': '德国北部', 'start': 39, 'end': 43, 'score': 1.0}
# {'answer': '汉堡', 'start': 36, 'end': 38, 'score': 1.0}
# {'answer': '东北', 'start': 81, 'end': 83, 'score': 1.0}
# {'answer': '英格兰', 'start': 41, 'end': 44, 'score': 1.0}
# {'answer': '东北', 'start': 81, 'end': 83, 'score': 1.0}
# {'answer': '苏州', 'start': 66, 'end': 68, 'score': 1.0}
# {'answer': '吴中区', 'start': 69, 'end': 72, 'score': 1.0}
# {'answer': '苏州市', 'start': 66, 'end': 69, 'score': 1.0}
# {'answer': '吴中区', 'start': 69, 'end': 72, 'score': 1.0}
# {'answer': '河南省', 'start': 70, 'end': 73, 'score': 1.0}
# {'answer': '河南', 'start': 70, 'end': 72, 'score': 1.0}
# {'answer': '河南省', 'start': 70, 'end': 73, 'score': 1.0}
# {'answer': '唐山开平区越河乡', 'start': 72, 'end': 80, 'score': 1.0}
# {'answer': '开平', 'start': 74, 'end': 76, 'score': 1.0}
# {'answer': '开平区越河乡', 'start': 74, 'end': 80, 'score': 1.0}
# {'answer': '中国', 'start': 75, 'end': 77, 'score': 1.0}
# {'answer': '珠穆朗玛峰', 'start': 36, 'end': 41, 'score': 1.0}
# {'answer': '中国', 'start': 75, 'end': 77, 'score': 1.0}
# {'answer': '安徽省黄山市黄山区汤口镇', 'start': 88, 'end': 100, 'score': 1.0}
# {'answer': '安徽省', 'start': 88, 'end': 91, 'score': 1.0}
# {'answer': '安徽省', 'start': 88, 'end': 91, 'score': 1.0}
# {'answer': '肇庆市区', 'start': 75, 'end': 79, 'score': 1.0}
# {'answer': '约2公里', 'start': 80, 'end': 84, 'score': 1.0}
# {'answer': '肇庆市区', 'start': 75, 'end': 79, 'score': 1.0}
# {'answer': '浙江', 'start': 73, 'end': 75, 'score': 1.0}
# {'answer': '浙江省杭州市淳安县', 'start': 73, 'end': 82, 'score': 1.0}
# {}
# {'answer': '河南省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '河南省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '河南省地级市', 'start': 39, 'end': 45, 'score': 0.9999988079071045}
# {'answer': '河南省', 'start': 39, 'end': 42, 'score': 0.9999998807907104}
# {'answer': '西藏', 'start': 67, 'end': 69, 'score': 1.0}
# {'answer': '浪卡子县', 'start': 73, 'end': 77, 'score': 1.0}
# {'answer': '西藏', 'start': 67, 'end': 69, 'score': 1.0}
# {'answer': '浪卡子县', 'start': 73, 'end': 77, 'score': 0.9999978542327881}
# {'answer': '辽宁省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '辽宁省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '辽宁省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '河南省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '河南省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '新乡', 'start': 36, 'end': 38, 'score': 1.0}
# {'answer': '山东青岛东部', 'start': 77, 'end': 83, 'score': 1.0}
# {'answer': '山东青岛东部', 'start': 77, 'end': 83, 'score': 1.0}
# {'answer': '山东青岛东部', 'start': 77, 'end': 83, 'score': 1.0}
# {'answer': '云南', 'start': 67, 'end': 69, 'score': 1.0}
# {'answer': '云南', 'start': 67, 'end': 69, 'score': 1.0}
# {'answer': '云南', 'start': 67, 'end': 69, 'score': 1.0}
# {'answer': '北京市', 'start': 81, 'end': 84, 'score': 1.0}
# {'answer': '北京市', 'start': 81, 'end': 84, 'score': 1.0}
# {'answer': '天安门', 'start': 36, 'end': 39, 'score': 1.0}
# {'answer': '东非', 'start': 69, 'end': 71, 'score': 1.0}
# {'answer': '乞力马扎罗', 'start': 36, 'end': 41, 'score': 1.0}
# {'answer': '坦桑尼亚', 'start': 77, 'end': 81, 'score': 1.0}
# {'answer': '布兰德山', 'start': 68, 'end': 72, 'score': 1.0}
# {}
# {'answer': '布兰德山', 'start': 68, 'end': 72, 'score': 1.0}
# {'answer': '俄罗斯', 'start': 73, 'end': 76, 'score': 1.0}
# {'answer': '贝加尔湖', 'start': 36, 'end': 40, 'score': 1.0}
# {'answer': '俄罗斯', 'start': 73, 'end': 76, 'score': 1.0}
# {'answer': '华北平原', 'start': 76, 'end': 80, 'score': 1.0}
# {'answer': '华北平原', 'start': 76, 'end': 80, 'score': 1.0}
# {'answer': '华北平原', 'start': 76, 'end': 80, 'score': 1.0}
# {'answer': '河南', 'start': 39, 'end': 41, 'score': 1.0}
# {'answer': '河南省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '河南省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '河北省', 'start': 39, 'end': 42, 'score': 1.0}
# {'answer': '沧州市', 'start': 42, 'end': 45, 'score': 1.0}
# {'answer': '沧州市', 'start': 42, 'end': 45, 'score': 1.0}

# %%
import re

test_string = 'miahsusd-200'
new_domain = re.match('[(a-zA-Z)]+', test_string).group(0)
print(new_domain)
# Out:
# miahsusd

# %%
answer = {}
if answer == {}:
    print('empty')
else:
    print(answer)
# Out:
# empty

# %%
answer = { "answer": "水溶液",
        "start": 70,
        "end": 73,
        "score": 0.9999912977218628}

print(answer['answer'])
# Out:
# 水溶液

# %%
import json
import csv

filename = 'test8.json'

x = {
    'domain_label':'',
     'qa_bank': [
                 {
                  'id':'',
                  'text':'',
                  'qa_pair':[
                             {

                             }
                  ]
                 }
     ]
}

with open(filename, 'r') as file:
    test_file = json.load(file)

test_file.append(x)

with open('./drive/MyDrive/NLP/NLP_Corpus/small-kg_base-label.csv', 'r', encoding='utf-8-sig') as csvfile:
    csvReader = csv.DictReader(csvfile)
    i = 0
    for row in csvReader:
        i = i + 1
        context1 = row['实体']
        context2 = row['属性']
        context3 = row['值']
        full_context = context1 + '的'+ context2 +  '是：'+  context3
        with open('./test8.json', 'w') as file:
            test_file[0]['domain_label'] = context2
            test_file[0]['qa_bank'][0]['id'] = i
            questions = qg(full_context)
            for q in questions:
                test_file[0]['qa_bank'][0]['text'] = full_context
                answer = qa({
                    'question': str(q),
                    'context': str(row)
                })
                test_file[0]['qa_bank'][0]['qa_pair'][0][q] = answer
            json.dump(test_file, file, ensure_ascii=False)

# %%
with open('test7.json', encoding='utf-8') as fh:
    data = json.load(fh)

print(data)
# Out:
# [{'domain_label': '别称', 'qa_bank': [{'id': 9, 'text': '碳酸氢钠的别称是：小苏打，重碳酸钠，酸式碳酸钠，重曹，Baking Soda', 'qa_pair': [{'电解质溶于水溶液中或在熔融状态下会产生什么?': {'answer': '导电', 'start': 84, 'end': 86, 'score': 0.9999998807907104}, '什么类型的电解质会产生电解质?': {}, '在溶融状态下,电解质能导电什么?': {'answer': '水溶液', 'start': 70, 'end': 73, 'score': 0.9999912977218628}, '电解质的中文名是什么?': {'answer': '电解质', 'start': 35, 'end': 38, 'score': 0.9999974966049194}, '在电解质中,电解质是什么意思?': {}, '什么是电解质?': {}, '电解质的外文名是什么?': {'answer': '电解质', 'start': 35, 'end': 38, 'score': 0.9999980926513672}, '什么外文名是电解质?': {'answer': "OrderedDict([('实体序号', ''), ('实体', '电解质", 'start': 0, 'end': 38, 'score': 0.9995280504226685}, '电解体的外文名字是什么?': {'answer': '电解质', 'start': 35, 'end': 38, 'score': 1.0}, '电解质属性的属性是什么?': {}, '什么属性是电解质的属性?': {}, '化合物的属性是什么': {}, '弱电解质的分类': {}, '强电解质是什么': {'answer': '强电解质、弱电解质', 'start': 63, 'end': 72, 'score': 0.9947358965873718}, '弱的电解质是啥': {}, '弱 电解质叫什么': {}, '碳酸氢钠的化学式是什么?': {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999998807907104}, '碳化氢钠的俗称是什么?': {'answer': '小苏打', 'start': 82, 'end': 85, 'score': 1.0}, 'NaHCO是什么意思?': {'answer': '碳酸氢钠', 'start': 36, 'end': 40, 'score': 0.9999998807907104}, '碳酸氢钠的中文名是什么?': {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}, '碳化氢钠的英文名是什么': {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 0.9999997615814209}, '碳化的氢钠中文名是什么': {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}, '碳酸氢钠的英文名是什么?': {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}, '碳化氢钠英文名是什么': {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}, '碳氢氢钠的中文名是什么': {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}, '碳酸氢钠的别名是什么?': {'answer': '小苏打', 'start': 64, 'end': 67, 'score': 1.0}, '重碳酸钠叫什么?': {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 1.0}, '轻碳酸钠的别称是什么?': {'answer': '碳酸氢钠', 'start': 35, 'end': 39, 'score': 0.9999998807907104}}]}]}]

# %%
filename = 'test4.json'

x = {
    'domain_label':'',
     'qa_bank': [
                 {
                  'id':'',
                  'text':'',
                  'qa_pair':[
                             {

                             }
                  ]
                 }
     ]
}

with open(filename, 'r') as file:
    test_file = json.load(file)

test_file.append(x)
test_file[0]['domain_label'] = '自然科学'
test_file[0]['qa_bank'][0]['id'] = 1
test_file[0]['qa_bank'][0]['text'] = '为什么会打雷下雨，不知道的奥秘万万千千。'
test_file[0]['qa_bank'][0]['qa_pair'][0]['q1'] = 'a1'

with open(filename, 'w') as file:
    json.dump(test_file, file)

# %% [markdown]
# ## 测试JSON append数据

# %%
import json

filename = 'test.json'
data_append = {'name':'yang'}

with open(filename, 'r') as file:
    data = json.load(file)

data.append(data_append)

with open(filename, 'w') as file:
    json.dump(data, file)

# %%
data2_append = {'hometown': 'lianyungang'}
with open(filename, 'r+') as file:
    data = json.load(file)
    data.append(data2_append)
    file.seek(0)
    json.dump(data, file)

# %%
import json

filename = 'test9.json' 

lst = [{'alice': 24, 'bob': 27}]

# Write the initial json object (list of dicts)
with open(filename, mode='w') as file:
    json.dump(lst, file)

# Append the new dict to the list and overwrite whole file
with open(filename, mode='w') as f:
    lst.append({'carl':33})
    json.dump(lst, f)

# %%
filename = 'test9.json'

x = {
    "qa_bank":{

    }
}

with open(filename, 'r') as file:
    data = json.load(file)

data.append(x)

with open(filename, 'w') as file:
    json.dump(data, file, ensure_ascii=False)

# %%
data[0]["q2"] = 'what is your name?'


with open(filename, 'w') as file:
    json.dump(data, file)

# %%
print(data)
# Out:
# [{'qa_bank': {}, 'q1': 'how old are you?', 'q2': 'what is your name?'}]

# %%
data[0]['qa_bank']= {'q1':'test1'}

# %%
print(data[0]['qa_bank'])
# Out:
# test1

# %%
with open(filename, 'w') as file:
    json.dump(data, file)

# %%
data[0]['qa_bank']['q2'] = 'test'

# %%
with open(filename, 'w') as file:
    json.dump(data, file)

# %% [markdown]
# ### 设计问题集的JSON文件格式

# %%
import json
filename = 'test1.json'

x = {
    'domain_label':'',
     'qa_bank': []
}

y = {
    'id':'',
    'text':'',
    'qa_pair':[
                {
                    'q':'',
                    'a':''
                }
    ]
}


with open(filename, 'r') as file:
    data = json.load(file)

data.append(x)
data[0]['qa_bank'].append(y)

print(data)
data[0]['domain_label'] = '自然科学'
data[0]['qa_bank'][0]['id'] = 1
data[0]['qa_bank'][0]['text'] = '为什么会打雷下雨，不知道的奥秘万万千千。'
data[0]['qa_bank'][0]['qa_pair'][0]['q1'] = 'a1'

with open(filename, 'w') as file:
    json.dump(data, file, ensure_ascii=False )
# Out:
# [{'domain_label': '', 'qa_bank': [{'id': '', 'text': '', 'qa_pair': [{}]}]}]

# %%
y = {
    'id':'',
    'text':'',
    'qa_pair':[]
}

z = {
    'q':'',
     'a':''
}

y['id'] = 2
y['text'] = '天天都会有好天气是不可能的。'
z['q'] = '今天天气如何？'
z['a'] = '今天天气不好，在下雨'
y['qa_pair'].append(z)
# data[0]['qa_bank'].append(y)
print(y)
# Out:
# {'id': 2, 'text': '天天都会有好天气是不可能的。', 'qa_pair': [{'q': '今天天气如何？', 'a': '今天天气不好，在下雨'}]}

# %%
z = {
    'q':'',
     'a':''
}
z['q'] = '你今天身体还好吗？'
z['a'] = '我今天好像一点头晕。'
y['qa_pair'].append(z)

print(y)
# Out:
# {'id': 2, 'text': '天天都会有好天气是不可能的。', 'qa_pair': [{'q': '今天天气如何？', 'a': '今天天气不好，在下雨'}, {'q': '你今天身体还好吗？', 'a': '我今天好像一点头晕。'}]}

# %%
y = {
    'id':'',
    'text':'',
    'qa_pair':[
                {

                }
    ]}
data[0]['qa_bank'].append(y)
print(data)
# Out:
# [{'domain_label': '自然科学', 'qa_bank': [{'id': 1, 'text': '为什么会打雷下雨，不知道的奥秘万万千千。', 'qa_pair': [{'q1': 'a1'}]}, {'id': 1, 'text': '为什么会打雷下雨，不知道的奥秘万万千千。', 'qa_pair': [{'q1': 'a1'}]}, {'id': '', 'text': '', 'qa_pair': [{}]}]}]

# %%
data[0]['qa_bank'][1]['id'] = 2
data[0]['qa_bank'][1]['text'] = '天天都会有好天气是不可能的。'
data[0]['qa_bank'][1]['qa_pair'][0]['q2'] = 'a2'

with open(filename, 'w') as file:
    json.dump(data, file, ensure_ascii=False )

# %% [markdown]
# ### 测试csv文件读取及不同column拼接

# %%
import csv

with open('./drive/MyDrive/NLP/NLP_Corpus/kg_base-label.csv', 'r', encoding='utf-8-sig') as csvfile:
    csvReader = csv.DictReader(csvfile)
    for row in csvReader:
        context1 = row['实体']
        context2 = row['属性']
        context3 = row['值']
        full_context = context1 + '、'+ context2 +  '、'+  context3
        with open('./test2.text', 'a') as test_file:
            test_file.write(full_context)
            test_file.write('\n')

# %% [markdown]
# ## 尝试分割大的csv文件

# %%
import pandas as pd
import numpy as np

chunksize = 50000
i=0
df = pd.read_csv("./drive/MyDrive/Database/ownthink_v2.csv")

# %%
chunksize = 50000
i=0

file_num = len(df) // chunksize
print(file_num)

for i in range(10, 100, 1):
    df_file = df[i*chunksize:i*chunksize+49999]
    df_file.to_csv(f'./drive/MyDrive/Database/split/split-ownthink-{i}.csv', encoding='utf-8-sig')

# %%
print(df.head())
# Out:
#      实体   属性                                      值
# 0    胶饴   描述                        别名: 饴糖、畅糖、畅、软糖。
# 1    词条   描述  词条（拼音：cí tiáo）也叫词目，是辞书学用语，指收列的词语及其释文。
# 2    词条   标签                                     文化
# 3  红色食品   描述                红色食品是指食品为红色、橙红色或棕红色的食品。
# 4  红色食品  中文名                                   红色食品

# %% [markdown]
# ## 使用ownthink知识图谱筛选的数据进行问题生成测试
#
# - 属性值：描述
#     - 3650条
# - 属性值：地理位置
#     - 213条

# %%
# !pip install transformers
# !pip install question_generation
# !pip install torch

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("Yangdf/mt5-base-chinese-qg")

model = AutoModelForSeq2SeqLM.from_pretrained("Yangdf/mt5-base-chinese-qg")

from question_generation import pipeline

# gpu版本
qg = pipeline("question-generation", device="cpu") 

qa = pipeline("question-answering")
# Out:
# Downloading:   0%|          | 0.00/420 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/15.6M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/714 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.17G [00:00<?, ?B/s]

# %%
import csv

with open('./drive/MyDrive/Database/split0-miaoshu.csv', 'r', encoding='utf-8-sig') as csvfile:
    csvReader = csv.DictReader(csvfile)
    for row in csvReader:
        context1 = row['实体']
        context2 = row['属性']
        context3 = row['值']
        full_context = context1 + '的'+ context2 +  '是：'+  context3
        with open('./split0-miaoshu.txt', 'a') as test_file:
            test_file.write(full_context)
            test_file.write("\n")
            print('full_context: ', full_context)
            questions = qg(full_context)
            for q in questions:
                test_file.write(q)
                print('question: ', q)
                answer = qa({
                    'question': str(q),
                    'context': str(row)
                })
                test_file.write(str(answer))
                test_file.write("\n")
                print('answer: ', answer, '\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# answer:  {'answer': '陕西', 'start': 77, 'end': 79, 'score': 0.999998927116394}
#
# question:  吴宓是哪个县人?
# answer:  {'answer': '泾阳县', 'start': 80, 'end': 83, 'score': 1.0}
#
# question:  谁是吴宓的父亲?
# answer:  {}
#
# full_context:  按揭[商业术语]的描述是：“按揭”一词是英文“Mortgage”的粤语音译，指以房地产等实物资产或有价证券、契约等作抵押，获得银行贷款并依合同分期付清本息，贷款还清后银行归还抵押物。
# question:  按揭指的是什么?
# answer:  {'answer': '房地产', 'start': 96, 'end': 99, 'score': 1.0}
#
# question:  按揭是什么意思?
# answer:  {'answer': '贷款', 'start': 121, 'end': 123, 'score': 0.9999998807907104}
#
# question:  贷款还清后银行归还什么?
# answer:  {}
#
# full_context:  命题的描述是：在现代哲学、数学、逻辑学、语言学中，命题是指一个判断（陈述）的语义（实际表达的概念），这个概念是可以被定义并观察的现象。
# question:  在现代哲学、数学、逻辑学、语言学和语言学中,命题是什么?
# answer:  {}
#
# question:  什么是命题的定义?
# answer:  {}
#
# question:  什么类型的概念可以被定义并观察?
# answer:  {'answer': '命题', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  极光[自然现象]的描述是：极光（Aurora），是一种绚丽多彩的发光现象，其发生是由于太阳带电粒子流（太阳风）进入地球磁场，在地球南北两极附近地区的高空，夜间出现的灿烂美丽的光辉。
# question:  极光是什么类型的发光现象?
# answer:  {'answer': '带电粒子', 'start': 101, 'end': 105, 'score': 0.9999996423721313}
#
# question:  太阳带电粒子流(太阳风)进入地球磁场的什么地方?
# answer:  {'answer': '地球南北两极', 'start': 119, 'end': 125, 'score': 0.9999990463256836}
#
# question:  极光是什么时候发生的?
# answer:  {'answer': '夜间', 'start': 133, 'end': 135, 'score': 0.9999839067459106}
#
# full_context:  范文澜的描述是：范文澜（1893年11月15日—1969年7月29日），初字芸台，后改字仲澐（另一说字仲潭），浙江绍兴人。
# question:  范文澜的初字叫什么?
# answer:  {'answer': '芸台', 'start': 94, 'end': 96, 'score': 1.0}
#
# question:  范文瀾的初字是什么?
# answer:  {'answer': '芸台', 'start': 94, 'end': 96, 'score': 1.0}
#
# question:  “范文澜”的另一个名字是什么?
# answer:  {'answer': '仲澐（另一说字仲潭', 'start': 100, 'end': 109, 'score': 0.9999294281005859}
#
# full_context:  顾颉刚的描述是：顾诵坤（1893.5.8-1980.12.25），字铭坚，号颉刚；小名双庆，笔名有余毅、铭坚等。
# question:  顾颉刚的字是什么?
# answer:  {'answer': '铭坚', 'start': 90, 'end': 92, 'score': 1.0}
#
# question:  顾诵坤字什么?
# answer:  {'answer': '铭坚', 'start': 90, 'end': 92, 'score': 1.0}
#
# question:  谁的笔名有余毅、铭坚等?
# answer:  {'answer': '顾诵坤', 'start': 64, 'end': 67, 'score': 1.0}
#
# full_context:  穆罕默德的描述是：穆罕默德（阿拉伯语：محمّد‎，拉丁语：Muḥammad；约570年－632年6月8日），全名穆罕默德·本·阿卜杜拉·本·阿卜杜勒·穆塔利·本·哈希姆（Abu al-Qasim Muhammad Ibn Abd Allah Ibn Abd al-Muttalib Ibn Hashim 含意为：受到善良人们高度赞扬的真主的使者和先知）。
# question:  穆罕默德的全名是什么?
# answer:  {'answer': '穆罕默德·本·阿卜杜拉·本·阿卜杜勒·穆塔利·本·哈希姆', 'start': 118, 'end': 146, 'score': 1.0}
#
# question:  谁是第一个被赞扬的真主的真主?
# answer:  {'answer': '穆罕默德', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  什么被认为是忠于善良的真主和先知?
# answer:  {'answer': '穆罕默德', 'start': 36, 'end': 40, 'score': 1.0}
#
# full_context:  涿鹿之战的描述是：涿（zhuō）鹿之战，是说距今大约6500余年前，黄帝部族联合炎帝部族，跟来自东方的蚩尤部族在今河北省张家口市涿鹿县一带（或说，在今天江苏苏北徐州一带，见吕思勉《中国通史》）所进行的一场大战。
# question:  涿鹿之战是什么时候发生的?
# answer:  {}
#
# question:  涿鹿战的描述是什么?
# answer:  {'answer': '涿鹿之战', 'start': 36, 'end': 40, 'score': 0.9999997615814209}
#
# question:  黄帝部族联合炎帝部族在今哪里进行一场大战?
# answer:  {'answer': '张家口', 'start': 116, 'end': 119, 'score': 1.0}
#
# full_context:  悖的描述是：悖是一个汉字，读作bèi，本意是指迷乱、迷惑，引申义是违背、谬误，也指背谬、行不通。
# question:  悖的本意是什么?
# answer:  {'answer': '迷乱、迷惑', 'start': 79, 'end': 84, 'score': 0.9999994039535522}
#
# question:  悖的引申义是什么?
# answer:  {'answer': '违背、谬误', 'start': 89, 'end': 94, 'score': 0.9999996423721313}
#
# question:  bèi是什么意思?
# answer:  {'answer': '迷乱、迷惑', 'start': 79, 'end': 84, 'score': 0.9998635053634644}
#
# full_context:  伊壁鸠鲁悖论的描述是：伊壁鸠鲁悖论：如果是上帝想阻止“恶”而阻止不了，那么上帝就是无能的；如果是上帝能阻止“恶”而不愿阻止，那么上帝就是坏的；如果是上帝既不想阻止也阻止不了“恶”，那么上帝就是既无能又坏；如果是上帝既想阻止又能阻止“恶”，那为什么我们的世界充满了“恶”呢？...
# question:  伊壁鸠鲁悖论的描述是什么?
# answer:  {}
#
# question:  如果是上帝想阻止恶而不愿阻止,那么上帝就是坏的
# answer:  {'answer': '无能', 'start': 97, 'end': 99, 'score': 1.0}
#
# question:  如果一个世界充满了“恶”
# answer:  {'answer': '无能', 'start': 97, 'end': 99, 'score': 0.9999995231628418}
#
# full_context:  百度萧亚轩吧的描述是：百度萧亚轩吧最初建立于2003-11-28，是百度贴吧推出后较早成立的一个贴吧，主要讨论萧亚轩相关内容。
# question:  百度萧亚轩吧最初建立于哪一年?
# answer:  {'answer': '2003', 'start': 78, 'end': 82, 'score': 1.0}
#
# question:  百度萧亚棠吧最初是什么时候建立的?
# answer:  {'answer': '2003', 'start': 78, 'end': 82, 'score': 1.0}
#
# question:  萧亚轩贴吧主要讨论什么内容?
# answer:  {'answer': '萧亚轩', 'start': 38, 'end': 41, 'score': 1.0}
#
# full_context:  哲学范畴的描述是：哲学范畴特点是概括与抽象程度较高的概念，例如物质与精神、信息与能量等。
# question:  哲学范畴的特点是什么?
# answer:  {'answer': '概括与抽象', 'start': 72, 'end': 77, 'score': 1.0}
#
# question:  什么类型的概念是概括与抽象程度较高的概念?
# answer:  {'answer': '哲学范畴', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  哲学的定义是什么?
# answer:  {'answer': '实体', 'start': 30, 'end': 32, 'score': 0.9999940395355225}
#
# full_context:  快门延迟的描述是：相机按下快门，这时相机自动对焦、测光、计算曝光量、选择合适曝光组合进行数据计算和存储处理所需要的时间称为快门延迟。
# question:  快门延迟的描述是什么?
# answer:  {}
#
# question:  相机按下快门时,相机自动对焦、测光、计算曝光量、选择合适曝光组合进行数据计算和处理?
# answer:  {'answer': '快门延迟', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  什么类型的延迟可以用来计算快门?
# answer:  {'answer': '快门延迟', 'start': 36, 'end': 40, 'score': 0.9999996423721313}
#
# full_context:  比尔·盖茨[美国微软公司联合创始人]的描述是：比尔·盖茨（Bill Gates），全名威廉·亨利·盖茨三世，简称比尔或盖茨。
# question:  威廉·亨利·盖茨的全名是什么?
# answer:  {}
#
# question:  比尔·盖茨是哪个公司联合创始人的?
# answer:  {'answer': '微软', 'start': 44, 'end': 46, 'score': 1.0}
#
# question:  谁是微软公司的联合创始人?
# answer:  {'answer': '比尔·盖茨', 'start': 36, 'end': 41, 'score': 1.0}
#
# full_context:  西湖龙井的描述是：西湖龙井，属绿茶，中国十大名茶之一。
# question:  西湖龙井属于什么茶?
# answer:  {'answer': '绿茶', 'start': 71, 'end': 73, 'score': 1.0}
#
# question:  西江龙井属于哪个茶类?
# answer:  {'answer': '绿茶', 'start': 71, 'end': 73, 'score': 1.0}
#
# question:  中国十大名茶之一是什么?
# answer:  {'answer': '西湖龙井', 'start': 36, 'end': 40, 'score': 1.0}
#
# full_context:  仓颉[五月天演唱歌曲]的描述是：《仓颉》是五月天演唱的一首歌曲，由陈信宏作词、石锦航作曲，收录在五月天2011年12月16日发行的专辑《第二人生》中。
# question:  《仓颉》收录于哪一年?
# answer:  {'answer': '2011年', 'start': 107, 'end': 112, 'score': 1.0}
#
# question:  仓颉的专辑叫什么名字?
# answer:  {'answer': '第二人生', 'start': 124, 'end': 128, 'score': 1.0}
#
# question:  谁作曲了仓颉?
# answer:  {'answer': '石锦航', 'start': 95, 'end': 98, 'score': 1.0}
#
# full_context:  X—Y理论的描述是：X—Y理论（Theory X-Theory Y）主要是对人性的根本性理解。
# question:  x—Y理论的描述是什么?
# answer:  {'answer': '实体', 'start': 30, 'end': 32, 'score': 0.9999996423721313}
#
# question:  x-Y理论是什么样的理论?
# answer:  {'answer': '人性的根本性理解', 'start': 94, 'end': 102, 'score': 0.9788731336593628}
#
# question:  什么是X—Y理论?
# answer:  {'answer': '人性的根本性理解', 'start': 94, 'end': 102, 'score': 0.9999948740005493}
#
# full_context:  米哈伊尔·库图佐夫的描述是：米哈伊尔·伊拉里奥诺维奇·库图佐夫（英语：Mikhail Illarionovich Kutuzov；1745年9月16日—1813年4月28日），是塔塔尔族人，是俄罗斯帝国元帅、军事家，由于在战斗中瞎了一只眼睛，故人称”独眼将军“。
# question:  米哈伊尔·伊拉里奥诺维奇·库图佐夫的国籍是什么?
# answer:  {'answer': '俄罗斯', 'start': 152, 'end': 155, 'score': 1.0}
#
# question:  谁是俄罗斯帝国元帅、军事家?
# answer:  {'answer': '库图佐夫', 'start': 41, 'end': 45, 'score': 1.0}
#
# question:  米哈 伊尔·库图斯夫的职业是什么?
# answer:  {'answer': '独眼将军', 'start': 181, 'end': 185, 'score': 1.0}
#
# full_context:  氧气美女[词语]的描述是：一种被喻为“氧气美女”的美女门派横空出世，给时下人们的浮躁情绪带来了一味心灵鸡汤。
# question:  氧气美女的词语是什么?
# answer:  {}
#
# question:  氧气女的词语是怎么来的?
# answer:  {}
#
# question:  什么词语可以用来描述氧气美女?
# answer:  {}
#
# full_context:  启蒙运动[文艺复兴后的又一次思想解放运动]的描述是：启蒙运动（法文：Siècle des Lumières，英文：The Enlightenment，德文：die Aufklärung），指发生在17-18世纪的一场资产阶级和人民大众的反封建，反教会的思想文化运动。
# question:  启蒙运动指的是什么?
# answer:  {}
#
# question:  什么运动指的启蒙运动?
# answer:  {'answer': '思想解放运动', 'start': 50, 'end': 56, 'score': 1.0}
#
# question:  启蒙的法文是什么?
# answer:  {'answer': 'des', 'start': 97, 'end': 100, 'score': 1.0}
#
# full_context:  快门[控制摄影机曝光时间的机件]的描述是：Shutter是快门的英文名称。
# question:  快门的英文名称是什么?
# answer:  {}
#
# question:  什么叫快门?
# answer:  {}
#
# question:  快门是什么?
# answer:  {'answer': '摄影机', 'start': 41, 'end': 44, 'score': 1.0}
#
# full_context:  知识管理[管理学术语]的描述是：知识管理是知识经济时代涌现出来的一种最新管理思想与方法, 它融合了现代信息技术、知识经济理论、企业管理思想和现代管理理念。
# question:  知识管理的概念是什么?
# answer:  {'answer': '知识经济', 'start': 77, 'end': 81, 'score': 0.9999995231628418}
#
# question:  知识管理与现代信息技术结合了什么?
# answer:  {}
#
# question:  什么是知识管理?
# answer:  {'answer': '知识管理是知识经济时代涌现出来的一种最新管理思想与方法', 'start': 72, 'end': 99, 'score': 0.999971866607666}
#
# full_context:  盗汗的描述是：盗汗是中医的一个病证名，是以入睡后汗出异常，醒后汗泄即止为特征的一种病征。
# question:  盗汗的术语是什么?
# answer:  {'answer': '中医的一个病证名', 'start': 66, 'end': 74, 'score': 0.9998948574066162}
#
# question:  盗汗是什么病的例子?
# answer:  {}
#
# question:  什么是盗汗?
# answer:  {}
#
# full_context:  陶喆的描述是：陶喆（David Zee Tao），1969年7月11日出生于香港，台湾创作型男歌手、音乐制作人，毕业于加利福尼亚大学洛杉矶分校。
# question:  陶喆毕业于哪所大学?
# answer:  {'answer': '加利福尼亚大学洛杉矶分校', 'start': 115, 'end': 127, 'score': 1.0}
#
# question:  陶喆的职业是什么?
# answer:  {'answer': '歌手', 'start': 103, 'end': 105, 'score': 1.0}
#
# question:  1969年7月11日,陶喆出生在哪里?
# answer:  {'answer': '香港', 'start': 94, 'end': 96, 'score': 1.0}
#
# full_context:  焦段的描述是：焦段就是指变焦镜头焦距的变化范围。
# question:  焦段的描述是什么?
# answer:  {'answer': '焦距的变化范围', 'start': 72, 'end': 79, 'score': 1.0}
#
# question:  焦段是什么意思?
# answer:  {'answer': '焦距', 'start': 72, 'end': 74, 'score': 1.0}
#
# question:  变焦镜头的焦距变化范围是什么?
# answer:  {'answer': '焦段', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  京剧[中国戏剧艺术国粹的典型代表]的描述是：京剧，曾称平剧，是中国五大戏曲剧种之一，腔调以西皮、二黄为主，用胡琴和锣鼓等伴奏，被视为中国国粹，位列中国戏曲三鼎甲“榜首”。
# question:  中国戏剧艺术国粹的典型代表是什么?
# answer:  {'answer': '京剧', 'start': 36, 'end': 38, 'score': 1.0}
#
# question:  中国戏曲三鼎甲“榜首”?
# answer:  {'answer': '京剧', 'start': 36, 'end': 38, 'score': 1.0}
#
# question:  中国五大戏曲剧种之一是什么?
# answer:  {'answer': '京剧', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  PM项目管理的描述是：PM（Project Manager），项目主管或项目经理，主要负责统筹规划项目进度及产品生命，其工作职能直接对公司高层负责。
# question:  PM项目管理的职责是什么?
# answer:  {'answer': '统筹规划', 'start': 101, 'end': 105, 'score': 1.0}
#
# question:  项目经理的职责是什么
# answer:  {'answer': '统筹规划', 'start': 101, 'end': 105, 'score': 1.0}
#
# question:  PM项目管理的主要职责是什么
# answer:  {'answer': '统筹规划', 'start': 101, 'end': 105, 'score': 1.0}
#
# full_context:  东坡肉的描述是：东坡肉，又名红烧肉、滚肉、东坡焖肉，是眉山和江南地区特色传统名菜。
# question:  东坡肉又被称为什么?
# answer:  {'answer': '红烧肉、滚肉、东坡焖肉', 'start': 70, 'end': 81, 'score': 1.0}
#
# question:  东坡的传统名菜是什么?
# answer:  {'answer': '东坡肉', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  除了东坡肉,东坡肉还叫什么?
# answer:  {'answer': '红烧肉、滚肉、东坡焖肉', 'start': 70, 'end': 81, 'score': 1.0}
#
# full_context:  数码单反相机的描述是：数码单镜反光相机（Digital Single Lens Reflex Camera，常简称为DSLR），简称数码单反相机是一种以数码方式记录成像的照相机。
# question:  数码单反相机的描述是什么?
# answer:  {'answer': '数码单镜反光相机', 'start': 67, 'end': 75, 'score': 0.9999997615814209}
#
# question:  数码单镜反光相机的名称是什么?
# answer:  {'answer': '数码单反相机', 'start': 36, 'end': 42, 'score': 1.0}
#
# question:  DSLR代表什么?
# answer:  {'answer': '数码单反相机', 'start': 36, 'end': 42, 'score': 0.999998927116394}
#
# full_context:  斯德哥尔摩综合征的描述是：斯德哥尔摩综合征，斯德哥尔摩效应，又称斯德哥尔摩症候群或者称为人质情结或人质综合征，是指犯罪的被害者对于犯罪者产生情感，甚至反过来帮助犯罪者的一种情结。
# question:  斯德哥尔摩综合征又被称为什么?
# answer:  {'answer': '人质情结', 'start': 100, 'end': 104, 'score': 1.0}
#
# question:  什么是人质综合征?
# answer:  {'answer': '斯德哥尔摩效应', 'start': 78, 'end': 85, 'score': 0.9999998807907104}
#
# question:  什么类型的综合征指的是犯罪的被害者对犯罪者产生情感?
# answer:  {'answer': '斯德哥尔摩综合征', 'start': 36, 'end': 44, 'score': 1.0}
#
# full_context:  海豚[生活在海洋中的鲸目哺乳动物]的描述是：海豚（学名：Delphinidae）具有齿鲸类典型的形态学性状：纺锤形的身体；单个新月形的呼吸孔；头骨套叠，上颌骨向后扩展与额骨重叠；颅顶偏左的不对称；圆锥形或钉状的齿等。
# question:  海豚是什么形状的身体?
# answer:  {'answer': '纺锤形', 'start': 110, 'end': 113, 'score': 1.0}
#
# question:  海豚的学名是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 1.0}
#
# question:  什么是海豚?
# answer:  {'answer': '哺乳动物', 'start': 48, 'end': 52, 'score': 1.0}
#
# full_context:  自由意志[哲学概念]的描述是：自由意志（Free will）是哲学里面的一个专业概念，理解为意识选择做什么的决定、也就是意志的主动性。
# question:  自由意志是什么?
# answer:  {'answer': '哲学概念', 'start': 41, 'end': 45, 'score': 0.999994158744812}
#
# question:  自由意志的定义是什么?
# answer:  {'answer': '意识选择做什么的决定、也就是意志的主动性', 'start': 102, 'end': 122, 'score': 0.9999915361404419}
#
# question:  “自由意志”这个词是什么?
# answer:  {'answer': '哲学概念', 'start': 41, 'end': 45, 'score': 0.9999997615814209}
#
# full_context:  电子政务[政府运作模式]的描述是： 电子政务是指国家机关在政务活动中，全面应用现代信息技术、网络技术以及办公自动化技术等进行办公、管理和为社会提供公共服务的一种全新的管理模式。
# question:  政府运作模式的名称是什么?
# answer:  {'answer': '电子政务', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  电子政务是指什么?
# answer:  {}
#
# question:  什么是电子政务?
# answer:  {}
#
# full_context:  单镜头反光相机的描述是：单镜头反光式取景照相机，（Single Lens Reflex Camera，缩写为SLR camera）又称作单反相机。
# question:  单镜头反光式取景照相机的缩写是什么?
# answer:  {'answer': 'camera', 'start': 114, 'end': 120, 'score': 0.9999996423721313}
#
# question:  单反相机又叫做什么?
# answer:  {'answer': '单镜头反光式取景照相机', 'start': 68, 'end': 79, 'score': 1.0}
#
# question:  双镜头反光照相机又称作什么?
# answer:  {'answer': '单反相机', 'start': 124, 'end': 128, 'score': 0.986248791217804}
#
# full_context:  归纳推理的描述是：所谓归纳推理，就是根据一类事物的部分对象具有某种性质，推出这类事物的所有对象都具有这种性质的推理，叫做归纳推理（简称归纳）。
# question:  归纳推理的描述是什么?
# answer:  {'answer': '实体', 'start': 30, 'end': 32, 'score': 0.9999998807907104}
#
# question:  推理的另一个术语是什么?
# answer:  {'answer': '归纳推理', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  “归纳”这个词是什么意思?
# answer:  {'answer': '推理', 'start': 38, 'end': 40, 'score': 0.9999996423721313}
#
# full_context:  股票[股份公司发行的所有权凭证]的描述是：股票（stock）是股份公司发行的所有权凭证，是股份公司为筹集资金而发行给各个股东作为持股凭证并借以取得股息和红利的一种有价证券。
# question:  股票的名称是什么?
# answer:  {}
#
# question:  股票的简称是什么?
# answer:  {'answer': 'stock', 'start': 80, 'end': 85, 'score': 0.9999994039535522}
#
# question:  “stock”是什么意思?
# answer:  {'answer': '股票', 'start': 36, 'end': 38, 'score': 1.0}
#
# question:  股份公司发行的所有权凭证是什么?
# answer:  {'answer': '股票', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  SWOT分析法的描述是：SWOT分析法，即态势分析，就是将与研究对象密切相关的各种主要内部优势、劣势和外部的机会和威胁等，通过调查列举出来，并依照矩阵形式排列，然后用系统分析的思想，把各种因素相互匹配起来加以分析，从中得出一系列相应的结论，而结论通常带有一定的决策性。
# question:  SWOT分析法指的是什么?
# answer:  {'answer': '态势分析', 'start': 77, 'end': 81, 'score': 1.0}
#
# question:  SWOT分析法的描述是什么?
# answer:  {'answer': '态势分析', 'start': 77, 'end': 81, 'score': 1.0}
#
# question:  分析法的结论通常带有什么样的决策性?
# answer:  {}
#
# full_context:  亚伯拉罕·林肯[美国第16任总统]的描述是：亚伯拉罕·林肯（英文名：Abraham Lincoln，1809年2月12日－1865年4月15日），美国政治家、思想家，演说家，共和党人，美利坚合众国第16任美国总统，黑人奴隶制的废除者。
# question:  美国第16任总统是谁?
# answer:  {'answer': '林肯', 'start': 41, 'end': 43, 'score': 1.0}
#
# question:  亚伯拉罕·林肯是哪个政党的废除者?
# answer:  {'answer': '共和党', 'start': 143, 'end': 146, 'score': 1.0}
#
# question:  谁是美利坚合众国第16任美国总统?
# answer:  {'answer': '林肯', 'start': 41, 'end': 43, 'score': 1.0}
#
# full_context:  释迦牟尼[佛陀]的描述是：佛教的创立者释迦牟尼（佛陀），是古代中印度迦毗罗卫国的释迦族人，他存在于西元前第一个千年的中期。
# question:  佛教的创立者是谁?
# answer:  {'answer': '释迦牟尼', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  释迦牟尼是什么时候出生的?
# answer:  {'answer': '西元前', 'start': 105, 'end': 108, 'score': 0.9941146969795227}
#
# question:  佛教创立者叫什么名字?
# answer:  {'answer': '释迦牟尼', 'start': 36, 'end': 40, 'score': 1.0}
#
# full_context:  沙尘暴[天气现象]的描述是：沙尘暴 (sand-dust storm) 是沙暴 (sand storm) 和尘暴 (dust storm) 的总称，是荒漠化的标志。
# question:  沙尘暴和尘暴的总称是什么?
# answer:  {'answer': '沙尘暴', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  什么是沙尘暴?
# answer:  {'answer': '荒漠化', 'start': 131, 'end': 134, 'score': 0.9999995231628418}
#
# question:  什么类型的沙尘暴被认为是荒漠化的标志?
# answer:  {}
#
# full_context:  斯巴鲁翼豹的描述是：斯巴鲁impreza翼豹以其卓越的性能在历届wrc世界拉力锦标赛中获得优异的成绩。
# question:  斯巴鲁翼豹在历届世界拉力锦标赛中获得了什么成绩?
# answer:  {}
#
# question:  斯巴尔翼豹在什么比赛中获得了优异的成绩?
# answer:  {'answer': 'wrc世界拉力锦标赛', 'start': 88, 'end': 98, 'score': 1.0}
#
# question:  谁是斯巴鲁的翼豹?
# answer:  {'answer': 'impreza', 'start': 69, 'end': 76, 'score': 0.9998836517333984}
#
# full_context:  比基尼[女性游泳时穿着的泳衣]的描述是：比基尼（Bikini，香港译称为“比坚尼”）一般指女性游泳时穿着的泳衣，即比基尼泳衣，也称“三点式游泳衣”。
# question:  比基尼游泳时穿着的泳衣叫什么名字?
# answer:  {'answer': '比坚尼', 'start': 93, 'end': 96, 'score': 1.0}
#
# question:  在比基尼泳衣中,女性游泳时穿的泳衣被称为什么?
# answer:  {'answer': '比坚尼', 'start': 93, 'end': 96, 'score': 1.0}
#
# question:  除了游泳,比基尼还指的是什么?
# answer:  {'answer': '泳衣', 'start': 48, 'end': 50, 'score': 1.0}
#
# full_context:  克里斯托弗·哥伦布[意大利的著名航海家]的描述是：克里斯托弗·哥伦布（西班牙语：Cristóbal Colón；意大利语：Cristoforo Colombo），1450/1451年秋天－1506年5月20日），探险家、殖民者、航海家，出生于中世纪的热那亚共和国（今意大利西北部）。
# question:  克里斯托弗·哥伦布出生在什么地方?
# answer:  {'answer': '意大利', 'start': 46, 'end': 49, 'score': 1.0}
#
# question:  意大利的著名航海家叫什么名字?
# answer:  {'answer': '哥伦布', 'start': 42, 'end': 45, 'score': 1.0}
#
# question:  谁是意大利著名的航海家?
# answer:  {'answer': '哥伦布', 'start': 42, 'end': 45, 'score': 1.0}
#
# full_context:  中央处理器的描述是：中央处理器（CPU，Central Processing Unit）是一块超大规模的集成电路，是一台计算机的运算核心（Core）和控制核心（ Control Unit）。
# question:  什么是中央处理器?
# answer:  {'answer': '集成电路', 'start': 108, 'end': 112, 'score': 0.9999996423721313}
#
# question:  中央处理器是什么?
# answer:  {}
#
# question:  谁是CPU的运算核心(Core)和控制核心(Control Unit)?
# answer:  {'answer': '中央处理器', 'start': 36, 'end': 41, 'score': 1.0}
#
# full_context:  鲁锦[Windows优化大师、鲁大师开发者]的描述是：鲁锦，男，现居中国，毕业于四川大学无线电系，是一名软件系统工程师。
# question:  鲁锦的职业是什么?
# answer:  {'answer': '软件系统工程师', 'start': 108, 'end': 115, 'score': 1.0}
#
# question:  鲁锦毕业于哪所大学?
# answer:  {'answer': '四川大学', 'start': 96, 'end': 100, 'score': 1.0}
#
# question:  Windows优化大师、鲁大师开发者是谁?
# answer:  {'answer': '鲁锦', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  斗鱼TV的描述是：斗鱼TV是一家弹幕式直播分享网站，为用户提供视频直播和赛事直播服务。
# question:  斗鱼直播的例子是什么?
# answer:  {}
#
# question:  斗鱼电视的描述是什么?
# answer:  {'answer': '弹幕式直播分享网站', 'start': 72, 'end': 81, 'score': 0.999998927116394}
#
# question:  “斗鱼直播”这个词是什么?
# answer:  {'answer': '弹幕式直播分享网站', 'start': 72, 'end': 81, 'score': 1.0}
#
# full_context:  折子戏[戏剧行术语]的描述是：折子戏－－顾名思义，它是针对本戏而言的，它是本戏里的一折，或是一出。
# question:  折子戏的描述是什么?
# answer:  {'answer': "OrderedDict([('', '20862'), ('实体', '折子戏[戏剧", 'start': 0, 'end': 42, 'score': 0.9999886751174927}
#
# question:  折子的戏叫什么?
# answer:  {'answer': '折子戏', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  什么是折子戏?
# answer:  {'answer': '戏剧', 'start': 40, 'end': 42, 'score': 0.9999423027038574}
#
# full_context:  仙剑奇侠传[《仙剑奇侠传》第一代游戏]的描述是：《仙剑奇侠传》是由大宇资讯所制作的一款国产单机中文角色扮演电脑游戏。
# question:  仙剑奇侠传是哪个公司制作的?
# answer:  {'answer': '大宇资讯', 'start': 89, 'end': 93, 'score': 1.0}
#
# question:  仙剑之传第一代游戏是什么?
# answer:  {'answer': '仙剑奇侠传', 'start': 36, 'end': 41, 'score': 1.0}
#
# question:  《仙剑奇俠传》第一代游戏是哪个公司开发的?
# answer:  {'answer': '大宇资讯', 'start': 89, 'end': 93, 'score': 1.0}
#
# full_context:  夫妻肺片的描述是：夫妻肺片（英文名：Sliced Beef and Ox Tongue in Chili Sauce；Mr and Mrs Smith）是一道四川成都名菜，由郭朝华、张田政夫妻创制而成。
# question:  夫妻肺片的英文名是什么?
# answer:  {'answer': 'Sliced Beef and Ox Tongue in', 'start': 74, 'end': 102, 'score': 0.9999924898147583}
#
# question:  谁创制了夫妻肺片?
# answer:  {'answer': '郭朝华', 'start': 143, 'end': 146, 'score': 1.0}
#
# question:  家庭肺片是由谁创制的?
# answer:  {'answer': '郭朝华', 'start': 143, 'end': 146, 'score': 1.0}
#
# full_context:  普利策奖的描述是：普利策奖也称为普利策新闻奖。
# question:  普利策新闻奖的另一个名字是什么?
# answer:  {'answer': '普利策奖', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  什么类型的新闻奖被称为普利策奖?
# answer:  {'answer': '新闻奖', 'start': 75, 'end': 78, 'score': 0.9999971389770508}
#
# question:  哪个奖被称为什么?
# answer:  {'answer': '普利策奖', 'start': 36, 'end': 40, 'score': 1.0}
#
# full_context:  K金的描述是：K金（或开金）是黄金与其他金属熔合而成的合金。
# question:  K金的另一个术语是什么?
# answer:  {'answer': '开金', 'start': 67, 'end': 69, 'score': 1.0}
#
# question:  K金是什么?
# answer:  {'answer': '黄金', 'start': 71, 'end': 73, 'score': 1.0}
#
# question:  除了金,还有什么金属在K金中熔合?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999957084655762}
#
# full_context:  口水鸡的描述是：口水鸡是中国四川传统特色菜肴，属于川菜系中的凉菜，佐料丰富，集麻辣鲜香嫩爽于一身。
# question:  口水鸡的佐料丰富,佐料丰富?
# answer:  {'answer': '麻辣', 'start': 95, 'end': 97, 'score': 1.0}
#
# question:  口水鸭的佐料多样,佐料多样的口水鸡是什么?
# answer:  {'answer': '凉菜，佐料丰富，集麻辣', 'start': 86, 'end': 97, 'score': 0.9999651908874512}
#
# question:  四川口水鸡属于什么菜系?
# answer:  {'answer': '川菜', 'start': 81, 'end': 83, 'score': 1.0}
#
# question:  成都口水鸡是哪个菜系的菜肴?
# answer:  {'answer': '川菜', 'start': 81, 'end': 83, 'score': 1.0}
#
# full_context:  热辐射的描述是：热辐射，物体由于具有温度而辐射电磁波的现象。
# question:  热辐射的例子是什么?
# answer:  {}
#
# question:  什么物体因温度而辐射电磁波而辐射?
# answer:  {'answer': '实体', 'start': 30, 'end': 32, 'score': 1.0}
#
# question:  温度引起的辐射是什么?
# answer:  {'answer': '电磁波', 'start': 79, 'end': 82, 'score': 1.0}
#
# full_context:  羊蝎子的描述是：羊蝎子就是带里脊肉和脊髓的完整的羊脊椎骨，因其形跟蝎子相似，故而俗称羊蝎子。
# question:  羊蝎子叫什么?
# answer:  {'answer': '羊脊椎骨', 'start': 80, 'end': 84, 'score': 0.9999992847442627}
#
# question:  羊蝎子的俗称是什么?
# answer:  {'answer': "OrderedDict([('', '20928'), ('实体', '羊蝎子", 'start': 0, 'end': 39, 'score': 0.9998360872268677}
#
# question:  为什么羊蝎子被称为羊蝎子?
# answer:  {'answer': '带里脊肉和脊髓的完整的羊脊椎骨，因其形跟蝎子相似', 'start': 69, 'end': 93, 'score': 0.9999806880950928}
#
# full_context:  过桥米线的描述是：过桥米线是云南滇南地区特有的小吃，属滇菜系，起源于蒙自地区，由汤料、佐料、生的猪里脊肉片、鸡脯肉片、乌鱼片及五成熟的猪腰片、肚头片、水发鱿鱼片制作而成。
# question:  过桥米线起源于哪个地区?
# answer:  {'answer': '云南', 'start': 70, 'end': 72, 'score': 1.0}
#
# question:  云南滇南地区特有的小吃是什么?
# answer:  {'answer': '过桥米线', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  过桥的米线是哪个地区特有的的小吃?
# answer:  {'answer': '云南', 'start': 70, 'end': 72, 'score': 1.0}
#
# full_context:  沈括的描述是：沈括（1031—1095），字存中，号梦溪丈人，汉族，浙江杭州钱塘县人，北宋政治家、科学家。
# question:  沈括是哪里人?
# answer:  {'answer': '浙江杭州', 'start': 90, 'end': 94, 'score': 1.0}
#
# question:  沈括的字是什么?
# answer:  {'answer': '存中', 'start': 78, 'end': 80, 'score': 1.0}
#
# question:  “沈括”字什么?
# answer:  {'answer': '存中', 'start': 78, 'end': 80, 'score': 1.0}
#
# full_context:  祖冲之的描述是：祖冲之（429-500），字文远。
# question:  祖冲之字什么?
# answer:  {'answer': '文远', 'start': 78, 'end': 80, 'score': 1.0}
#
# question:  祖冲的字是什么?
# answer:  {'answer': '文远', 'start': 78, 'end': 80, 'score': 1.0}
#
# question:  是谁写的祖冲之?
# answer:  {}
#
# full_context:  梁思成的描述是：梁思成（1901年4月20日—1972年1月9日），籍贯广东新会，生于日本东京，毕生致力于中国古代建筑的研究和保护，是建筑历史学家、建筑教育家和建筑师。
# question:  梁思成的籍贯是哪里?
# answer:  {'answer': '广东新会', 'start': 92, 'end': 96, 'score': 1.0}
#
# question:  梁思成的职业是什么?
# answer:  {'answer': '建筑师', 'start': 136, 'end': 139, 'score': 1.0}
#
# question:  谁是梁思成的建筑历史学家?
# answer:  {}
#
# full_context:  辐射[物理名词]的描述是：辐射指的是由场源出的电磁能量中一部分脱离场源向远处传播，而后再返回场源的现象，能量以电磁波或粒子（如阿尔法粒子、贝塔粒子等）的形式向外扩散。
# question:  辐射指的是什么?
# answer:  {'answer': '电磁波', 'start': 111, 'end': 114, 'score': 1.0}
#
# question:  电磁能量的一部分脱离场源向远处传播,然后再返回场源的现象?
# answer:  {'answer': '辐射', 'start': 36, 'end': 38, 'score': 1.0}
#
# question:  辐射的物理名词是什么?
# answer:  {'answer': '电磁波', 'start': 111, 'end': 114, 'score': 1.0}
#
# full_context:  酸辣粉[重庆小吃名称]的描述是：酸辣粉起源于四川，是四川省、重庆市、贵州省等地的传统特色小吃，属于渝菜、川菜、贵州小吃。
# question:  酸辣粉起源于哪里?
# answer:  {'answer': '四川', 'start': 78, 'end': 80, 'score': 1.0}
#
# question:  重庆小吃的名称是什么?
# answer:  {'answer': '酸辣粉', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  重庆的酸辣粉属于哪一类?
# answer:  {'answer': '小吃', 'start': 42, 'end': 44, 'score': 1.0}
#
# full_context:  旗袍[形成于民国时代的女性服装]的描述是：旗袍，中国和世界华人女性的传统服装，被誉为中国国粹和女性国服。
# question:  中国和世界华人女性的传统服装叫什么名字?
# answer:  {'answer': '旗袍', 'start': 36, 'end': 38, 'score': 1.0}
#
# question:  旗袍被称为什么?
# answer:  {'answer': '中国国粹和女性国服', 'start': 98, 'end': 107, 'score': 1.0}
#
# question:  在民国时代,什么被称为中国国粹和女性国服?
# answer:  {'answer': '旗袍', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  兵马俑[秦始皇兵马俑]的描述是：兵马俑，即秦始皇兵马俑，亦简称秦兵马俑或秦俑，第一批全国重点文物保护单位，第一批中国世界遗产，位于今陕西省西安市临潼区秦始皇陵以东1.5千米处的兵马俑坑内。
# question:  秦始皇兵马俑位于哪里?
# answer:  {'answer': '西安', 'start': 125, 'end': 127, 'score': 1.0}
#
# question:  兵马俑的描述是什么?
# answer:  {'answer': '秦始皇兵马俑', 'start': 40, 'end': 46, 'score': 1.0}
#
# question:  秦始皇帝兵马俑又叫什么?
# answer:  {'answer': '秦俑', 'start': 92, 'end': 94, 'score': 1.0}
#
# full_context:  杨振宁的描述是：杨振宁，1922年10月1日出生于安徽合肥，世界著名物理学家，现任香港中文大学讲座教授、清华大学教授、美国纽约州立大学石溪分校荣休教授、中国科学院院士、美国国家科学院院士、台湾“中央研究院”院士、俄罗斯科学院院士、英国皇家学会会员，1957年获诺贝尔物理学奖；是中美关系松动后回中国探访的第一位华裔科学家，积极推动中美文化交流和中美人民的互相了解；在促进中美两国建交、中美人才交流和科技合作等方面，做出了重大贡献。
# question:  杨振宁在哪一年获得诺贝尔物理学奖?
# answer:  {'answer': '1957', 'start': 180, 'end': 184, 'score': 1.0}
#
# question:  1957年杨振宁获得了什么奖项?
# answer:  {'answer': '诺贝尔物理学奖', 'start': 186, 'end': 193, 'score': 1.0}
#
# question:  1957年的杨振宁获得什么奖项
# answer:  {'answer': '诺贝尔物理学奖', 'start': 186, 'end': 193, 'score': 1.0}
#
# full_context:  水煮鱼[经典川菜的一道菜]的描述是：水煮鱼也称为江水煮江鱼、水煮鱼片，最早流行于重庆市渝北区翠云乡。
# question:  水煮鱼最早流行于哪个城市?
# answer:  {'answer': '重庆', 'start': 96, 'end': 98, 'score': 1.0}
#
# question:  江水煮江鱼的名称是什么?
# answer:  {'answer': '水煮鱼', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  河水煮鱼最流行在哪里?
# answer:  {'answer': '重庆', 'start': 96, 'end': 98, 'score': 1.0}
#
# full_context:  酗酒的描述是：酗酒是指无节制地过量饮酒。
# question:  酗酒的定义是什么?
# answer:  {'answer': '无节制地过量饮酒', 'start': 67, 'end': 75, 'score': 1.0}
#
# question:  酗酒是什么意思?
# answer:  {'answer': '无节制地过量饮酒', 'start': 67, 'end': 75, 'score': 0.9999997615814209}
#
# question:  什么是酗酒?
# answer:  {'answer': '无节制地过量饮酒', 'start': 67, 'end': 75, 'score': 0.9999997615814209}
#
# full_context:  李四光[地质学家、中国科学院院士]的描述是：李四光（1889年10月26日—1971年4月29日），字仲拱，原名李仲揆，湖北黄冈人，蒙古族，地质学家、教育家、音乐家、社会活动家，中国地质力学的创立者、中国现代地球科学和地质工作的主要领导人和奠基人之一，新中国成立后第一批杰出的科学家和为新中国发展做出卓越贡献的元勋，2009年当选为100位新中国成立以来感动中国人物之一。
# question:  李四光的原名叫什么?
# answer:  {'answer': '李仲揆', 'start': 112, 'end': 115, 'score': 1.0}
#
# question:  李四光是哪个国家的科学家?
# answer:  {'answer': '中国', 'start': 45, 'end': 47, 'score': 1.0}
#
# question:  为什么李四光当选为100位新中国成立以来感动中国人物之一?
# answer:  {}
#
# full_context:  杨辉[北京邮电大学副教授]的描述是：北京邮电大学副教授，硕士生导师。
# question:  杨辉的职业是什么?
# answer:  {'answer': '副教授', 'start': 45, 'end': 48, 'score': 1.0}
#
# question:  北京邮电大学副教授是谁?
# answer:  {'answer': '杨辉', 'start': 36, 'end': 38, 'score': 1.0}
#
# question:  杨辉是哪个大学的副教授?
# answer:  {'answer': '北京邮电大学', 'start': 39, 'end': 45, 'score': 1.0}
#
# full_context:  人本主义理论的描述是：人本主义理论是美国当代心理学主要流派之一，由美国心理学家A.H马斯洛创立，现在的代表人物有 C.R罗杰斯。
# question:  谁创立了人本主义理论?
# answer:  {'answer': '马斯洛', 'start': 98, 'end': 101, 'score': 1.0}
#
# question:  人本主义是美国当代心理学的主要流派之一?
# answer:  {}
#
# question:  美国当代心理学主要流派是什么?
# answer:  {'answer': '人本主义', 'start': 36, 'end': 40, 'score': 1.0}
#
# full_context:  路易威登的描述是：自1854年以来，代代相传至今的路易威登，以卓越品质、杰出创意和精湛工艺成为时尚旅行艺术的象征。
# question:  路易威登是什么时候被称为时尚旅行艺术的象征的?
# answer:  {'answer': '1854', 'start': 66, 'end': 70, 'score': 1.0}
#
# question:  路易维登是在哪一年成为时尚旅行艺术的主要象征?
# answer:  {'answer': '1854', 'start': 66, 'end': 70, 'score': 1.0}
#
# question:  从哪一年开始,街易威登以卓越品质而闻名?
# answer:  {'answer': '1854', 'start': 66, 'end': 70, 'score': 1.0}
#
# full_context:  理性情绪理论的描述是：该理论是由美国临床心理学家阿尔伯特·艾利斯于60年代创立的一种心理治疗体系，他认为人有其固有本性，人的先天倾向中有积极的取向，也有消极的本性，换句话说人有趋向于成长和自我实现这样的内在倾向，同时也具有非理性的不利于生存发展的生活态度倾向，而且艾利斯更强调后一种倾向，他认为正是这种非理性的生活态度，导致心理失调。
# question:  艾利斯认为人的先天倾向中有积极的取向,还有什么不利于生存发展的生活态度倾向?
# answer:  {'answer': '非理性', 'start': 167, 'end': 170, 'score': 0.9998517036437988}
#
# question:  阿尔伯特·艾利斯在60年代创立了什么心理治疗体系?
# answer:  {'answer': '理性情绪理论', 'start': 36, 'end': 42, 'score': 1.0}
#
# question:  谁创立了理性情绪理论?
# answer:  {'answer': '阿尔伯特·艾利斯', 'start': 80, 'end': 88, 'score': 1.0}
#
# full_context:  王安忆[当代作家、文学家、中国作协副主席]的描述是：王安忆，1954年3月生于江苏南京，原籍福建省同安县，当代作家、文学家。
# question:  王安忆的原籍是哪里?
# answer:  {'answer': '福建', 'start': 102, 'end': 104, 'score': 1.0}
#
# question:  是谁写的王安忆?
# answer:  {}
#
# question:  1954年3月,王安忆生于哪里?
# answer:  {'answer': '江苏南京', 'start': 95, 'end': 99, 'score': 1.0}
#
# full_context:  胡安·安东尼奥·萨马兰奇的描述是：胡安·安东尼奥·萨马兰奇（Juan Antonio Samaranch，1920.7.17－2010.4.21）侯爵，西班牙人，国际奥委会终身名誉主席。
# question:  胡安·安东尼奥·萨马兰奇的职业是什么?
# answer:  {'answer': '国际奥委会终身名誉主席', 'start': 137, 'end': 148, 'score': 1.0}
#
# question:  谁是国际奥委会终身名誉主席?
# answer:  {'answer': '萨马兰奇', 'start': 44, 'end': 48, 'score': 1.0}
#
# question:  哪个国家在国际奥委会的终身荣誉主席?
# answer:  {'answer': '西班牙', 'start': 132, 'end': 135, 'score': 1.0}
#
# full_context:  亚历山大·谢尔盖耶维奇·普希金的描述是：亚历山大·谢尔盖耶维奇·普希金（Александр Сергеевич Пушкин；1799年5月26日—1837年1月29日），是俄罗斯著名文学家、诗人、小说家，现代俄国文学的创始人，19世纪俄罗斯浪漫主义文学主要代表，同时也是现实主义文学的奠基人，现代标准俄语的创始人，被誉为“俄罗斯文学之父”、“俄罗斯诗歌的太阳”，“青铜骑士”。
# question:  亚历山大·谢尔盖耶维奇·普希金的职业是什么?
# answer:  {'answer': '文学家', 'start': 148, 'end': 151, 'score': 1.0}
#
# question:  谁是现代俄国文学的奠基人?
# answer:  {'answer': '普希金', 'start': 48, 'end': 51, 'score': 1.0}
#
# question:  现代俄语的创始人是谁?
# answer:  {'answer': '普希金', 'start': 48, 'end': 51, 'score': 1.0}
#
# full_context:  高斯·奥特曼[特摄片《高斯·奥特曼》中主角]的描述是：高斯奥特曼是日本特摄片《高斯·奥特曼》中主角，是从行星朱兰而来的神秘巨人，期盼和平、不喜欢互相战斗，是一位主张不伤害对方并建立友好关系的但面对凶暴的敌人果断地与其战斗的奥特战士。
# question:  高斯奥特曼是哪个国家的特摄片?
# answer:  {'answer': '日本', 'start': 89, 'end': 91, 'score': 1.0}
#
# question:  高斯·奥特曼是哪个国家特摄片的主角?
# answer:  {'answer': '日本', 'start': 89, 'end': 91, 'score': 1.0}
#
# question:  谁是日本特摄片中主角?
# answer:  {}
#
# full_context:  三毛[台湾著名女作家、旅行家]的描述是：三毛（1943年3月26日-1991年1月4日），女，原名陈懋（mào）平（后改名为陈平），中国现代作家，浙江定海（今舟山市定海区）人。
# question:  三毛的原名叫什么?
# answer:  {'answer': '陈平', 'start': 118, 'end': 120, 'score': 1.0}
#
# question:  三毛是哪里人?
# answer:  {}
#
# question:  陈懋(mào)平(后改名为什么?
# answer:  {'answer': '陈平', 'start': 118, 'end': 120, 'score': 1.0}
#
# full_context:  李白[唐代著名浪漫主义诗人]的描述是：李白（701年－762年） ，字太白，号青莲居士，又号“谪仙人”，是唐代伟大的浪漫主义诗人，被后人誉为“诗仙”，与杜甫并称为“李杜”，为了与另两位诗人李商隐与杜牧即“小李杜”区别，杜甫与李白又合称“大李杜”。
# question:  唐代著名浪漫主义诗人是谁?
# answer:  {'answer': '李白', 'start': 36, 'end': 38, 'score': 1.0}
#
# question:  李白的字是什么?
# answer:  {'answer': '太白', 'start': 91, 'end': 93, 'score': 1.0}
#
# question:  杜甫与李白又合称什么?
# answer:  {'answer': '大李杜', 'start': 174, 'end': 177, 'score': 1.0}
#
# full_context:  罗曼·罗兰的描述是：罗曼·罗兰（Romain Rolland，1866年1月29日-1944年12月30日），1866年生于法国克拉姆西，思想家，文学家，批判现实主义作家，音乐评论家，社会活动家，1915年诺贝尔文学奖得主，是20世纪上半叶法国著名的人道主义作家。
# question:  罗曼·罗兰是哪一年获得诺贝尔文学奖的?
# answer:  {'answer': '1915', 'start': 154, 'end': 158, 'score': 1.0}
#
# question:  谁是20世纪上半叶法国著名的人道主义作家?
# answer:  {'answer': '罗曼·罗兰', 'start': 36, 'end': 41, 'score': 1.0}
#
# question:  什么奖得主是20世纪下半叶法国著名人道主义者?
# answer:  {'answer': '诺贝尔文学奖', 'start': 159, 'end': 165, 'score': 0.9999998807907104}
#
# full_context:  柳永[北宋著名词人]的描述是：柳永（约984年—约1053年），原名三变，字景庄，后改名柳永，字耆卿，因排行第七，又称柳七，福建崇安人，北宋著名词人，婉约派代表人物。
# question:  柳永字什么?
# answer:  {'answer': '景庄', 'start': 94, 'end': 96, 'score': 1.0}
#
# question:  柳永的字是什么?
# answer:  {'answer': '耆卿', 'start': 104, 'end': 106, 'score': 1.0}
#
# question:  北宋著名词人是谁?
# answer:  {'answer': '柳永', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  汉斯·克里斯汀·安徒生的描述是：汉斯·克里斯汀·安徒生 （1805-1875），丹麦19世纪童话作家，被誉为“世界儿童文学的太阳”。
# question:  汉斯·克里斯汀·安徒生是哪个国家的童话作家?
# answer:  {'answer': '丹麦', 'start': 96, 'end': 98, 'score': 1.0}
#
# question:  哪位作家被称为世界儿童文学的太阳?
# answer:  {'answer': '安徒生', 'start': 44, 'end': 47, 'score': 1.0}
#
# question:  汉斯克里斯汀安徒生的职业是什么?
# answer:  {'answer': '作家', 'start': 104, 'end': 106, 'score': 1.0}
#
# full_context:  精神分析理论的描述是：精神分析理论，是奥地利精神科医生弗洛伊德于19世纪末20世纪初创立。
# question:  奥地利精神科医生弗洛伊德什么时候创立了精神分析理论?
# answer:  {'answer': '19世纪末', 'start': 88, 'end': 93, 'score': 1.0}
#
# question:  弗雷伊德是什么时候创立的精神分析理论的?
# answer:  {'answer': '19世纪末20世纪初', 'start': 88, 'end': 98, 'score': 0.9999936819076538}
#
# question:  精神分析理论是哪一年创立的?
# answer:  {'answer': '21313', 'start': 19, 'end': 24, 'score': 0.9997298121452332}
#
# full_context:  音乐治疗[应用学科]的描述是：音乐治疗1944年在美国密歇根州立大学正式成为学科。
# question:  密歇根州立大学的哪所大学是音乐治疗的学科?
# answer:  {}
#
# question:  音乐治疗是哪一年成为音乐治疗的?
# answer:  {'answer': '1944', 'start': 75, 'end': 79, 'score': 1.0}
#
# question:  哪所大学正式成为音乐治疗学科?
# answer:  {'answer': '密歇根州立大学', 'start': 83, 'end': 90, 'score': 1.0}
#
# full_context:  陈景润[中国著名数学家]的描述是：陈景润，1933年5月22日生于福建福州，当代数学家。
# question:  陈景润出生在什么地方?
# answer:  {'answer': '福建福州', 'start': 89, 'end': 93, 'score': 1.0}
#
# question:  陈景润的国籍是什么?
# answer:  {'answer': '中国', 'start': 40, 'end': 42, 'score': 1.0}
#
# question:  当代数学家陈景润的职业是什么?
# answer:  {'answer': '数学家', 'start': 44, 'end': 47, 'score': 1.0}
#
# full_context:  张爱玲[中国女作家]的描述是：张爱玲（1920.9.30—1995.9.8），原名张煐，1920年9月30日出生在上海公共租界西区一幢没落贵族府邸，中国现代作家。
# question:  张爱玲的原名叫什么?
# answer:  {'answer': '张煐', 'start': 97, 'end': 99, 'score': 1.0}
#
# question:  张爱的的原名是什么?
# answer:  {'answer': '张爱玲', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  1920年9月30日出生在公共租界西区的一幢没落贵族府邸叫什么名字?
# answer:  {'answer': '张爱玲', 'start': 36, 'end': 39, 'score': 0.9999672174453735}
#
# full_context:  威廉·莎士比亚[文艺复兴时期英国戏剧家、诗人]的描述是：威廉·莎士比亚（英语：William Shakespeare，1564年4月23日－1616年4月23日），华人社会常尊称为莎翁，清末民初鲁迅在《摩罗诗力说》（1908年2月）称莎翁为“狭斯丕尔”，是英国文学史上最杰出的戏剧家，也是欧洲文艺复兴时期最重要、最伟大的作家，全世界最卓越的文学家之一。
# question:  威廉·莎士比亚的国籍是什么?
# answer:  {'answer': '英国', 'start': 50, 'end': 52, 'score': 1.0}
#
# question:  英国文学史上最杰出的戏剧家是谁?
# answer:  {'answer': '莎士比亚', 'start': 39, 'end': 43, 'score': 1.0}
#
# question:  谁在《摩罗诗力说》中称赞莎翁为“狭斯丕尔”?
# answer:  {'answer': '鲁迅', 'start': 153, 'end': 155, 'score': 1.0}
#
# full_context:  李嘉诚[香港首富、长江和记实业有限公司原主席]的描述是：李嘉诚（1928年7月29日—），汉族，出生于广东潮州潮安县，祖籍福建 莆田，长江和记实业有限公司及长江实业地产有限公司主席。
# question:  李嘉诚出生在什么地方?
# answer:  {'answer': '香港', 'start': 40, 'end': 42, 'score': 1.0}
#
# question:  李嘉诚的祖籍是哪里?
# answer:  {'answer': '福建 莆田', 'start': 117, 'end': 122, 'score': 1.0}
#
# question:  谁是李嘉诚的原主席?
# answer:  {'answer': "OrderedDict([('', '21397'), ('实体', '李嘉诚[香港", 'start': 0, 'end': 42, 'score': 0.9998854398727417}
#
# full_context:  认知心理学[一种心理学研究方向]的描述是：认知心理学（cognitive psychology），20 世纪 50 年代中期在西方兴起的一种心理学思潮和研究方向。
# question:  认知心理学是什么时候开始兴起的?
# answer:  {'answer': '20 世纪 50 年代', 'start': 105, 'end': 116, 'score': 1.0}
#
# question:  认知心理是什么时候开始的?
# answer:  {'answer': '20 世纪 50 年代中期', 'start': 105, 'end': 118, 'score': 0.999997615814209}
#
# question:  20世纪50年代中期,认知心理学在西方兴起的是什么?
# answer:  {}
#
# full_context:  忧郁症[神经官能症的一个症状]的描述是：忧郁症是神经官能症的一个症状，它是由于用脑过度，精神紧张，体力劳累所引起的一种机体功能失调所引起的疾病。
# question:  神经官能症的症状
# answer:  {'answer': '忧郁症', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  什么症状是神经官能病的症状?
# answer:  {'answer': '忧郁症', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  什么类型的疾病导致了忧郁症?
# answer:  {'answer': '神经官能症', 'start': 40, 'end': 45, 'score': 1.0}
#
# full_context:  行为主义理论的描述是：由美国心理学家华生在巴甫洛夫条件反射学说的基础上创立的，他主张心理学应该摒弃意识、意象等太多主观的东西，只研究所观察到的并能客观地加以测量的刺激和反应。
# question:  华生在巴甫洛夫条件反射学说的基础上创立了什么理论?
# answer:  {'answer': '行为主义理论', 'start': 36, 'end': 42, 'score': 0.9999996423721313}
#
# question:  华生主张心理学应该如何加以测量的刺激和反应?
# answer:  {'answer': '条件反射', 'start': 81, 'end': 85, 'score': 0.9999998807907104}
#
# question:  是谁创立了行为主义理论?
# answer:  {'answer': '华生', 'start': 74, 'end': 76, 'score': 1.0}
#
# full_context:  约翰·麦卡锡[数学博士]的描述是：1927年9月4日麦卡锡生于美国波士顿一个共产党家庭，父母的工作性质决定全家需不断搬迁，从波士顿迁到纽约，然后又到了洛杉矶。
# question:  约翰·麦卡锡出生在哪个城市?
# answer:  {'answer': '波士顿', 'start': 89, 'end': 92, 'score': 1.0}
#
# question:  麦卡锡是哪一年出生的?
# answer:  {'answer': '1927年', 'start': 73, 'end': 78, 'score': 1.0}
#
# question:  约翰麦卡锡的职业是什么?
# answer:  {'answer': '数学博士', 'start': 43, 'end': 47, 'score': 0.9996639490127563}
#
# full_context:  阿基米德[古希腊哲学家、数学家、物理学家]的描述是：阿基米德（公元前287年—公元前212年），伟大的古希腊哲学家、百科式科学家、数学家、物理学家、力学家，静态力学和流体静力学的奠基人，并且享有“力学之父”的美称，阿基米德和高斯、牛顿并列为世界三大数学家。
# question:  阿基米德是哪一年出生的?
# answer:  {'answer': '公元前287年', 'start': 87, 'end': 94, 'score': 1.0}
#
# question:  谁是世界三大数学家?
# answer:  {}
#
# question:  哪位科学家是阿基米德的奠基人?
# answer:  {'answer': '阿基米德', 'start': 36, 'end': 40, 'score': 1.0}
#
# full_context:  焦虑的描述是：焦虑是对亲人或自己生命安全、前途命运等的过度担心而产生的一种烦躁情绪。
# question:  焦虑的描述是什么?
# answer:  {'answer': '烦躁情绪', 'start': 93, 'end': 97, 'score': 0.9999998807907104}
#
# question:  焦虑对亲人有什么影响?
# answer:  {}
#
# question:  什么情绪对亲人有过度担心?
# answer:  {'answer': '焦虑', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  艾伦·麦席森·图灵的描述是：艾伦·麦席森·图灵（Alan Mathison Turing，1912年6月23日－1954年6月7日），英国数学家、逻辑学家，被称为计算机科学之父，人工智能之父。
# question:  艾伦·麦席森·图灵的职业是什么?
# answer:  {'answer': '数学家', 'start': 125, 'end': 128, 'score': 1.0}
#
# question:  谁是计算机科学之父?
# answer:  {'answer': '图灵', 'start': 43, 'end': 45, 'score': 1.0}
#
# question:  图灵的国籍是什么?
# answer:  {'answer': '英国', 'start': 123, 'end': 125, 'score': 1.0}
#
# full_context:  居庸关的描述是：居庸关，是京北长城沿线上的著名古关城，“天下九塞”之一，“太行八陉”之八，国家级文物保护单位。
# question:  居庸关位于哪里?
# answer:  {'answer': '太行', 'start': 93, 'end': 95, 'score': 0.9999988079071045}
#
# question:  太行八陉之八的名称是什么?
# answer:  {'answer': '居庸关', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  位于居庸关的哪个地方?
# answer:  {}
#
# full_context:  石空寺石窟的描述是：石空寺石窟位于中宁县石空镇西北的双龙山南麓。
# question:  石空寺石窟位于什么地方?
# answer:  {'answer': '中宁县石空镇西北的双龙山南麓', 'start': 73, 'end': 87, 'score': 1.0}
#
# question:  石空石窟位于哪个县?
# answer:  {'answer': '中宁县', 'start': 73, 'end': 76, 'score': 1.0}
#
# question:  什么石窟位于石空寺附近?
# answer:  {'answer': '石空寺石窟', 'start': 36, 'end': 41, 'score': 1.0}
#
# full_context:  山顶洞人的描述是：山顶洞人，中国华北地区旧石器时代晚期的人类化石。
# question:  山顶洞人是哪个国家的人?
# answer:  {'answer': '中国', 'start': 70, 'end': 72, 'score': 1.0}
#
# question:  什么类型的石器时代晚期的人类化石?
# answer:  {'answer': '山顶洞人', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  谁是山顶洞人的?
# answer:  {}
#
# full_context:  尼泊尔的描述是：尼泊尔联邦民主共和国（英语：Federal Democratic Republic of Nepal），简称尼泊尔。
# question:  尼泊尔联邦民主共和国的简称是什么?
# answer:  {'answer': '尼泊尔', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  哪个国家是尼泊尔的联邦民主共和国?
# answer:  {'answer': '尼泊尔', 'start': 36, 'end': 39, 'score': 0.9999685287475586}
#
# question:  什么国家被称为尼泊尔?
# answer:  {'answer': '尼泊尔联邦民主共和国', 'start': 64, 'end': 74, 'score': 1.0}
#
# full_context:  钿子的描述是：钿子是古代妇女的一种首饰，上面嵌有金花，点翠，宝石，以及多种名贵珠宝。
# question:  古代妇女的首饰是什么?
# answer:  {'answer': '钿子', 'start': 36, 'end': 38, 'score': 1.0}
#
# question:  钿子是什么类型的首饰?
# answer:  {'answer': '珠宝', 'start': 95, 'end': 97, 'score': 0.9998626708984375}
#
# question:  古代妇女首饰的名称是什么?
# answer:  {'answer': '钿子', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  承天寺塔的描述是：承天寺塔是一座密檐式八角形砖塔，连塔尖通高64．5米，比西安的大雁塔还高0.5米。
# question:  承天寺塔的高度是多少?
# answer:  {'answer': '64．5米', 'start': 86, 'end': 91, 'score': 0.9999998807907104}
#
# question:  承天的塔有多高?
# answer:  {'answer': '64．5米', 'start': 86, 'end': 91, 'score': 1.0}
#
# question:  西安大雁塔高多少米?
# answer:  {}
#
# full_context:  太白山的描述是：太白山，秦岭山脉最高峰，也是青藏高原以东第一高峰，如鹤立鸡群之势冠列秦岭群峰之首。
# question:  太白山是哪个山脉最高峰?
# answer:  {'answer': '秦岭山脉', 'start': 68, 'end': 72, 'score': 1.0}
#
# question:  秦岭群峰的最高峰是哪里?
# answer:  {'answer': '太白山', 'start': 36, 'end': 39, 'score': 1.0}
#
# question:  苍山群峰最高峰的名称是什么?
# answer:  {'answer': '太白山', 'start': 36, 'end': 39, 'score': 0.9999918937683105}
#
# question:  青藏高原以东的第一高峰是什么?
# answer:  {'answer': '太白山', 'start': 36, 'end': 39, 'score': 1.0}
#
# full_context:  蓝田人的描述是：“蓝田人”即“蓝田猿人”，学名为“直立人蓝田亚种”，英文名称：Homo（Sinanthropus）erectuslantianensis。
# question:  蓝田人学名叫什么?
# answer:  {'answer': '直立人', 'start': 81, 'end': 84, 'score': 0.9999998807907104}
#
# question:  蓝田人的英文名称是什么?
# answer:  {'answer': 'erectuslantianensis', 'start': 113, 'end': 132, 'score': 0.999993085861206}
#
# question:  “蓝田人”这个词的英文名是什么?
# answer:  {'answer': 'erectuslantianensis', 'start': 113, 'end': 132, 'score': 0.9999736547470093}
#
# full_context:  印度的描述是：印度共和国（印地语：भारत गणराज्य；英语：Republic of India），简称印度。
# question:  印度共和国的英文名称是什么?
# answer:  {'answer': '印度共和国（印地语：भारत गणराज्य；英语：Republic of', 'start': 63, 'end': 100, 'score': 0.9998831748962402}
#
# question:  印度的印地语是什么意思?
# answer:  {'answer': '印度共和国', 'start': 63, 'end': 68, 'score': 0.9999996423721313}
#
# question:  印地语印度共和国的印地词是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999986886978149}
#
# full_context:  世界知识产权日的描述是：世界知识产权日（The World Intellectual Property Day)，由世界知识产权组织于2001年4月26日设立，并决定从2001年起将每年的4月26日定为&quot;世界知识产权日&quot;(World Intellectual Property Day)，目的是在世界范围内树立尊重知识、崇尚科学和保护知识产权的意识，营造鼓励知识创新的法律环境。
# question:  世界知识产权日是什么时候设立的?
# answer:  {'answer': '2001年', 'start': 123, 'end': 128, 'score': 1.0}
#
# question:  世界上知识产权日的目的是什么?
# answer:  {'answer': '保护知识产权', 'start': 231, 'end': 237, 'score': 1.0}
#
# question:  世界知识产权组织什么时候设立了世界知识产权日?
# answer:  {'answer': '2001年', 'start': 123, 'end': 128, 'score': 1.0}
#
# full_context:  世界知识产权组织的描述是：世界知识产权组织（World Intellectual property organization）简称“WIPO”。
# question:  WIPO的简称是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999985694885254}
#
# question:  WIPO的缩写是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999831914901733}
#
# question:  世界知识产权组织的名称是什么?
# answer:  {'answer': '世界知识产权组织', 'start': 36, 'end': 44, 'score': 0.9999995231628418}
#
# full_context:  世界乒乓球锦标赛的描述是：世界乒乓球锦标赛（简称”世乒赛”，英文：World Table Tennis Championships）由国际乒乓球联合会主办，每届比赛由国际乒乓球联合会授权比赛地乒乓球协会主办，具有广泛的影响力。
# question:  世界乒乓球锦标赛的主办方是谁?
# answer:  {'answer': '国际乒乓球联合会', 'start': 123, 'end': 131, 'score': 1.0}
#
# question:  世界锦标赛是由谁主办的?
# answer:  {'answer': '国际乒乓球联合会', 'start': 123, 'end': 131, 'score': 1.0}
#
# question:  国际乒乓球联合会授权比赛地是谁?
# answer:  {'answer': '乒乓球协会', 'start': 152, 'end': 157, 'score': 1.0}
#
# full_context:  雅鲁藏布江[藏南大河]的描述是：雅鲁藏布江：是中国最长的高原河流，位于西藏自治区境内，也是世界上海拔最高的大河之一。
# question:  雅鲁藏布江位于哪里?
# answer:  {'answer': '西藏', 'start': 91, 'end': 93, 'score': 1.0}
#
# question:  西藏自治区境内最长的高原河流叫什么名字?
# answer:  {'answer': '雅鲁藏布江', 'start': 36, 'end': 41, 'score': 1.0}
#
# question:  藏南大河的描述是什么?
# answer:  {'answer': '雅鲁藏布江', 'start': 36, 'end': 41, 'score': 1.0}
#
# full_context:  吉林[中华人民共和国省级行政区]的描述是：吉林，地处中国东北中部，东北亚地理中心，因清初建吉林乌拉城而得名，简称“吉”，省会长春，原省会吉林市。
# question:  吉林省的简称是什么?
# answer:  {'answer': '吉', 'start': 36, 'end': 37, 'score': 1.0}
#
# question:  吉林省的省会是哪里?
# answer:  {'answer': '长春', 'start': 118, 'end': 120, 'score': 1.0}
#
# question:  东北亚地理中心的名称是什么?
# answer:  {'answer': '吉林', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  元谋人的描述是：元谋人，因发现地点在云南元谋县上那蚌村西北小山岗上，定名为“元谋直立人”，英文称雕塑：Homo erectus yuan mouensis，俗称“元谋人”。
# question:  元谋人的名字是什么?
# answer:  {'answer': '元谋直立人', 'start': 94, 'end': 99, 'score': 1.0}
#
# question:  元谋人的英文称是什么?
# answer:  {'answer': '雕塑', 'start': 104, 'end': 106, 'score': 0.9999935626983643}
#
# question:  “元谋直立人”这个词的由来是什么?
# answer:  {'answer': '因发现地点在云南元谋县上那蚌村西北小山岗上', 'start': 68, 'end': 89, 'score': 0.9999350309371948}
#
# full_context:  旧石器时代的描述是：旧石器时代（Paleolithic；距今约300万年～距今约1万年），以使用打制石器（见石器）为标志的人类物质文化发展阶段。
# question:  旧石器时代的描述是什么?
# answer:  {'answer': '打制石器', 'start': 104, 'end': 108, 'score': 0.999996542930603}
#
# question:  石器时代是什么时候开始的?
# answer:  {}
#
# question:  什么类型的石器被认为是人类物质文化发展阶段?
# answer:  {'answer': '旧石器', 'start': 36, 'end': 39, 'score': 1.0}
#
# full_context:  峨眉山[中国佛教名山，世界文化与自然双遗产]的描述是：峨眉山（Mount Emei）山头位于中国四川省乐山市峨眉山市境内，是中国“四大佛教名山”之一，地势陡峭，风景秀丽，素有“峨眉天下秀”之称，山上的万佛顶最高，海拔3099米，高出峨眉平原2700多米。
# question:  峨眉山高出峨眉平原多少米?
# answer:  {'answer': '2700', 'start': 176, 'end': 180, 'score': 1.0}
#
# question:  “峨眉天下秀”之称是什么?
# answer:  {}
#
# question:  峨眉山市的山头在哪里?
# answer:  {'answer': '乐山', 'start': 107, 'end': 109, 'score': 1.0}
#
# full_context:  茶马古道[古代中国西南地区商贸通道]的描述是：茶马古道是指存在于中国西南地区，以马帮为主要交通工具的民间国际商贸通道，是中国西南民族经济文化交流的走廊。
# question:  茶马古道是哪个国家的商贸通道
# answer:  {'answer': '中国', 'start': 43, 'end': 45, 'score': 1.0}
#
# question:  中国西南民族经济文化交流的走廊
# answer:  {'answer': '茶马古道', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  中国哪个民族的经济文化交流走廊
# answer:  {}
#
# full_context:  乌鲁木齐[新疆维吾尔自治区首府]的描述是：乌鲁木齐，通称“乌市”，旧称迪化，是新疆维吾尔自治区首府，全疆政治、经济、文化、科教和交通中心。
# question:  新疆维吾尔自治区首府的名称是什么?
# answer:  {'answer': '乌鲁木齐', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  乌鲁木齐的旧称是什么?
# answer:  {'answer': '迪化', 'start': 91, 'end': 93, 'score': 1.0}
#
# question:  “乌市”这个词是什么意思?
# answer:  {'answer': '乌鲁木齐', 'start': 36, 'end': 40, 'score': 1.0}
#
# full_context:  丽江[云南省辖地级市]的描述是：丽江，云南省辖地级市，位于云南省西北部，市区中心位于东经100°25&#39;，北纬26°86&#39;，总面积2.06万平方公里，北连迪庆藏族自治州，南接大理白族自治州，西邻怒江傈僳族自治州，东与四川凉山彝族自治州和攀枝花市接壤，距昆明市527公里。
# question:  丽江位于哪里?
# answer:  {'answer': '云南', 'start': 39, 'end': 41, 'score': 1.0}
#
# question:  丽江离昆明市有多远?
# answer:  {'answer': '527公里', 'start': 192, 'end': 197, 'score': 1.0}
#
# question:  大理白族自治州和攀枝花市接壤于哪里?
# answer:  {}
#
# full_context:  世界地球日的描述是：世界地球日（Earth Day）即每年的4月22日，是一个专为世界环境保护而设立的节日，旨在提高民众对于现有环境问题的意识，并动员民众参与到环保运动中，通过绿色低碳生活，改善地球的整体环境。
# question:  世界地球日的名称是什么?
# answer:  {'answer': '4月22日', 'start': 86, 'end': 91, 'score': 1.0}
#
# question:  地球日是什么时候?
# answer:  {'answer': '4月22日', 'start': 86, 'end': 91, 'score': 1.0}
#
# question:  什么节日是为了提高人们对环境问题的意识?
# answer:  {'answer': '世界地球日', 'start': 36, 'end': 41, 'score': 1.0}
#
# question:  是什么促使人们参与环保运动?
# answer:  {'answer': '世界地球日', 'start': 36, 'end': 41, 'score': 1.0}
#
# full_context:  白云山[广东省广州市白云山]的描述是：白云山，位于广东省广州市白云区，为南粤名山之一，自古就有“羊城第一秀”之称。
# question:  白云山位于什么地方?
# answer:  {'answer': '广东', 'start': 40, 'end': 42, 'score': 1.0}
#
# question:  白云山市位于哪个区?
# answer:  {'answer': '广州', 'start': 43, 'end': 45, 'score': 1.0}
#
# question:  广州白云山的名字是什么?
# answer:  {'answer': '羊城第一秀', 'start': 104, 'end': 109, 'score': 0.9999992847442627}
#
# question:  广州市白云山的名称是什么?
# answer:  {'answer': '白云山', 'start': 36, 'end': 39, 'score': 1.0}
#
# full_context:  大禹治水[历史典故]的描述是：大禹治水（鲧禹治水）是中国古代的神话传说故事，著名的上古大洪水传说。
# question:  大禹治水的传说叫什么?
# answer:  {'answer': '大禹治水', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  大洪水传说叫什么名字?
# answer:  {'answer': '大禹治水', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  什么是大洪水的传说?
# answer:  {'answer': '大禹治水', 'start': 36, 'end': 40, 'score': 1.0}
#
# full_context:  华山[五岳之西岳华山]的描述是：华山（Mount Hua），古称“西岳”，雅称“太华山”，为中国著名的五岳之一，中华文明的发祥地，“中华”和“华夏”之“华”，就源于华山。
# question:  华山的古称是什么?
# answer:  {'answer': '西岳', 'start': 42, 'end': 44, 'score': 1.0}
#
# question:  中华文明的发祥地是哪里?
# answer:  {'answer': '华山', 'start': 36, 'end': 38, 'score': 0.9999997615814209}
#
# question:  中国著名的五岳之一是什么?
# answer:  {'answer': '华山', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  梵净山[贵州省铜仁市梵净山]的描述是：梵净山（Mount Fanjing）：国家AAAA级旅游景区，国家级自然保护区，中国十大避暑名山，中国著名的弥勒菩萨道场，国际“人与生物圈保护网”（MAB）成员。
# question:  梵净山位于哪里?
# answer:  {'answer': '贵州', 'start': 40, 'end': 42, 'score': 1.0}
#
# question:  梵净山市的名称是什么?
# answer:  {'answer': '铜仁', 'start': 43, 'end': 45, 'score': 1.0}
#
# question:  哪个组织是梵净山的成员?
# answer:  {'answer': '人与生物圈保护网', 'start': 139, 'end': 147, 'score': 1.0}
#
# question:  中国十大避暑名山是什么?
# answer:  {'answer': '梵净山', 'start': 36, 'end': 39, 'score': 1.0}
#
# full_context:  西安[陕西省会、十三朝古都]的描述是：西安，古称长安、镐京，是陕西省会、副省级市、关中平原城市群核心城市、丝绸之路起点城市、&quot;一带一路&quot;核心区、中国西部地区重要的中心城市，国家重要的科研、教育、工业基地。
# question:  西安是哪个朝代的古都
# answer:  {'answer': '十三朝', 'start': 44, 'end': 47, 'score': 0.9993785619735718}
#
# question:  西安的哪个朝代是西安
# answer:  {'answer': '十三朝', 'start': 44, 'end': 47, 'score': 0.9974865913391113}
#
# question:  西安是什么朝代
# answer:  {'answer': '十三朝', 'start': 44, 'end': 47, 'score': 0.9934919476509094}
#
# question:  西安这个朝代叫什么?
# answer:  {'answer': '十三朝古都', 'start': 44, 'end': 49, 'score': 0.9998655319213867}
#
# full_context:  长春[吉林省省会、副省级市]的描述是：长春，简称“长”，别称“春城”，是吉林省省会、副省级市、东北亚经济圈中心城市，是国务院定位的中国东北地区中心城市之一，国家历史文化名城，我国重要的工业基地和综合交通枢纽。
# question:  吉林省省会、副省级市、东北亚经济圈中心城市的名称是什么?
# answer:  {'answer': '长春', 'start': 36, 'end': 38, 'score': 1.0}
#
# question:  东北地区中心城市是哪个?
# answer:  {'answer': '长春', 'start': 36, 'end': 38, 'score': 1.0}
#
# question:  长春的简称是什么?
# answer:  {'answer': '长', 'start': 36, 'end': 37, 'score': 1.0}
#
# full_context:  敦煌[甘肃省酒泉市代管县级市]的描述是：敦煌市，隶属于甘肃省酒泉市，位于河西走廊的最西端，地处甘肃、青海、新疆三省（区）的交汇处，介于东经92°13′—95°30′，北纬39°40′—41°40′之间，总面积3.12万平方千米。
# question:  敦煌的总面积是多少?
# answer:  {'answer': '3.12万平方千米', 'start': 160, 'end': 169, 'score': 0.9999998807907104}
#
# question:  敦煌位于什么地方?
# answer:  {'answer': '甘肃', 'start': 39, 'end': 41, 'score': 1.0}
#
# question:  兰州市隶属于哪个省?
# answer:  {'answer': '甘肃省', 'start': 39, 'end': 42, 'score': 0.9567425847053528}
#
# full_context:  康定[四川省甘孜藏族自治州首府]的描述是：康定，一座享誉世界的历史文化名城；一座跑马山，名扬五洲四海；一曲《康定情歌》千古绝唱，醉了天下人。
# question:  康定位于哪里?
# answer:  {'answer': '四川', 'start': 39, 'end': 41, 'score': 1.0}
#
# question:  康定是哪里的首府?
# answer:  {'answer': '四川', 'start': 39, 'end': 41, 'score': 1.0}
#
# question:  《康定情歌》醉了谁?
# answer:  {'answer': '天下人', 'start': 122, 'end': 125, 'score': 0.9999997615814209}
#
# full_context:  孔子[儒家学派创始人]的描述是：孔子（公元前551年9月28日―公元前479年4月11日），子姓，孔氏，名丘，字仲尼，春秋末期鲁国陬邑人（今山东曲阜），祖籍宋国栗邑（今河南夏邑）。
# question:  孔子的祖籍是哪里?
# answer:  {'answer': '河南', 'start': 140, 'end': 142, 'score': 1.0}
#
# question:  孔子是什么时候出生的?
# answer:  {'answer': '公元前551年9月28日', 'start': 75, 'end': 87, 'score': 0.9999997615814209}
#
# question:  儒家学派创始人是谁?
# answer:  {'answer': '孔子', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  仙剑奇侠传[大宇资讯出品的单机游戏品牌]的描述是：《仙剑奇侠传》是由中国台湾大宇资讯股份有限公司（简称“大宇资讯”或“大宇”）旗下发行的系列电脑游戏。
# question:  《仙剑奇侠传》是由哪个公司发行的?
# answer:  {'answer': '大宇资讯', 'start': 42, 'end': 46, 'score': 1.0}
#
# question:  大宇资讯股份有限公司(简称“大宇资讯”的简称是什么?
# answer:  {'answer': '大宇', 'start': 94, 'end': 96, 'score': 1.0}
#
# question:  仙剑奇俠传(大宇资讯)是哪个公司旗下发行的游戏?
# answer:  {'answer': '大宇资讯', 'start': 94, 'end': 98, 'score': 1.0}
#
# full_context:  大理白族自治州的描述是：大理白族自治州地处云南省中部偏西，海拔2090米，东邻楚雄州，南靠普洱市、临沧市，西与保山市、怒江州相连，北接丽江市。
# question:  大理白族自治州的海拔是多少米?
# answer:  {'answer': '2090', 'start': 87, 'end': 91, 'score': 1.0}
#
# question:  大理的白族自治州位于哪里?
# answer:  {'answer': '云南', 'start': 77, 'end': 79, 'score': 1.0}
#
# question:  昆明白族自治州海拔多少米?
# answer:  {'answer': '2090米', 'start': 87, 'end': 92, 'score': 0.9989190101623535}
#
# full_context:  中国人民政治协商会议的描述是：中国人民政治协商会议( 简称人民政协，英文：the Chinese People&#39;s Political Consultative Conference，缩写：CPPCC)是中国人民爱国统一战线的组织，是中国共产党领导的多党合作和政治协商的重要机构，是中国政治生活中发扬社会主义民主的一种重要形式。
# question:  中国政治生活中发扬社会主义民主的重要形式是什么?
# answer:  {'answer': '政治协商会议', 'start': 40, 'end': 46, 'score': 1.0}
#
# question:  中国人民政治协商会议的缩写是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 1.0}
#
# question:  CPCC代表什么?
# answer:  {'answer': '中国人民政治协商会议', 'start': 36, 'end': 46, 'score': 0.9999997615814209}
#
# full_context:  人民[汉语词汇]的描述是：人民是对一个经济体认同并有归属感的人群集合，人指成年人近代以后，“人民”的概念被广泛使用，但往往与公民、国民等词混用，泛指社会的全体成员。
# question:  人民指的是什么?
# answer:  {'answer': '公民', 'start': 118, 'end': 120, 'score': 0.9999998807907104}
#
# question:  “人民”这个词被广泛使用了,但往往与公民、国民等词混用?
# answer:  {}
#
# question:  什么是人民?
# answer:  {'answer': '公民', 'start': 118, 'end': 120, 'score': 0.9999992847442627}
#
# full_context:  同志[道同志合的人]的描述是：同志原指志同道合的人，在我国古代，同志与先生、长者、君等词的涵义一样，都是朋友之间的称呼。
# question:  同志与先生、长者、君等词的涵义是什么?
# answer:  {'answer': '朋友', 'start': 108, 'end': 110, 'score': 1.0}
#
# question:  同志与老师、长者和君等词有什么区别?
# answer:  {'answer': '朋友', 'start': 108, 'end': 110, 'score': 1.0}
#
# question:  在我国古代,同志与先生和先生等词有什么关系?
# answer:  {'answer': '朋友', 'start': 108, 'end': 110, 'score': 1.0}
#
# full_context:  北京凤凰岭自然风景区的描述是：北京凤凰岭自然风景区位于海淀区苏家坨镇境内，距天安门33公里，总面积10.62平方公里。
# question:  北京凤凰岭自然风景区距天安门多少公里?
# answer:  {'answer': '33公里', 'start': 97, 'end': 101, 'score': 1.0}
#
# question:  北京凤凰岭风景区离天安门有多远?
# ...
#
# question:  汉至晋时期的女真族叫什么名字?
# answer:  {'answer': '挹娄', 'start': 95, 'end': 97, 'score': 1.0}
#
# full_context:  企鹅[动物名称]的描述是：企鹅（学名：Spheniscidae）：有“海洋之舟”美称的企鹅是一种最古老的游禽，它们很可能在地球穿上冰甲之前，就已经在南极安家落户。
# question:  企鹅的学名是什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 1.0}
#
# question:  企鹅在地球穿上冰甲之前是在哪里落户的?
# answer:  {'answer': '南极', 'start': 130, 'end': 132, 'score': 1.0}
#
# question:  “海洋之舟”美称的企鹅是什么?
# answer:  {}
#
# full_context:  国学[中国传统思想文化学术]的描述是：国学，是以先秦经典及诸子百家学说为根基，它涵盖了两汉经学、魏晋玄学、隋唐道学、宋明理学、明清实学和同时期的先秦诗赋、汉赋、六朝骈文、唐宋诗词、元曲与明清小说并历代史学等一套完整的文化、学术体系。
# question:  国学涵盖了哪两种文化、学术体系?
# answer:  {}
#
# question:  国学包含了哪两部分?
# answer:  {}
#
# question:  中国传统思想文化学术的名称是什么?
# answer:  {'answer': '国学', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  计算机病毒的描述是：计算机病毒（Computer Virus）是编制者在计算机程序中插入的破坏计算机功能或者数据的代码，能影响计算机使用，能自我复制的一组计算机指令或者程序代码。
# question:  什么是计算机病毒?
# answer:  {'answer': '程序', 'start': 95, 'end': 97, 'score': 1.0}
#
# question:  计算机病毒的描述是什么?
# answer:  {'answer': '程序', 'start': 95, 'end': 97, 'score': 0.9999998807907104}
#
# question:  什么类型的病毒能影响计算机使用?
# answer:  {'answer': '计算机病毒', 'start': 36, 'end': 41, 'score': 0.9999992847442627}
#
# full_context:  孙策[三国时期孙吴政权奠基人]的描述是：孙策（175年—200年5月5日），字伯符，吴郡富春（今浙江杭州富阳区）人。
# question:  孙策字什么?
# answer:  {'answer': '伯符', 'start': 95, 'end': 97, 'score': 1.0}
#
# question:  孙策的字是什么?
# answer:  {'answer': '伯符', 'start': 95, 'end': 97, 'score': 1.0}
#
# question:  谁是孙策的奠基人?
# answer:  {'answer': '伯符', 'start': 95, 'end': 97, 'score': 0.9999591112136841}
#
# full_context:  超级女声[湖南卫视选秀娱乐节目]的描述是：《超级女声》，简称超女，是中国湖南卫视在2004年开始举办的针对女性的大众歌手选秀赛，每年一届。
# question:  超级女声是哪一年开始举办的?
# answer:  {'answer': '2004年', 'start': 97, 'end': 102, 'score': 1.0}
#
# question:  超女声是哪个电视台的选秀娱乐节目?
# answer:  {'answer': '湖南卫视', 'start': 41, 'end': 45, 'score': 1.0}
#
# question:  《超级女声》的简称是什么?
# answer:  {'answer': '超女', 'start': 86, 'end': 88, 'score': 1.0}
#
# full_context:  蠕虫[多细胞无脊椎动物]的描述是：蠕虫（Worm）为多细胞无脊椎动物，蠕虫藉由身体的肌肉收缩而作蠕形运动，故通称为蠕虫。
# question:  蠕虫叫什么?
# answer:  {'answer': 'OrderedDict', 'start': 0, 'end': 11, 'score': 0.9999998807907104}
#
# question:  蠕虫是什么动物?
# answer:  {'answer': '无脊椎动物', 'start': 42, 'end': 47, 'score': 1.0}
#
# question:  多细胞无脊椎动物的名称是什么?
# answer:  {'answer': '蠕虫', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  腊八节的描述是：腊八节，俗称“腊八” ，即农历十二月初八，古人有祭祀祖先和神灵、祈求丰收吉祥的传统，一些地区有喝腊八粥的习俗。
# question:  腊八节的俗称是什么?
# answer:  {'answer': '腊八节', 'start': 36, 'end': 39, 'score': 0.9999954700469971}
#
# question:  腊八节日的习俗是什么?
# answer:  {'answer': '喝腊八粥', 'start': 111, 'end': 115, 'score': 1.0}
#
# question:  “腊八”节是什么时候?
# answer:  {'answer': '农历十二月初八', 'start': 77, 'end': 84, 'score': 1.0}
#
# question:  祭祀祖先和神灵的节日是什么?
# answer:  {'answer': '腊八节', 'start': 36, 'end': 39, 'score': 1.0}
#
# full_context:  生化危机[根据Capcom电子游戏改编的系列电影]的描述是：《生化危机》系列电影改编自capcom游戏《生化危机》，由保罗·安德森执导，米拉·乔沃维奇主演。
# question:  《生化危机》系列电影改编自哪个游戏?
# answer:  {'answer': '生化危机', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  谁主演了生化危机?
# answer:  {'answer': '米拉·乔沃维奇', 'start': 124, 'end': 131, 'score': 1.0}
#
# question:  Capcom电子游戏改编的系列电影叫什么名字?
# answer:  {'answer': '生化危机', 'start': 36, 'end': 40, 'score': 1.0}
#
# full_context:  湖北大学的描述是：湖北大学（Hubei University）简称湖大（HUBU） ，坐落于湖北省武汉市，是湖北省人民政府与中华人民共和国教育部共建的省属重点综合性大学，入选“中西部高校基础能力建设工程”，是湖北省“2011计划”牵头高校，武器装备科研生产二级保密资格高校，中国政府奖学金来华留学生和港澳台学生接收高校，湖北省“最佳文明单位”，教育部和英国大使馆批准设立的湖北省唯一的雅思（IELTS）考试考点单位。
# question:  湖北大学位于哪里?
# answer:  {'answer': '湖北省武汉市', 'start': 102, 'end': 108, 'score': 1.0}
#
# question:  湖北省唯一的雅思考试考点单位是哪里?
# answer:  {'answer': '湖北大学', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  湖北大学的简称是什么?
# answer:  {'answer': '湖大', 'start': 89, 'end': 91, 'score': 1.0}
#
# full_context:  晋祠的描述是：晋祠，位于山西省太原市晋源区晋祠镇，原名为晋王祠，初名唐叔虞祠，是为纪念晋国开国诸侯唐叔虞（后被追封为晋王）及母后邑姜后而建。
# question:  晋祠的原名叫什么?
# answer:  {}
#
# question:  晋祠位于哪里?
# answer:  {'answer': '山西省太原', 'start': 68, 'end': 73, 'score': 1.0}
#
# question:  唐叔虞祠的初名是什么?
# answer:  {'answer': '晋祠', 'start': 36, 'end': 38, 'score': 1.0}
#
# full_context:  金庸的描述是：金庸，原名查良镛，1924年3月10日生于浙江省海宁市，1948年移居香港。
# question:  金庸原名叫什么?
# answer:  {'answer': '查良镛', 'start': 68, 'end': 71, 'score': 1.0}
#
# question:  金庸的原名叫做什么?
# answer:  {'answer': '查良镛', 'start': 68, 'end': 71, 'score': 1.0}
#
# question:  1948年金庸移居香港的原名是什么?
# answer:  {'answer': '查良镛', 'start': 68, 'end': 71, 'score': 1.0}
#
# full_context:  统计悖论的描述是：这个悖论可追溯到18世纪，它是一个非传递关系的典型，这种关系是在人们作两两对比选择时可能产生的。
# question:  统计悖论的描述是什么时候开始的?
# answer:  {'answer': '18世纪', 'start': 73, 'end': 77, 'score': 1.0}
#
# question:  什么类型的非传递关系可以追溯到18世纪?
# answer:  {'answer': '统计悖论', 'start': 36, 'end': 40, 'score': 1.0}
#
# question:  非传递关系的典型例子是什么?
# answer:  {'answer': '统计悖论', 'start': 36, 'end': 40, 'score': 1.0}
#
# full_context:  木料的描述是：[timber;lumber;wood] 准备用于或构成一个建筑物的部分的一块较大的方木或修整过的块木...
# question:  木料的描述是什么?
# answer:  {'answer': '实体', 'start': 30, 'end': 32, 'score': 0.9999998807907104}
#
# question:  什么类型的木料可以用来建造建筑物的部分?
# answer:  {'answer': '方木', 'start': 105, 'end': 107, 'score': 1.0}
#
# question:  木料是用来做什么的?
# answer:  {'answer': '建筑物', 'start': 93, 'end': 96, 'score': 0.9999998807907104}
#
# full_context:  魔兽争霸的描述是：《魔兽争霸》是暴雪娱乐公司开发的角色扮演即时战略游戏系列，魔兽争霸在世界游戏排名一直排名在前列，魔兽争霸是一款即时战略性游戏。
# question:  《魔兽争霸》是哪个公司开发的游戏?
# answer:  {'answer': '暴雪', 'start': 72, 'end': 74, 'score': 1.0}
#
# question:  魔兽争霸的角色扮演角色扮演什么角色?
# answer:  {}
#
# question:  谁开发了魔兽争霸?
# answer:  {'answer': '暴雪', 'start': 72, 'end': 74, 'score': 1.0}
#
# full_context:  小儿清肺颗粒的描述是：小儿清肺颗粒，清热,化痰。
# question:  小儿清肺颗粒吃啥药
# answer:  {'answer': '小儿清肺颗粒', 'start': 36, 'end': 42, 'score': 0.9999990463256836}
#
# question:  小儿的清肺的颗粒吃什么药
# answer:  {'answer': '小儿清肺颗粒', 'start': 36, 'end': 42, 'score': 1.0}
#
# question:  大儿清肺中的颗粒吃哪个药
# answer:  {'answer': '小儿清肺颗粒', 'start': 36, 'end': 42, 'score': 1.0}
#
# full_context:  河北工程大学科信学院的描述是：河北工程大学科信学院坐落于中国历史文化名城邯郸市。
# question:  河北工程大学科信学院坐落于什么地方?
# answer:  {'answer': '邯郸', 'start': 92, 'end': 94, 'score': 1.0}
#
# question:  邯郸市的科信学院位于哪里?
# answer:  {'answer': '河北工程大学', 'start': 36, 'end': 42, 'score': 1.0}
#
# question:  河北工程学院的地址是哪里?
# answer:  {'answer': '邯郸', 'start': 92, 'end': 94, 'score': 1.0}
#
# full_context:  魔兽世界[暴雪娱乐开发的多人在线角色扮演游戏]的描述是：《魔兽世界》（World of Warcraft）是由著名游戏公司暴雪娱乐所制作的第一款网络游戏，属于大型多人在线角色扮演游戏。
# question:  《魔兽世界》是哪个公司开发的游戏?
# answer:  {'answer': '暴雪', 'start': 41, 'end': 43, 'score': 1.0}
#
# question:  暴雪娱乐开发的游戏叫什么名字?
# answer:  {'answer': '魔兽', 'start': 36, 'end': 38, 'score': 1.0}
#
# question:  魔兽世界是由谁开发的?
# answer:  {'answer': '暴雪', 'start': 41, 'end': 43, 'score': 1.0}
#
# full_context:  woman[woman]的描述是：woman：2013年满岛光主演电视剧woman：AZU演唱歌曲woman：英语单词woman：约翰列侬创作于1980年的一首歌曲woman：Kesha&amp;The Dap-Kings Horns演唱歌曲...
# question:  谁创作了女的歌曲?
# answer:  {'answer': '约翰列侬', 'start': 121, 'end': 125, 'score': 1.0}
#
# question:  谁演唱了女主角的歌?
# answer:  {'answer': '约翰列侬', 'start': 121, 'end': 125, 'score': 0.9999814033508301}
#
# question:  女主角的歌曲叫什么名字?
# answer:  {'answer': 'woman', 'start': 36, 'end': 41, 'score': 0.9999963045120239}
#
# full_context:  荀彧[东汉末年政治家、战略家]的描述是：荀彧（xún yù）（163年－212年），字文若。
# question:  荀彧字什么?
# answer:  {'answer': '文若', 'start': 99, 'end': 101, 'score': 1.0}
#
# question:  荀彧的字是什么?
# answer:  {'answer': '文若', 'start': 99, 'end': 101, 'score': 1.0}
#
# question:  谁是荀彧的政治家?
# answer:  {}
#
# full_context:  阿富汗伊斯兰共和国的描述是：阿富汗伊斯兰共和国（普什图语：جمهوری اسلامی افغانستان‎），简称阿富汗，是一个位于亚洲中南部的内陆国家，坐落在亚洲的心脏地区。
# question:  阿富汗伊斯兰共和国位于亚洲的心脏地区
# answer:  {'answer': '亚洲中南部', 'start': 127, 'end': 132, 'score': 0.9999994039535522}
#
# question:  阿富汗 伊斯兰共和国坐落在亚洲的心脏地区的
# answer:  {'answer': '中南部', 'start': 129, 'end': 132, 'score': 0.9999995231628418}
#
# question:  哪个国家是阿富汗的内陆国家
# answer:  {'answer': '阿富汗伊斯兰共和国', 'start': 36, 'end': 45, 'score': 1.0}
#
# full_context:  男人[具有xy染色体的人]的描述是：男人同女人相对，从生理学上讲，具有xy染色体的人就是男人。
# question:  在生理学上讲,具有xy染色体的人是什么?
# answer:  {'answer': '男人', 'start': 36, 'end': 38, 'score': 1.0}
#
# question:  具有xy染体体的人叫什么?
# answer:  {'answer': '男人', 'start': 36, 'end': 38, 'score': 1.0}
#
# question:  男人和女人的区别是什么?
# answer:  {'answer': "OrderedDict([('', '28426'), ('实体', '男人[具有xy染色体", 'start': 0, 'end': 46, 'score': 0.9999182224273682}
#
# full_context:  摩羯座[十二星座之一]的描述是：摩羯座（Capricornus），黄道十二宫的第十宫，出生日期为12月22日至1月19日，位于射手座之东，水瓶座之西。
# question:  摩羯座在黄道十二宫的第十宫是什么?
# answer:  {'answer': '水瓶座', 'start': 125, 'end': 128, 'score': 0.9999958276748657}
#
# question:  摩羯的出生日期是什么时候?
# answer:  {'answer': '12月22日', 'start': 104, 'end': 110, 'score': 0.9999998807907104}
#
# question:  火瓶座位于什么地方?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-38f8c719ab23> in <module>()
#      18                 answer = qa({
#      19                     'question': str(q),
# ---> 20                     'context': str(row)
#      21                 })
#      22                 test_file.write(str(answer))
#
# /usr/local/lib/python3.7/dist-packages/question_generation/pipelines/question_answering.py in __call__(self, input, *args, **kwargs)
#     124         with torch.no_grad():
#     125             eval_predictions = self.model(input_ids=input_ids,
# --> 126                                           attention_mask=input_masks)
#     127         examples = Dataset.from_dict(examples)
#     128         flat_examples = []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, start_positions, end_positions, output_attentions, output_hidden_states, return_dict)
#    1837             output_attentions=output_attentions,
#    1838             output_hidden_states=output_hidden_states,
# -> 1839             return_dict=return_dict,
#    1840         )
#    1841
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1004             output_attentions=output_attentions,
#    1005             output_hidden_states=output_hidden_states,
# -> 1006             return_dict=return_dict,
#    1007         )
#    1008         sequence_output = encoder_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     590                     encoder_attention_mask,
#     591                     past_key_value,
# --> 592                     output_attentions,
#     593                 )
#     594
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     475             head_mask,
#     476             output_attentions=output_attentions,
# --> 477             past_key_value=self_attn_past_key_value,
#     478         )
#     479         attention_output = self_attention_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     407             encoder_attention_mask,
#     408             past_key_value,
# --> 409             output_attentions,
#     410         )
#     411         attention_output = self.output(self_outputs[0], hidden_states)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     289         else:
#     290             key_layer = self.transpose_for_scores(self.key(hidden_states))
# --> 291             value_layer = self.transpose_for_scores(self.value(hidden_states))
#     292
#     293         query_layer = self.transpose_for_scores(mixed_query_layer)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# KeyboardInterrupt:

# %%
# !transformers-cli login
# Out:
# WARNING! `transformers-cli login` is deprecated and will be removed in v5. Please use `huggingface-cli login` instead.
#
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#
# Username: yangdafu123@gmail.com
# Password:
# ERROR:root:HfApi.login: This method is deprecated in favor of `set_access_token`.
# Login successful
# Your token: WkTlJJhLZYliTNwiVhyaQnJKDxHxCmBSlYAeTspLMFTaQoZcZQxNmtZAuiIBYVRyTtmzsTiYngWnRoxqYrCdBJvaEpIcqXviIykrcVjorMEzcdhbVBitmeKFupDUcWmR
#
# Your token has been saved to /root/.huggingface/token

# %%
# !transformers-cli upload ./path/to/pretrained_model/
# Out:
# usage: transformers-cli <command> [<args>]
# Transformers CLI tool: error: invalid choice: 'upload' (choose from 'convert', 'download', 'env', 'run', 'serve', 'login', 'whoami', 'logout', 'repo', 'add-new-model', 'add-new-model-like', 'lfs-enable-largefiles', 'lfs-multipart-upload')

# %%
# !ls -a
# Out:
# .   .config  .ipynb_checkpoints  split0-diliweizhi-qa.txt
# ..  drive    sample_data

# %%
from transformers import AutoModel

# %%
# !apt-get install git-lfs=2.13.3
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Version '2.13.3' for 'git-lfs' was not found

# %% [markdown]
# **Clone repository. First install git lfs. Pulling all checkpoints may take a while**

# %%
# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | sudo bash
# !sudo apt-get install git-lfs
# !git lfs install
# Out:
# Detected operating system as Ubuntu/bionic.
# Checking for curl...
# Detected curl...
# Checking for gpg...
# Detected gpg...
# Running apt-get update... done.
# Installing apt-transport-https... done.
# Installing /etc/apt/sources.list.d/github_git-lfs.list...done.
# Importing packagecloud gpg key... done.
# Running apt-get update... done.
#
# The repository is setup! You can now install packages.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   git-lfs
# 0 upgraded, 1 newly installed, 0 to remove and 40 not upgraded.
# Need to get 6,800 kB of archives.
# After this operation, 15.3 MB of additional disk space will be used.
# Get:1 https://packagecloud.io/github/git-lfs/ubuntu bionic/main amd64 git-lfs amd64 3.1.2 [6,800 kB]
# Fetched 6,800 kB in 1s (5,646 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package git-lfs.
# (Reading database ... 155336 files and directories currently installed.)
# Preparing to unpack .../git-lfs_3.1.2_amd64.deb ...
# Unpacking git-lfs (3.1.2) ...
# Setting up git-lfs (3.1.2) ...
# Git LFS initialized.
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Git LFS initialized.

# %%
model.push_to_hub("mt5-base-chinese-qg", use_temp_dir=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py:1004: FutureWarning: `create_repo` now takes `token` as an optional positional argument. Be sure to adapt your code!
#   FutureWarning,
# Cloning https://huggingface.co/Yangdf/mt5-base-chinese-qg into local empty directory.
# Upload file pytorch_model.bin:   0%|          | 32.0k/2.17G [00:00<?, ?B/s]
# To https://huggingface.co/Yangdf/mt5-base-chinese-qg
#    435354c..5e92dab  main -> main
# 'https://huggingface.co/Yangdf/mt5-base-chinese-qg/commit/5e92dabb48dfa5caff54f550d6cb2ff968cd2491'

# %%
tokenizer.push_to_hub("mt5-base-chinese-qg", use_temp_dir=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py:1004: FutureWarning: `create_repo` now takes `token` as an optional positional argument. Be sure to adapt your code!
#   FutureWarning,
# Cloning https://huggingface.co/Yangdf/mt5-base-chinese-qg into local empty directory.
# Download file pytorch_model.bin:   0%|          | 8.48k/2.17G [00:00<?, ?B/s]
# Clean file pytorch_model.bin:   0%|          | 1.00k/2.17G [00:00<?, ?B/s]
# Adding files tracked by Git LFS: ['tokenizer.json']. This may take a bit of time if the files are large.
# Upload file tokenizer.json:   0%|          | 32.0k/15.6M [00:00<?, ?B/s]
# To https://huggingface.co/Yangdf/mt5-base-chinese-qg
#    5e92dab..cd9134e  main -> main
# 'https://huggingface.co/Yangdf/mt5-base-chinese-qg/commit/cd9134e579d36a1c38d8671e84769442ee2a26ee'
