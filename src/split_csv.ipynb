# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./drive/MyDrive/Database/KnowledgeGraph/ownthink_v2.csv')
length = len(df)
print('length: ', length)

chunksize = 10000000
num = length//chunksize
# Out:
# length:  139951300

# %%
i = 0
for chunk in np.split(df[:130000000], 13, axis=0):
    chunk.to_csv('./drive/MyDrive/Database/split_1000/file{:02d}.csv'.format(i), index=True)
    i += 1

# %%
chunk = df[130000000:]
chunk.to_csv('./drive/MyDrive/Database/split_1000/file_13.csv', index=True)
