# %%
count_list = []

domain_label = 'label-1'
count_number = 10
dict_domain = {'domain_label': domain_label, 'count_number': count_number}
dict_domain_copy = dict_domain.copy()

count_list.append(dict_domain_copy)

print(count_list)
# Out:
# [{'domain_label': 'label-1', 'count_number': 10}]

# %%
a_dictionary = {"name" : "John", "age" : 20}
a_list = []

dictionary_copy = a_dictionary.copy()
a_list.append(dictionary_copy)

print(a_list)
# Out:
# [{'name': 'John', 'age': 20}]
